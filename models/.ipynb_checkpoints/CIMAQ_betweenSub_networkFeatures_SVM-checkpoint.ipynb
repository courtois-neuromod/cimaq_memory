# %%
# %matplotlib inline

# %% [markdown]
# Between-subject SVM classification based on network weight features, for CIMAQ memory encoding task (fMRI data).
#
# Network weights reflect the engagement of a particular network for each trial.
#
# Parcellations include:
# - 7 networks
# - 20 networks
# - 64 networks
#
# Trials (conditions) are classifierd according to:
# - task condition (encoding or control task)
# - memory performance (hit vs miss, correct vs incorrect source)
# - stimulus category (?)

# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import nilearn
import scipy
import nibabel as nb
import sklearn
import seaborn as sns
import itertools

from numpy import nan as NaN
from matplotlib import pyplot as plt
from nilearn import image, plotting
from nilearn import masking
from nilearn import plotting
from nilearn import datasets
from nilearn.plotting import plot_stat_map, plot_roi, plot_anat, plot_img, show
from nilearn.input_data import NiftiMasker
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, f1_score
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Step 1: import list of participants, and generate sublists of participants who have enough trials per category for each classification
#
# 1. Encoding vs Control task conditions (all 94)
#
# 2. Stimulus category (all 94)
#
# 3. Hit versus Miss (42 participants; at least 15 trials per condition)
#
# 4. Correct Source versus Wrong Source (49 participants; at least 15 trials per condition)
#
# 5. Correct Source versus Miss (38 participants; at least 15 trials per condition)
#
#
# **NOTE: ADD filter to exclude participants with too many scrubbed frames?? **

# %%
# Path to directory with participant lists
data_file = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Participants/Splitting/Sub_list.tsv'
sub_data = pd.read_csv(data_file, sep = '\t')

# Exclude participants who failed QC
sub_data = sub_data[sub_data['QC_status']!= 'F']

# Exclude participants with bad X matrices
sub_data = sub_data[sub_data['net_NaN']!= 'N']

## ADD filter to exclude participants with too many scrubbed frames?? ##

# Set minimal number of trials needed per subject to include them in analysis
num = 14

# Encoding vs Control, and Stimulus Category classifications
all_subs = sub_data['participant_id']
all_diagnosis = sub_data['cognitive_status']
print(all_subs)
print(len(all_subs))

# Hit versus Miss
hm_data = sub_data[sub_data['hits'] > num]
hm_data = hm_data[hm_data['miss'] > num]
hm_subs = hm_data['participant_id']
hm_diagnosis = hm_data['cognitive_status']
print(hm_subs)
print(len(hm_subs))

# Correct Source versus Wrong Source 
cw_data = sub_data[sub_data['correct_source'] > num]
cw_data = cw_data[cw_data['wrong_source'] > num]
cw_subs = cw_data['participant_id']
cw_diagnosis = cw_data['cognitive_status']
print(cw_subs)
print(len(cw_subs))

# Correct Source versus Miss
cmiss_data = sub_data[sub_data['correct_source'] > num]
cmiss_data = cmiss_data[cmiss_data['miss'] > num]
cmiss_subs = cmiss_data['participant_id']
cmiss_diagnosis = cmiss_data['cognitive_status']
print(cmiss_subs)
print(len(cmiss_subs))
# Out:
# 0      108391
# 1      120839
# 2      122922
# 3      127228
# 4      139593
# 6      147863
# 8      164965
# 9      175295
# 11     189005
# 12     197192
# 14     199801
# 15     219637
# 16     229301
# 17     247659
# 20     258618
# 21     258912
# 22     267168
# 23     270218
# 28     326073
# 29     336665
# 30     337021
# 32     370092
# 34     385370
# 35     386333
# 36     396250
# 37     403131
# 38     408506
# 39     413474
# 40     427357
# 41     437101
#         ...
# 65     677561
# 66     711830
# 69     748676
# 70     763590
# 71     778749
# 72     783781
# 73     785217
# 74     785245
# 75     804743
# 77     845675
# 78     866812
# 79     878354
# 80     884343
# 81     886007
# 83     893978
# 85     901551
# 86     906145
# 87     914042
# 88     915022
# 89     920577
# 90     932933
# 92     938001
# 93     955548
# 94     956049
# 95     956130
# 96     968913
# 97     974246
# 99     983291
# 100    988602
# 101    996599
# Name: participant_id, Length: 80, dtype: int64
# 80
# 0     108391
# 2     122922
# 4     139593
# 8     164965
# 14    199801
# 17    247659
# 20    258618
# 21    258912
# 29    336665
# 30    337021
# 36    396250
# 37    403131
# 38    408506
# 39    413474
# 41    437101
# 42    439776
# 44    458807
# 45    459801
# 47    484204
# 55    567214
# 56    597569
# 60    652850
# 65    677561
# 66    711830
# 69    748676
# 70    763590
# 71    778749
# 72    783781
# 80    884343
# 81    886007
# 89    920577
# 95    956130
# 97    974246
# 99    983291
# Name: participant_id, dtype: int64
# 34
# 0      108391
# 2      122922
# 4      139593
# 9      175295
# 12     197192
# 14     199801
# 16     229301
# 20     258618
# 22     267168
# 28     326073
# 29     336665
# 30     337021
# 34     385370
# 38     408506
# 39     413474
# 40     427357
# 41     437101
# 44     458807
# 45     459801
# 46     462345
# 53     549994
# 54     555537
# 55     567214
# 57     619278
# 60     652850
# 62     659068
# 65     677561
# 66     711830
# 69     748676
# 71     778749
# 72     783781
# 79     878354
# 80     884343
# 83     893978
# 85     901551
# 86     906145
# 88     915022
# 90     932933
# 92     938001
# 93     955548
# 96     968913
# 101    996599
# Name: participant_id, dtype: int64
# 42
# 0     108391
# 2     122922
# 4     139593
# 8     164965
# 14    199801
# 17    247659
# 20    258618
# 29    336665
# 30    337021
# 36    396250
# 37    403131
# 38    408506
# 39    413474
# 41    437101
# 42    439776
# 44    458807
# 45    459801
# 47    484204
# 55    567214
# 56    597569
# 60    652850
# 65    677561
# 66    711830
# 69    748676
# 71    778749
# 72    783781
# 80    884343
# 81    886007
# 95    956130
# 99    983291
# Name: participant_id, dtype: int64
# 30

# %% [markdown]
# Step 2: For each categorization, randomly assign and split participants into a training set and a test set
#
# Note: stratify to maintain comparable proportions of Cognitively Normal (Controls), Subjective Cognitive Disorder (SCD) and Mild Cognitive Impairment (MCI) participants between the testing and training sets

# %%
# Encoding vs Control Task Conditions

enc_ctl_train, enc_ctl_test = train_test_split(
    all_subs, # list to split
    test_size = 0.4, # 60%/40% split between train and test
    shuffle= True, 
    stratify = all_diagnosis, # keep consistent proportions of Controls, SCDs and MCIs between sets
    random_state = 123)

print('enc_ctl training:', len(enc_ctl_train),
     'enc_ctl testing:', len(enc_ctl_test))


# Hit vs Miss Trials

hit_miss_train, hit_miss_test = train_test_split(
    hm_subs, # list to split
    test_size = 0.4, # 60%/40% split between train and test
    shuffle= True, 
    stratify = hm_diagnosis, # keep consistent proportions of Controls, SCDs and MCIs between sets
    random_state = 52)

print('hit_miss training:', len(hit_miss_train),
     'hit_miss testing:', len(hit_miss_test))


# Correct Source vs Wrong Source Trials

cs_ws_train, cs_ws_test = train_test_split(
    cw_subs, # list to split
    test_size = 0.4, # 60%/40% split between train and test
    shuffle= True, 
    stratify = cw_diagnosis, # keep consistent proportions of Controls, SCDs and MCIs between sets
    random_state = 46)

print('cs_ws training:', len(cs_ws_train),
     'cs_ws testing:', len(cs_ws_test))


# Correct Source vs Miss Trials

cs_miss_train, cs_miss_test = train_test_split(
    cmiss_subs, # list to split
    test_size = 0.4, # 60%/40% split between train and test
    shuffle= True, 
    stratify = cmiss_diagnosis, # keep consistent proportions of Controls, SCDs and MCIs between sets
    random_state = 103)

print('cs_miss training:', len(cs_miss_train),
     'cs_miss testing:', len(cs_miss_test))
# Out:
# enc_ctl training: 48 enc_ctl testing: 32
# hit_miss training: 20 hit_miss testing: 14
# cs_ws training: 25 cs_ws testing: 17
# cs_miss training: 18 cs_miss testing: 12

# %% [markdown]
# Step 3: Build training and testing feature matrices
#
# For each participant:
# - load matrix of network weigth features (shape = trials per networks)
# - load the trial labels
# - mask the data (network weights and labels) that correspond to trials of interest
# - concatenate the participant's weights and label data into two matrices (weights and labels). There should be two matrices per set (train and test) per analysis.
#
# Note:
# Trying three different grains of segmentation: 7, 20 and 64 networks
#
# ALSO:
# Import MIST network labels to identify and interpret features

# %%
# set paths to directories of interest
beta_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Nistats/NetworkWeights'
label_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Nistats/Events'
output_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Nilearn/features'

# %%
# ENCODING VERSUS CONTROL TASK CLASSIFICATION

# For each set (training and test), create an empty numpy array to store 
# concatenated network weight maps (one row per trial; size = trials * networks).

# 1. set the parcellation level
numnet = 7
# numnet = 20
# numnet = 64

# 2. determine the number of rows needed (sum of trials per participants in set)
numrow_train = 0
numrow_test = 0
for sub in enc_ctl_train:
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_enco_ctl.tsv')
    y_enco_ctl = pd.read_csv(labels_file, sep='\t')
    numrow_train = numrow_train + y_enco_ctl.shape[0]

for sub in enc_ctl_test:
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_enco_ctl.tsv')
    y_enco_ctl = pd.read_csv(labels_file, sep='\t')
    numrow_test = numrow_test + y_enco_ctl.shape[0]    
    
print('number of trials in the training set: ', numrow_train,
     'number of trials in the test set: ', numrow_test)    

# 3. create an empty numpy array to store the data 
X_enc_ctl_train = np.empty(shape=(numrow_train, numnet))
X_enc_ctl_test = np.empty(shape=(numrow_test, numnet))

print(X_enc_ctl_train.shape, X_enc_ctl_test.shape)

# 4. create empty dataframes to store trial labels (one per set)
y_enc_ctl_train = pd.DataFrame()
y_enc_ctl_train.insert(loc = 0, column = 'condition', value = 'TBD', allow_duplicates=True)
y_enc_ctl_train.insert(loc = 1, column = 'dccid', value = 'TBD', allow_duplicates=True)
y_enc_ctl_train.insert(loc = 2, column = 'trialnum', value = 'NaN', allow_duplicates=True)

y_enc_ctl_test = y_enc_ctl_train.copy()
# Out:
# number of trials in the training set:  5590 number of trials in the test set:  3734
# (5590, 7) (3734, 7)

# %%
# 5. Fill the X (beta weights per voxel) and y (trial labels) data matrices

# note: nilearn.image.load_img concatenates 3D beta maps in alphabetical order
# trial numbers must be PADDED with zeros to preserve their temporal order when alphabetized

# TRAINING SET
j = 0
for sub in enc_ctl_train: 
    print(sub)
    weights_file = os.path.join(beta_dir, 'MIST_'+str(numnet), 'sub-'+str(sub)+'-MIST_'+str(numnet)+'networks_117Trials.tsv')
    X_netWeights = pd.read_csv(weights_file, sep='\t')
    #print(X_netWeights)
    X_enc_ctl_train[j:(j+X_netWeights.shape[0]), :] = X_netWeights
    j = j + X_netWeights.shape[0]
    print(np.where(np.isnan(X_netWeights)))
    print('number of X filled rows: ', j, 
          'subject X_shape:', X_netWeights.shape,
         'total X_shape:', X_enc_ctl_train.shape)
    
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_enco_ctl.tsv')
    y_enco_ctl = pd.read_csv(labels_file, sep='\t')
    trialnum = y_enco_ctl.index
    y_enco_ctl.insert(loc = y_enco_ctl.shape[1], column = 'dccid', 
                           value = sub, allow_duplicates=True)
    y_enco_ctl.insert(loc = y_enco_ctl.shape[1], column = 'trialnum', 
                           value = trialnum+1, allow_duplicates=True)
    y_enc_ctl_train = y_enc_ctl_train.append(y_enco_ctl, ignore_index=True)
    print('subject y_shape:', y_enco_ctl.shape,
         'total y_shape:', y_enc_ctl_train.shape)
    print(y_enco_ctl.condition.value_counts())

print('The training data set is built!') 

# TESTING SET
j = 0
for sub in enc_ctl_test: 
    print(sub)    
    weights_file = os.path.join(beta_dir, 'MIST_'+str(numnet), 'sub-'+str(sub)+'-MIST_'+str(numnet)+'networks_117Trials.tsv')
    X_netWeights = pd.read_csv(weights_file, sep='\t')
    #print(X_netWeights)
    X_enc_ctl_test[j:(j+X_netWeights.shape[0]), :] = X_netWeights
    j = j + X_netWeights.shape[0]
    print(np.where(np.isnan(X_netWeights)))
    print('number of X filled rows: ', j, 
          'subject X_shape:', X_netWeights.shape,
         'total X_shape:', X_enc_ctl_test.shape)
    
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_enco_ctl.tsv')
    y_enco_ctl = pd.read_csv(labels_file, sep='\t')
    trialnum = y_enco_ctl.index
    y_enco_ctl.insert(loc = y_enco_ctl.shape[1], column = 'dccid', 
                           value = sub, allow_duplicates=True)
    y_enco_ctl.insert(loc = y_enco_ctl.shape[1], column = 'trialnum', 
                           value = trialnum+1, allow_duplicates=True)
    y_enc_ctl_test= y_enc_ctl_test.append(y_enco_ctl, ignore_index=True)
    print('subject y_shape:', y_enco_ctl.shape,
         'total y_shape:', y_enc_ctl_test.shape)
    print(y_enco_ctl.condition.value_counts())

print('The testing data set is built!') 

# 6. extract the label columns from the y data dataframes (to input model)
y_enco_ctl_labels_train = y_enc_ctl_train['condition']
y_enco_ctl_labels_test = y_enc_ctl_test['condition']
# Out:
# 974246
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  117 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (117, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 886007
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  234 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (234, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 197192
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  351 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (351, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 658178
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  468 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (468, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 932933
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  585 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (585, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 906145
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  702 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (702, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 543589
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  817 subject X_shape: (115, 7) total X_shape: (5590, 7)
# subject y_shape: (115, 3) total y_shape: (817, 3)
# Enc    76
# CTL    39
# Name: condition, dtype: int64
# 408506
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  934 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (934, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 783781
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1051 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1051, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 127228
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1168 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1168, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 955548
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1285 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1285, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 413474
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1402 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1402, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 270218
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1519 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1519, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 484204
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1636 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1636, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 549994
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1753 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1753, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 370092
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1866 subject X_shape: (113, 7) total X_shape: (5590, 7)
# subject y_shape: (113, 3) total y_shape: (1866, 3)
# Enc    74
# CTL    39
# Name: condition, dtype: int64
# 267168
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1983 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (1983, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 490035
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2100 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2100, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 778749
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2217 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2217, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 396250
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2334 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2334, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 785217
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2451 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2451, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 845675
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2568 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2568, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 336665
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2681 subject X_shape: (113, 7) total X_shape: (5590, 7)
# subject y_shape: (113, 3) total y_shape: (2681, 3)
# Enc    75
# CTL    38
# Name: condition, dtype: int64
# 938001
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2798 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2798, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 122922
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2915 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (2915, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 652850
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3032 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3032, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 462345
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3147 subject X_shape: (115, 7) total X_shape: (5590, 7)
# subject y_shape: (115, 3) total y_shape: (3147, 3)
# Enc    76
# CTL    39
# Name: condition, dtype: int64
# 441008
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3264 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3264, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 120839
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3381 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3381, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 968913
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3498 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3498, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 659068
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3615 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3615, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 459801
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3732 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3732, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 711830
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3849 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (3849, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 258912
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3962 subject X_shape: (113, 7) total X_shape: (5590, 7)
# subject y_shape: (113, 3) total y_shape: (3962, 3)
# Enc    74
# CTL    39
# Name: condition, dtype: int64
# 988602
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4079 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (4079, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 878354
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4196 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (4196, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 247659
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4305 subject X_shape: (109, 7) total X_shape: (5590, 7)
# subject y_shape: (109, 3) total y_shape: (4305, 3)
# Enc    71
# CTL    38
# Name: condition, dtype: int64
# 427357
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4422 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (4422, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 884343
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4539 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (4539, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 437101
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4656 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (4656, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 520377
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4771 subject X_shape: (115, 7) total X_shape: (5590, 7)
# subject y_shape: (115, 3) total y_shape: (4771, 3)
# Enc    76
# CTL    39
# Name: condition, dtype: int64
# 439776
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  4888 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (4888, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 458807
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  5005 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (5005, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 555537
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  5122 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (5122, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 597569
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  5239 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (5239, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 628299
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  5356 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (5356, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 619278
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  5473 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (5473, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 199801
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  5590 subject X_shape: (117, 7) total X_shape: (5590, 7)
# subject y_shape: (117, 3) total y_shape: (5590, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# The training data set is built!
# 175295
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  117 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (117, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 229301
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  230 subject X_shape: (113, 7) total X_shape: (3734, 7)
# subject y_shape: (113, 3) total y_shape: (230, 3)
# Enc    75
# CTL    38
# Name: condition, dtype: int64
# 403131
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  347 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (347, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 785245
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  464 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (464, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 337021
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  581 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (581, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 893978
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  698 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (698, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 385370
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  815 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (815, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 956130
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  932 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (932, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 996599
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1049 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1049, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 108391
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1166 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1166, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 139593
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1283 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1283, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 147863
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1400 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1400, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 914042
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1517 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1517, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 748676
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1634 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1634, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 219637
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1751 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1751, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 386333
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1868 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1868, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 920577
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  1985 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (1985, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 901551
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2100 subject X_shape: (115, 7) total X_shape: (3734, 7)
# subject y_shape: (115, 3) total y_shape: (2100, 3)
# Enc    76
# CTL    39
# Name: condition, dtype: int64
# 677561
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2217 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2217, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 567214
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2334 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2334, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 956049
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2451 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2451, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 804743
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2568 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2568, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 983291
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2685 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2685, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 866812
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2802 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2802, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 915022
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  2919 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (2919, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 258618
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3036 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (3036, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 326073
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3153 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (3153, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 164965
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3270 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (3270, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 763590
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3383 subject X_shape: (113, 7) total X_shape: (3734, 7)
# subject y_shape: (113, 3) total y_shape: (3383, 3)
# Enc    75
# CTL    38
# Name: condition, dtype: int64
# 517070
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3500 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (3500, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 630120
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3617 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (3617, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# 189005
# (array([], dtype=int64), array([], dtype=int64))
# number of X filled rows:  3734 subject X_shape: (117, 7) total X_shape: (3734, 7)
# subject y_shape: (117, 3) total y_shape: (3734, 3)
# Enc    78
# CTL    39
# Name: condition, dtype: int64
# The testing data set is built!

# %%
# Data to input the Support Vector Machine model for different classifications: 

# ENCODING vs CONTROL condition: 
# Training: X_enc_ctl_train, y_enco_ctl_labels_train
# Testing: X_enc_ctl_test, y_enco_ctl_labels_test

# HIT vs MISS trials: 
# Training: X_hit_miss_train, y_hit_miss_labels_train
# Testing: X_hit_miss_test, y_hit_miss_labels_test

# CORRECT SOURCE vs WRONG SOURCE trials:
# Training: X_cs_ws_train, y_cs_ws_labels_train
# Testing: X_cs_ws_test, y_cs_ws_labels_test

# CORRECT SOURCE vs MISS trials: 
# Training: X_cs_miss_train, y_cs_miss_labels_train
# Testing: X_cs_miss_test, y_cs_miss_labels_test

X_train = X_enc_ctl_train
y_train = y_enco_ctl_labels_train
X_test = X_enc_ctl_test
y_test = y_enco_ctl_labels_test

# initialise the SVC model
# Note that class_weight gives equivalent influence to different categories
# important if number of trials differs per condition
#trial_svc = SVC(kernel='linear', class_weight='balanced') #define the model
trial_svc = LinearSVC(class_weight='balanced') #define the model

print(trial_svc)
# Out:
# LinearSVC(C=1.0, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
trial_svc.fit(X_train, y_train) #train the model

# MAKE SURE: mettre poids egal par categorie.
# class-weight: balanced!!! 

# predict the training data based on the model
y_pred = trial_svc.predict(X_train)

# calculate the model accuracy
acc = trial_svc.score(X_train, y_train)

# calculate the model precision, recall and f1 in one report
cr = classification_report(y_true=y_train,
                      y_pred = y_pred)

# get a table to help us break down these scores
cm = confusion_matrix(y_true=y_train, y_pred = y_pred)

# print results
print('accuracy:', acc)
print(cr)
print(cm)

# plot confusion matrix (training data)
cmdf = pd.DataFrame(cm, index = ['Control','Encoding'], columns = ['Control','Encoding'])
sns.heatmap(cmdf, cmap = 'RdBu_r')
plt.xlabel('Predicted')
plt.ylabel('Observed')
# label cells in matrix
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j+0.5, i+0.5, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white")
# Out:
# accuracy: 0.6368515205724508
#               precision    recall  f1-score   support
#
#          CTL       0.47      0.64      0.54      1870
#          Enc       0.78      0.64      0.70      3720
#
#    micro avg       0.64      0.64      0.64      5590
#    macro avg       0.62      0.64      0.62      5590
# weighted avg       0.67      0.64      0.65      5590
#
# [[1188  682]
#  [1348 2372]]

# %%
# Set up 10-fold cross-validation to evaluate the model's performance over the training set
# predict
y_pred = cross_val_predict(trial_svc, X_train, y_train,
                           groups=y_train, cv=10)
# scores
acc = cross_val_score(trial_svc, X_train, y_train,
                     groups=y_train, cv=10)

#Look at accuracy of prediction for each fold of the cross-validation
for i in range(10):
    print('Fold %s -- Acc = %s'%(i, acc[i]))
# Out:
# Fold 0 -- Acc = 0.6368515205724508
# Fold 1 -- Acc = 0.631484794275492
# Fold 2 -- Acc = 0.6547406082289803
# Fold 3 -- Acc = 0.6332737030411449
# Fold 4 -- Acc = 0.6797853309481217
# Fold 5 -- Acc = 0.627906976744186
# Fold 6 -- Acc = 0.6171735241502684
# Fold 7 -- Acc = 0.6135957066189625
# Fold 8 -- Acc = 0.6100178890876565
# Fold 9 -- Acc = 0.6207513416815742

# %%
#look at the overall accuracy of the model

overall_acc = accuracy_score(y_pred = y_pred, y_true = y_train)
overall_cr = classification_report(y_pred = y_pred, y_true = y_train)
overall_cm = confusion_matrix(y_pred = y_pred, y_true = y_train)
print('Accuracy:',overall_acc)
print(overall_cr)

thresh = overall_cm.max() / 2
cmdf = pd.DataFrame(overall_cm, index = ['CTL','Enc'], columns = ['CTL','Enc'])
sns.heatmap(cmdf, cmap='copper')
plt.xlabel('Predicted')
plt.ylabel('Observed')
for i, j in itertools.product(range(overall_cm.shape[0]), range(overall_cm.shape[1])):
        plt.text(j+0.5, i+0.5, format(overall_cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white")
# Out:
# Accuracy: 0.6325581395348837
#               precision    recall  f1-score   support
#
#          CTL       0.46      0.63      0.53      1870
#          Enc       0.77      0.63      0.70      3720
#
#    micro avg       0.63      0.63      0.63      5590
#    macro avg       0.62      0.63      0.62      5590
# weighted avg       0.67      0.63      0.64      5590

# %%
# Test model on unseen data from the test set

# Unscaled
trial_svc.fit(X_train, y_train)
y_pred = trial_svc.predict(X_test) # classify age class using testing data
acc = trial_svc.score(X_test, y_test) # get accuracy

cr = classification_report(y_pred=y_pred, y_true=y_test) # get prec., recall & f1
cm = confusion_matrix(y_pred=y_pred, y_true=y_test) # get confusion matrix

# print results
print('accuracy =', acc)
print(cr)

# plot results
thresh = cm.max() / 2
cmdf = pd.DataFrame(cm, index = ['Control','Encoding'], columns = ['Control','Encoding'])
sns.heatmap(cmdf, cmap='RdBu_r')
plt.xlabel('Predicted')
plt.ylabel('Observed')
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j+0.5, i+0.5, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white")
# Out:
# accuracy = 0.6328334226031066
#               precision    recall  f1-score   support
#
#          CTL       0.46      0.64      0.54      1246
#          Enc       0.78      0.63      0.70      2488
#
#    micro avg       0.63      0.63      0.63      3734
#    macro avg       0.62      0.63      0.62      3734
# weighted avg       0.67      0.63      0.64      3734

# %%
#Display feature weights

coef_ = trial_svc.coef_[0]
print(coef_.shape)

# To interpret MIST parcellation labels:
# https://simexp.github.io/multiscale_dashboard/index.html
basc_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/MIST/Release/Parcellations'
basc = image.load_img(os.path.join(basc_dir, 'MIST_'+str(numnet)+'.nii'))

print(basc.header.get_data_shape())
#print(basc.header)

b_labels = os.path.join('/Users/mombot/Documents/Simexp/CIMAQ/Data/MIST/Release/Parcel_Information/MIST_'+str(numnet)+'.csv')
basc_labels = pd.read_csv(b_labels, sep=';')

basc_labels.insert(loc=3, column='coef', value=coef_, allow_duplicates=True)

print(basc_labels.iloc[:, 2:4])
# Out:
# (7,)
# (53, 64, 52)
#                                                 name      coef
# 0                                         CEREBELLUM -0.196397
# 1                                 MESOLIMBIC_NETWORK  0.274058
# 2                                SOMATOMOTOR_NETWORK -0.365998
# 3                                     VISUAL_NETWORK  0.856488
# 4                               DEFAULT_MODE_NETWORK -1.012513
# 5      FRONTO_PARIETAL_NETWORK_and_VISUAL_DOWNSTREAM  0.810968
# 6  VENTRAL_ATTENTION_NETWORK_and_SALIENCE_NETWORK... -0.181860
