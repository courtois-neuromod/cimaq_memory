# %%
# %matplotlib inline

# %% [markdown]
# Within-subject SVM classification based on beta weights (per trials) averaged within networks from different grains of MIST parcellation, for CIMAQ memory encoding task (fMRI data).
# Mean network betas reflect the engagement of a particular network for each trial.
# MIST Parcellations include: 7, 12, 20, 36, 64, 122, 197, 325, 444 networks
#
# Trials (conditions) are classifierd according to:
# - task condition (encoding or control task)
# - memory performance (hit vs miss, correct vs incorrect source)
# - stimulus category (?)
#
# Each model is ran and tested on data from the same subject, and then group statistics (confidence intervals) are computed around accuracy scores from each individual participant.

# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import nilearn
import scipy
import nibabel as nb
import sklearn
import seaborn as sns
import itertools

from numpy import nan as NaN
from matplotlib import pyplot as plt
from nilearn import image, plotting
from nilearn import masking
from nilearn import plotting
from nilearn import datasets
from nilearn.plotting import plot_stat_map, plot_roi, plot_anat, plot_img, show
from nilearn.input_data import NiftiMasker, NiftiLabelsMasker
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, f1_score
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Step 1: import list of participants, and generate sublists of participants who have enough trials per category for each classification.
#
# Encoding vs Control task conditions (all 94)
# Stimulus category (all 94)
# Hit versus Miss (42 participants; at least 15 trials per condition)
# Correct Source versus Wrong Source (49 participants; at least 15 trials per condition)
# Correct Source versus Miss (38 participants; at least 15 trials per condition)
# *NOTE: ADD filter to exclude participants with too many scrubbed frames?? *

# %%
# Path to directory with participant lists
data_file = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Participants/Splitting/Sub_list.tsv'
sub_data = pd.read_csv(data_file, sep = '\t')

# Exclude participants who failed QC
sub_data = sub_data[sub_data['QC_status']!= 'F']

## ADD filter to exclude participants with too many scrubbed frames?? ##

# Set minimal number of trials needed per subject to include them in analysis
num = 14

# Encoding vs Control, and Stimulus Category classifications
all_subs = sub_data['participant_id']
all_diagnosis = sub_data['cognitive_status']
print(all_subs)
print(len(all_subs))

# Hit versus Miss
hm_data = sub_data[sub_data['hits'] > num]
hm_data = hm_data[hm_data['miss'] > num]
hm_subs = hm_data['participant_id']
hm_diagnosis = hm_data['cognitive_status']
print(hm_subs)
print(len(hm_subs))

# Correct Source versus Wrong Source 
cw_data = sub_data[sub_data['correct_source'] > num]
cw_data = cw_data[cw_data['wrong_source'] > num]
cw_subs = cw_data['participant_id']
cw_diagnosis = cw_data['cognitive_status']
print(cw_subs)
print(len(cw_subs))

# Correct Source versus Miss
cmiss_data = sub_data[sub_data['correct_source'] > num]
cmiss_data = cmiss_data[cmiss_data['miss'] > num]
cmiss_subs = cmiss_data['participant_id']
cmiss_diagnosis = cmiss_data['cognitive_status']
print(cmiss_subs)
print(len(cmiss_subs))
# Out:
# 0      108391
# 1      120839
# 2      122922
# 3      127228
# 4      139593
# 6      147863
# 7      150649
# 8      164965
# 9      175295
# 10     178101
# 11     189005
# 12     197192
# 14     199801
# 15     219637
# 16     229301
# 17     247659
# 18     254402
# 19     255499
# 20     258618
# 21     258912
# 22     267168
# 23     270218
# 24     271596
# 27     314409
# 28     326073
# 29     336665
# 30     337021
# 31     350555
# 32     370092
# 34     385370
#         ...
# 70     763590
# 71     778749
# 72     783781
# 73     785217
# 74     785245
# 75     804743
# 77     845675
# 78     866812
# 79     878354
# 80     884343
# 81     886007
# 83     893978
# 85     901551
# 86     906145
# 87     914042
# 88     915022
# 89     920577
# 90     932933
# 91     936730
# 92     938001
# 93     955548
# 94     956049
# 95     956130
# 96     968913
# 97     974246
# 98     979001
# 99     983291
# 100    988602
# 101    996599
# 102    998166
# Name: participant_id, Length: 94, dtype: int64
# 94
# 0      108391
# 2      122922
# 4      139593
# 8      164965
# 14     199801
# 17     247659
# 19     255499
# 20     258618
# 21     258912
# 24     271596
# 27     314409
# 29     336665
# 30     337021
# 36     396250
# 37     403131
# 38     408506
# 39     413474
# 41     437101
# 42     439776
# 44     458807
# 45     459801
# 47     484204
# 49     502616
# 55     567214
# 56     597569
# 60     652850
# 65     677561
# 66     711830
# 67     729722
# 68     739694
# 69     748676
# 70     763590
# 71     778749
# 72     783781
# 80     884343
# 81     886007
# 89     920577
# 91     936730
# 95     956130
# 97     974246
# 99     983291
# 102    998166
# Name: participant_id, dtype: int64
# 42
# 0      108391
# 2      122922
# 4      139593
# 7      150649
# 9      175295
# 10     178101
# 12     197192
# 14     199801
# 16     229301
# 20     258618
# 22     267168
# 28     326073
# 29     336665
# 30     337021
# 31     350555
# 34     385370
# 38     408506
# 39     413474
# 40     427357
# 41     437101
# 44     458807
# 45     459801
# 46     462345
# 49     502616
# 53     549994
# 54     555537
# 55     567214
# 57     619278
# 60     652850
# 62     659068
# 64     668786
# 65     677561
# 66     711830
# 68     739694
# 69     748676
# 71     778749
# 72     783781
# 79     878354
# 80     884343
# 83     893978
# 85     901551
# 86     906145
# 88     915022
# 90     932933
# 91     936730
# 92     938001
# 93     955548
# 96     968913
# 101    996599
# Name: participant_id, dtype: int64
# 49
# 0      108391
# 2      122922
# 4      139593
# 8      164965
# 14     199801
# 17     247659
# 19     255499
# 20     258618
# 24     271596
# 27     314409
# 29     336665
# 30     337021
# 36     396250
# 37     403131
# 38     408506
# 39     413474
# 41     437101
# 42     439776
# 44     458807
# 45     459801
# 47     484204
# 49     502616
# 55     567214
# 56     597569
# 60     652850
# 65     677561
# 66     711830
# 67     729722
# 68     739694
# 69     748676
# 71     778749
# 72     783781
# 80     884343
# 81     886007
# 91     936730
# 95     956130
# 99     983291
# 102    998166
# Name: participant_id, dtype: int64
# 38

# %% [markdown]
# Step 2. Set up paths of directories of interest
#
# Create empty data structures to save and export classification results

# %%
# set paths to directories of interest
beta_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Nistats/Betas'
label_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Nistats/Events'
mask_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/masks'
output_dir = '/Users/mombot/Documents/Simexp/CIMAQ/Data/Nilearn/Group_results'

# %% [markdown]
# Step 3. ENCODING VERSUS CONTROL TASK CLASSIFICATION
#
# Build and test model for each participant on list, and compile data in a single pandas dataframe

# %%
# ENCODING VERSUS CONTROL TASK CLASSIFICATION

# build data structure to store accuracy data and coefficients
enc_ctl_data = pd.DataFrame()
enc_ctl_data.insert(loc = 0, column = 'dccid', value = 'None', allow_duplicates=True)
# enc_ctl_data.insert(loc = 1, column = 'diagnosis', value = 'None', allow_duplicates=True)
for i in range(0, 10):
    enc_ctl_data.insert(loc = enc_ctl_data.shape[1], column = 'CV'+str(i+1)+'_acc', value = NaN, allow_duplicates=True)
enc_ctl_data.insert(loc = enc_ctl_data.shape[1], column = 'TrainSet_MeanCV_acc', value = 'None', allow_duplicates=True)
enc_ctl_data.insert(loc = enc_ctl_data.shape[1], column = 'TestSet_acc', value = 'None', allow_duplicates=True)

for sub in all_subs:
    print(sub)
    sub_data = [sub]
    # load subject's beta maps (one per trial)
    betas = image.load_img(img=os.path.join(beta_dir, str(sub), 'TrialContrasts/betas_sub'+str(sub)+'*.nii'),
                           wildcards=True)
    # initialize NiftiMasker object    
    sub_mask = nb.load(os.path.join(mask_dir, 'func_sub'+str(sub)+'_mask_stereonl.nii'))
    sub_masker = NiftiMasker(mask_img=sub_mask, standardize=True)
    
    # transform subject's beta maps into vector of network means per trial
    X_enc_ctl = sub_masker.fit_transform(betas)

    # load subject's trial labels
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_enco_ctl.tsv')
    enco_ctl_labels = pd.read_csv(labels_file, sep='\t')
    y_enco_ctl = enco_ctl_labels['condition']
    
    # mask data to exclude trials of no interest
    # does not apply here
    
    # Split trials into a training and a test set
    X_train, X_test, y_train, y_test = train_test_split(
        X_enc_ctl, # x
        y_enco_ctl, # y
        test_size = 0.4, # 60%/40% split
        shuffle = True, # shuffle dataset before splitting
        stratify = y_enco_ctl, # keep distribution of conditions consistent betw. train & test sets
        #random_state = 123  # if set number, same shuffle each time, otherwise randomization algo
        ) 
    print('training:', len(X_train), 'testing:', len(X_test))
    print(y_train.value_counts(), y_test.value_counts())
    
    # define the model
    sub_svc = SVC(kernel='linear', class_weight='balanced')
    
    # do cross-validation to evaluate model performance
    # within 10 folds of training set
    # predict
    y_pred = cross_val_predict(sub_svc, X_train, y_train,
                               groups=y_train, cv=10)
    # scores
    cv_acc = cross_val_score(sub_svc, X_train, y_train,
                         groups=y_train, cv=10)
    print(cv_acc)
    
    for i in range(0, len(cv_acc)):
        sub_data.append(cv_acc[i])
        
    # evaluate overall model performance on training data
    overall_acc = accuracy_score(y_pred = y_pred, y_true = y_train)
    overall_cr = classification_report(y_pred = y_pred, y_true = y_train)
    print('Accuracy:',overall_acc)
    print(overall_cr)
    
    sub_data.append(overall_acc)

    # Test model on unseen data from the test set
    sub_svc.fit(X_train, y_train)
    y_pred = sub_svc.predict(X_test) # classify age class using testing data
    acc = sub_svc.score(X_test, y_test) # get accuracy

    cr = classification_report(y_pred=y_pred, y_true=y_test) # get prec., recall & f1
    # print results
    print('accuracy =', acc)
    print(cr)  
    
    sub_data.append(acc)
    
    # get map of coefficients    
    # coef_ = sub_svc.coef_
    # print(coef_.shape)
    #Return voxel weights into a nifti image using the NiftiMasker
    # coef_img = sub_masker.inverse_transform(coef_)
    #Save .nii to file
    # coef_img.to_filename(os.path.join(output_dir, 'Coef_maps', 'SVC_coeff_enc_ctl_sub-'+str(sub)+'.nii'))

    enc_ctl_data = enc_ctl_data.append(pd.Series(sub_data, index=enc_ctl_data.columns), ignore_index=True)

enc_ctl_data.to_csv(os.path.join(output_dir, 'SVC_withinSub_enc_ctl_wholeBrain.tsv'),
    sep='\t', header=True, index=False)
# Out:
# 108391
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         0.625      0.875      0.85714286 0.57142857 1.
#  0.85714286 0.66666667 1.         0.83333333]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.74      0.74      0.74        23
#          Enc       0.87      0.87      0.87        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.81      0.81      0.81        70
# weighted avg       0.83      0.83      0.83        70
#
# accuracy = 0.7659574468085106
#               precision    recall  f1-score   support
#
#          CTL       0.78      0.44      0.56        16
#          Enc       0.76      0.94      0.84        31
#
#    micro avg       0.77      0.77      0.77        47
#    macro avg       0.77      0.69      0.70        47
# weighted avg       0.77      0.77      0.75        47
#
# 120839
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.5        0.875      0.75       0.71428571 0.57142857 0.42857143
#  0.85714286 0.83333333 0.5        0.5       ]
# Accuracy: 0.6571428571428571
#               precision    recall  f1-score   support
#
#          CTL       0.47      0.35      0.40        23
#          Enc       0.72      0.81      0.76        47
#
#    micro avg       0.66      0.66      0.66        70
#    macro avg       0.59      0.58      0.58        70
# weighted avg       0.64      0.66      0.64        70
#
# accuracy = 0.723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.57      0.81      0.67        16
#          Enc       0.88      0.68      0.76        31
#
#    micro avg       0.72      0.72      0.72        47
#    macro avg       0.72      0.74      0.72        47
# weighted avg       0.77      0.72      0.73        47
#
# 122922
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.875      0.875      1.         0.57142857 0.85714286
#  0.85714286 0.83333333 1.         0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.83      0.65      0.73        23
#          Enc       0.85      0.94      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.84      0.79      0.81        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.8936170212765957
#               precision    recall  f1-score   support
#
#          CTL       0.92      0.75      0.83        16
#          Enc       0.88      0.97      0.92        31
#
#    micro avg       0.89      0.89      0.89        47
#    macro avg       0.90      0.86      0.88        47
# weighted avg       0.90      0.89      0.89        47
#
# 127228
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.625      0.75       0.625      1.         0.85714286 1.
#  0.85714286 1.         1.         0.66666667]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.92      0.52      0.67        23
#          Enc       0.81      0.98      0.88        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.87      0.75      0.78        70
# weighted avg       0.85      0.83      0.81        70
#
# accuracy = 0.7446808510638298
#               precision    recall  f1-score   support
#
#          CTL       0.62      0.62      0.62        16
#          Enc       0.81      0.81      0.81        31
#
#    micro avg       0.74      0.74      0.74        47
#    macro avg       0.72      0.72      0.72        47
# weighted avg       0.74      0.74      0.74        47
#
# 139593
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       1.         0.75       0.71428571 0.71428571 0.42857143
#  0.71428571 0.5        0.33333333 0.83333333]
# Accuracy: 0.6857142857142857
#               precision    recall  f1-score   support
#
#          CTL       0.52      0.48      0.50        23
#          Enc       0.76      0.79      0.77        47
#
#    micro avg       0.69      0.69      0.69        70
#    macro avg       0.64      0.63      0.64        70
# weighted avg       0.68      0.69      0.68        70
#
# accuracy = 0.6382978723404256
#               precision    recall  f1-score   support
#
#          CTL       0.46      0.38      0.41        16
#          Enc       0.71      0.77      0.74        31
#
#    micro avg       0.64      0.64      0.64        47
#    macro avg       0.58      0.57      0.58        47
# weighted avg       0.62      0.64      0.63        47
#
# 147863
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       1.         0.75       0.85714286 0.85714286 1.
#  0.71428571 0.83333333 1.         0.66666667]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.70      0.74        23
#          Enc       0.86      0.91      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.83      0.81      0.82        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.89      0.50      0.64        16
#          Enc       0.79      0.97      0.87        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.84      0.73      0.75        47
# weighted avg       0.82      0.81      0.79        47
#
# 150649
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         1.         1.         1.         0.71428571 0.85714286
#  0.85714286 0.66666667 0.66666667 0.5       ]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.75      0.78      0.77        23
#          Enc       0.89      0.87      0.88        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.82      0.83      0.82        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       1.00      0.62      0.77        16
#          Enc       0.84      1.00      0.91        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.92      0.81      0.84        47
# weighted avg       0.89      0.87      0.86        47
#
# 164965
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.625      0.875      0.875      0.71428571 1.         0.71428571
#  0.57142857 0.83333333 0.83333333 0.83333333]
# Accuracy: 0.7857142857142857
#               precision    recall  f1-score   support
#
#          CTL       0.70      0.61      0.65        23
#          Enc       0.82      0.87      0.85        47
#
#    micro avg       0.79      0.79      0.79        70
#    macro avg       0.76      0.74      0.75        70
# weighted avg       0.78      0.79      0.78        70
#
# accuracy = 0.7659574468085106
#               precision    recall  f1-score   support
#
#          CTL       0.86      0.38      0.52        16
#          Enc       0.75      0.97      0.85        31
#
#    micro avg       0.77      0.77      0.77        47
#    macro avg       0.80      0.67      0.68        47
# weighted avg       0.79      0.77      0.74        47
#
# 175295
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.875      0.85714286 1.         0.85714286
#  1.         0.66666667 0.66666667 0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.70      0.74        23
#          Enc       0.86      0.91      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.83      0.81      0.82        70
# weighted avg       0.84      0.84      0.84        70
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.76      0.81      0.79        16
#          Enc       0.90      0.87      0.89        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.83      0.84      0.84        47
# weighted avg       0.85      0.85      0.85        47
#
# 178101
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.875      0.42857143 0.71428571 0.85714286
#  0.85714286 1.         1.         0.83333333]
# Accuracy: 0.8
#               precision    recall  f1-score   support
#
#          CTL       0.74      0.61      0.67        23
#          Enc       0.82      0.89      0.86        47
#
#    micro avg       0.80      0.80      0.80        70
#    macro avg       0.78      0.75      0.76        70
# weighted avg       0.80      0.80      0.79        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.71      0.75      0.73        16
#          Enc       0.87      0.84      0.85        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.79      0.79      0.79        47
# weighted avg       0.81      0.81      0.81        47
#
# 189005
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.875      0.75       1.         0.85714286 0.71428571
#  1.         1.         0.83333333 0.66666667]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.70      0.74        23
#          Enc       0.86      0.91      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.83      0.81      0.82        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.9148936170212766
#               precision    recall  f1-score   support
#
#          CTL       1.00      0.75      0.86        16
#          Enc       0.89      1.00      0.94        31
#
#    micro avg       0.91      0.91      0.91        47
#    macro avg       0.94      0.88      0.90        47
# weighted avg       0.92      0.91      0.91        47
#
# 197192
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       1.         0.71428571 0.57142857 0.71428571
#  0.71428571 1.         0.5        0.83333333]
# Accuracy: 0.7714285714285715
#               precision    recall  f1-score   support
#
#          CTL       0.71      0.52      0.60        23
#          Enc       0.79      0.89      0.84        47
#
#    micro avg       0.77      0.77      0.77        70
#    macro avg       0.75      0.71      0.72        70
# weighted avg       0.76      0.77      0.76        70
#
# accuracy = 0.723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.67      0.38      0.48        16
#          Enc       0.74      0.90      0.81        31
#
#    micro avg       0.72      0.72      0.72        47
#    macro avg       0.70      0.64      0.65        47
# weighted avg       0.71      0.72      0.70        47
#
# 199801
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       1.         0.85714286 1.         0.85714286
#  0.85714286 1.         0.66666667 0.83333333]
# Accuracy: 0.8714285714285714
#               precision    recall  f1-score   support
#
#          CTL       0.89      0.70      0.78        23
#          Enc       0.87      0.96      0.91        47
#
#    micro avg       0.87      0.87      0.87        70
#    macro avg       0.88      0.83      0.84        70
# weighted avg       0.87      0.87      0.87        70
#
# accuracy = 0.7446808510638298
#               precision    recall  f1-score   support
#
#          CTL       0.64      0.56      0.60        16
#          Enc       0.79      0.84      0.81        31
#
#    micro avg       0.74      0.74      0.74        47
#    macro avg       0.72      0.70      0.71        47
# weighted avg       0.74      0.74      0.74        47
#
# 219637
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.625      0.57142857 0.71428571 1.
#  0.85714286 0.83333333 1.         0.83333333]
# Accuracy: 0.7857142857142857
#               precision    recall  f1-score   support
#
#          CTL       0.68      0.65      0.67        23
#          Enc       0.83      0.85      0.84        47
#
#    micro avg       0.79      0.79      0.79        70
#    macro avg       0.76      0.75      0.75        70
# weighted avg       0.78      0.79      0.78        70
#
# accuracy = 0.7021276595744681
#               precision    recall  f1-score   support
#
#          CTL       0.58      0.44      0.50        16
#          Enc       0.74      0.84      0.79        31
#
#    micro avg       0.70      0.70      0.70        47
#    macro avg       0.66      0.64      0.64        47
# weighted avg       0.69      0.70      0.69        47
#
# 229301
# training: 67 testing: 46
# Enc    44
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    15
# Name: condition, dtype: int64
# [0.75       0.625      0.75       0.71428571 1.         0.66666667
#  0.5        0.66666667 0.66666667 0.5       ]
# Accuracy: 0.6865671641791045
#               precision    recall  f1-score   support
#
#          CTL       0.55      0.48      0.51        23
#          Enc       0.74      0.80      0.77        44
#
#    micro avg       0.69      0.69      0.69        67
#    macro avg       0.65      0.64      0.64        67
# weighted avg       0.68      0.69      0.68        67
#
# accuracy = 0.782608695652174
#               precision    recall  f1-score   support
#
#          CTL       0.69      0.60      0.64        15
#          Enc       0.82      0.87      0.84        31
#
#    micro avg       0.78      0.78      0.78        46
#    macro avg       0.76      0.74      0.74        46
# weighted avg       0.78      0.78      0.78        46
#
# 247659
# training: 65 testing: 44
# Enc    42
# CTL    23
# Name: condition, dtype: int64 Enc    29
# CTL    15
# Name: condition, dtype: int64
# [0.625      0.75       1.         0.83333333 0.5        0.83333333
#  1.         0.66666667 0.66666667 0.33333333]
# Accuracy: 0.7230769230769231
#               precision    recall  f1-score   support
#
#          CTL       0.65      0.48      0.55        23
#          Enc       0.75      0.86      0.80        42
#
#    micro avg       0.72      0.72      0.72        65
#    macro avg       0.70      0.67      0.68        65
# weighted avg       0.71      0.72      0.71        65
#
# accuracy = 0.8636363636363636
#               precision    recall  f1-score   support
#
#          CTL       0.85      0.73      0.79        15
#          Enc       0.87      0.93      0.90        29
#
#    micro avg       0.86      0.86      0.86        44
#    macro avg       0.86      0.83      0.84        44
# weighted avg       0.86      0.86      0.86        44
#
# 254402
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      1.         1.         1.         0.85714286
#  1.         0.83333333 1.         0.83333333]
# Accuracy: 0.9285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.91      0.87      0.89        23
#          Enc       0.94      0.96      0.95        47
#
#    micro avg       0.93      0.93      0.93        70
#    macro avg       0.92      0.91      0.92        70
# weighted avg       0.93      0.93      0.93        70
#
# accuracy = 0.8936170212765957
#               precision    recall  f1-score   support
#
#          CTL       0.92      0.75      0.83        16
#          Enc       0.88      0.97      0.92        31
#
#    micro avg       0.89      0.89      0.89        47
#    macro avg       0.90      0.86      0.88        47
# weighted avg       0.90      0.89      0.89        47
#
# 255499
# training: 69 testing: 46
# Enc    46
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.25       0.375      0.75       0.57142857 0.85714286 0.57142857
#  0.83333333 0.5        0.66666667 0.5       ]
# Accuracy: 0.5797101449275363
#               precision    recall  f1-score   support
#
#          CTL       0.38      0.39      0.38        23
#          Enc       0.69      0.67      0.68        46
#
#    micro avg       0.58      0.58      0.58        69
#    macro avg       0.53      0.53      0.53        69
# weighted avg       0.58      0.58      0.58        69
# accuracy = 0.6304347826086957
#               precision    recall  f1-score   support
#
#          CTL       0.46      0.38      0.41        16
#          Enc       0.70      0.77      0.73        30
#
#    micro avg       0.63      0.63      0.63        46
#    macro avg       0.58      0.57      0.57        46
# weighted avg       0.62      0.63      0.62        46
#
# 258618
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         1.         1.         0.85714286 0.71428571 0.85714286
#  1.         0.83333333 0.83333333 1.        ]
# Accuracy: 0.9142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.90      0.83      0.86        23
#          Enc       0.92      0.96      0.94        47
#
#    micro avg       0.91      0.91      0.91        70
#    macro avg       0.91      0.89      0.90        70
# weighted avg       0.91      0.91      0.91        70
#
# accuracy = 0.9574468085106383
#               precision    recall  f1-score   support
#
#          CTL       1.00      0.88      0.93        16
#          Enc       0.94      1.00      0.97        31
#
#    micro avg       0.96      0.96      0.96        47
#    macro avg       0.97      0.94      0.95        47
# weighted avg       0.96      0.96      0.96        47
#
# 258912
# training: 67 testing: 46
# Enc    44
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.5        0.5        0.75       0.71428571 1.         0.66666667
#  0.83333333 0.83333333 0.66666667 0.83333333]
# Accuracy: 0.7164179104477612
#               precision    recall  f1-score   support
#
#          CTL       0.61      0.48      0.54        23
#          Enc       0.76      0.84      0.80        44
#
#    micro avg       0.72      0.72      0.72        67
#    macro avg       0.68      0.66      0.67        67
# weighted avg       0.71      0.72      0.71        67
#
# accuracy = 0.6521739130434783
#               precision    recall  f1-score   support
#
#          CTL       0.50      0.62      0.56        16
#          Enc       0.77      0.67      0.71        30
#
#    micro avg       0.65      0.65      0.65        46
#    macro avg       0.63      0.65      0.63        46
# weighted avg       0.68      0.65      0.66        46
#
# 267168
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.625      0.75       1.         0.85714286 1.         0.42857143
#  0.71428571 0.5        0.83333333 1.        ]
# Accuracy: 0.7714285714285715
#               precision    recall  f1-score   support
#
#          CTL       0.64      0.70      0.67        23
#          Enc       0.84      0.81      0.83        47
#
#    micro avg       0.77      0.77      0.77        70
#    macro avg       0.74      0.75      0.75        70
# weighted avg       0.78      0.77      0.77        70
#
# accuracy = 0.8297872340425532
#               precision    recall  f1-score   support
#
#          CTL       0.75      0.75      0.75        16
#          Enc       0.87      0.87      0.87        31
#
#    micro avg       0.83      0.83      0.83        47
#    macro avg       0.81      0.81      0.81        47
# weighted avg       0.83      0.83      0.83        47
#
# 270218
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.875      0.875      0.85714286 0.85714286 1.
#  0.71428571 1.         0.83333333 1.        ]
# Accuracy: 0.8714285714285714
#               precision    recall  f1-score   support
#
#          CTL       0.94      0.65      0.77        23
#          Enc       0.85      0.98      0.91        47
#
#    micro avg       0.87      0.87      0.87        70
#    macro avg       0.89      0.82      0.84        70
# weighted avg       0.88      0.87      0.86        70
#
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.85      0.69      0.76        16
#          Enc       0.85      0.94      0.89        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.85      0.81      0.83        47
# weighted avg       0.85      0.85      0.85        47
#
# 271596
# training: 67 testing: 46
# Enc    44
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.75       1.         1.         0.71428571 1.         1.
#  0.83333333 0.83333333 1.         0.83333333]
# Accuracy: 0.8955223880597015
#               precision    recall  f1-score   support
#
#          CTL       0.90      0.78      0.84        23
#          Enc       0.89      0.95      0.92        44
#
#    micro avg       0.90      0.90      0.90        67
#    macro avg       0.90      0.87      0.88        67
# weighted avg       0.90      0.90      0.89        67
#
# accuracy = 0.9130434782608695
#               precision    recall  f1-score   support
#
#          CTL       0.93      0.81      0.87        16
#          Enc       0.91      0.97      0.94        30
#
#    micro avg       0.91      0.91      0.91        46
#    macro avg       0.92      0.89      0.90        46
# weighted avg       0.91      0.91      0.91        46
#
# 314409
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         0.875      0.75       0.71428571 0.85714286 0.85714286
#  1.         1.         0.66666667 0.66666667]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.83      0.65      0.73        23
#          Enc       0.85      0.94      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.84      0.79      0.81        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.75      0.77        16
#          Enc       0.88      0.90      0.89        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.84      0.83      0.83        47
# weighted avg       0.85      0.85      0.85        47
#
# 326073
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.875      0.71428571 0.85714286 0.71428571
#  1.         1.         0.83333333 0.83333333]
# Accuracy: 0.8571428571428571
#               precision    recall  f1-score   support
#
#          CTL       0.81      0.74      0.77        23
#          Enc       0.88      0.91      0.90        47
#
#    micro avg       0.86      0.86      0.86        70
#    macro avg       0.84      0.83      0.83        70
# weighted avg       0.86      0.86      0.86        70
#
# accuracy = 0.7872340425531915
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.50      0.62        16
#          Enc       0.78      0.94      0.85        31
#
#    micro avg       0.79      0.79      0.79        47
#    macro avg       0.79      0.72      0.73        47
# weighted avg       0.79      0.79      0.77        47
#
# 336665
# training: 67 testing: 46
# Enc    44
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    15
# Name: condition, dtype: int64
# [0.875      0.875      0.5        1.         1.         0.83333333
#  0.83333333 0.66666667 0.83333333 0.83333333]
# Accuracy: 0.8208955223880597
#               precision    recall  f1-score   support
#
#          CTL       0.76      0.70      0.73        23
#          Enc       0.85      0.89      0.87        44
#
#    micro avg       0.82      0.82      0.82        67
#    macro avg       0.80      0.79      0.80        67
# weighted avg       0.82      0.82      0.82        67
#
# accuracy = 0.8695652173913043
#               precision    recall  f1-score   support
#
#          CTL       0.91      0.67      0.77        15
#          Enc       0.86      0.97      0.91        31
#
#    micro avg       0.87      0.87      0.87        46
#    macro avg       0.88      0.82      0.84        46
# weighted avg       0.87      0.87      0.86        46
#
# 337021
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.875      0.71428571 1.         1.
#  1.         0.83333333 1.         0.66666667]
# Accuracy: 0.8714285714285714
#               precision    recall  f1-score   support
#
#          CTL       0.82      0.78      0.80        23
#          Enc       0.90      0.91      0.91        47
#
#    micro avg       0.87      0.87      0.87        70
#    macro avg       0.86      0.85      0.85        70
# weighted avg       0.87      0.87      0.87        70
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.86      0.75      0.80        16
#          Enc       0.88      0.94      0.91        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.87      0.84      0.85        47
# weighted avg       0.87      0.87      0.87        47
#
# 350555
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.875      0.85714286 0.71428571 0.85714286
#  0.71428571 1.         0.83333333 1.        ]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.76      0.70      0.73        23
#          Enc       0.86      0.89      0.88        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.81      0.79      0.80        70
# weighted avg       0.83      0.83      0.83        70
#
# accuracy = 0.8297872340425532
#               precision    recall  f1-score   support
#
#          CTL       0.79      0.69      0.73        16
#          Enc       0.85      0.90      0.88        31
#
#    micro avg       0.83      0.83      0.83        47
#    macro avg       0.82      0.80      0.80        47
# weighted avg       0.83      0.83      0.83        47
#
# 370092
# training: 67 testing: 46
# Enc    44
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [1.         1.         1.         0.85714286 1.         0.83333333
#  1.         0.83333333 0.83333333 1.        ]
# Accuracy: 0.9402985074626866
#               precision    recall  f1-score   support
#
#          CTL       0.95      0.87      0.91        23
#          Enc       0.93      0.98      0.96        44
#
#    micro avg       0.94      0.94      0.94        67
#    macro avg       0.94      0.92      0.93        67
# weighted avg       0.94      0.94      0.94        67
#
# accuracy = 0.9565217391304348
#               precision    recall  f1-score   support
#
#          CTL       0.94      0.94      0.94        16
#          Enc       0.97      0.97      0.97        30
#
#    micro avg       0.96      0.96      0.96        46
#    macro avg       0.95      0.95      0.95        46
# weighted avg       0.96      0.96      0.96        46
#
# 385370
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.625      0.875      0.71428571 1.         1.
#  0.85714286 0.5        1.         0.83333333]
# Accuracy: 0.8142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.78      0.61      0.68        23
#          Enc       0.83      0.91      0.87        47
#
#    micro avg       0.81      0.81      0.81        70
#    macro avg       0.80      0.76      0.78        70
# weighted avg       0.81      0.81      0.81        70
#
# accuracy = 0.9361702127659575
#               precision    recall  f1-score   support
#
#          CTL       0.88      0.94      0.91        16
#          Enc       0.97      0.94      0.95        31
#
#    micro avg       0.94      0.94      0.94        47
#    macro avg       0.92      0.94      0.93        47
# weighted avg       0.94      0.94      0.94        47
#
# 386333
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.5        0.875      0.85714286 0.85714286 1.
#  0.85714286 0.83333333 0.83333333 0.83333333]
# Accuracy: 0.8142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.78      0.61      0.68        23
#          Enc       0.83      0.91      0.87        47
#
#    micro avg       0.81      0.81      0.81        70
#    macro avg       0.80      0.76      0.78        70
# weighted avg       0.81      0.81      0.81        70
#
# accuracy = 0.7021276595744681
#               precision    recall  f1-score   support
#
#          CTL       0.58      0.44      0.50        16
#          Enc       0.74      0.84      0.79        31
#
#    micro avg       0.70      0.70      0.70        47
#    macro avg       0.66      0.64      0.64        47
# weighted avg       0.69      0.70      0.69        47
#
# 396250
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.625      0.875      0.875      0.57142857 0.71428571 0.71428571
#  0.71428571 0.66666667 0.66666667 1.        ]
# Accuracy: 0.7428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.60      0.65      0.63        23
#          Enc       0.82      0.79      0.80        47
#
#    micro avg       0.74      0.74      0.74        70
#    macro avg       0.71      0.72      0.71        70
# weighted avg       0.75      0.74      0.75        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.77      0.62      0.69        16
#          Enc       0.82      0.90      0.86        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.80      0.76      0.78        47
# weighted avg       0.81      0.81      0.80        47
#
# 403131
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.375      0.625      0.5        0.85714286 0.71428571 0.85714286
#  1.         0.83333333 0.66666667 0.83333333]
# Accuracy: 0.7142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.57      0.57      0.57        23
#          Enc       0.79      0.79      0.79        47
#
#    micro avg       0.71      0.71      0.71        70
#    macro avg       0.68      0.68      0.68        70
# weighted avg       0.71      0.71      0.71        70
#
# accuracy = 0.5957446808510638
#               precision    recall  f1-score   support
#
#          CTL       0.38      0.31      0.34        16
#          Enc       0.68      0.74      0.71        31
#
#    micro avg       0.60      0.60      0.60        47
#    macro avg       0.53      0.53      0.53        47
# weighted avg       0.58      0.60      0.58        47
#
# 408506
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.75       0.42857143 0.57142857 0.85714286
#  0.57142857 0.5        1.         1.        ]
# Accuracy: 0.7428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.62      0.57      0.59        23
#          Enc       0.80      0.83      0.81        47
#
#    micro avg       0.74      0.74      0.74        70
#    macro avg       0.71      0.70      0.70        70
# weighted avg       0.74      0.74      0.74        70
#
# accuracy = 0.7021276595744681
#               precision    recall  f1-score   support
#
#          CTL       0.58      0.44      0.50        16
#          Enc       0.74      0.84      0.79        31
#
#    micro avg       0.70      0.70      0.70        47
#    macro avg       0.66      0.64      0.64        47
# weighted avg       0.69      0.70      0.69        47
#
# 413474
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.875      1.         0.85714286 0.85714286
#  0.85714286 1.         0.5        0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.77      0.74      0.76        23
#          Enc       0.88      0.89      0.88        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.82      0.82      0.82        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.8297872340425532
#               precision    recall  f1-score   support
#
#          CTL       0.75      0.75      0.75        16
#          Enc       0.87      0.87      0.87        31
#
#    micro avg       0.83      0.83      0.83        47
#    macro avg       0.81      0.81      0.81        47
# weighted avg       0.83      0.83      0.83        47
#
# 427357
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         0.75       0.625      0.71428571 1.         0.85714286
#  1.         0.66666667 0.5        0.5       ]
# Accuracy: 0.7714285714285715
#               precision    recall  f1-score   support
#
#          CTL       0.68      0.57      0.62        23
#          Enc       0.80      0.87      0.84        47
#
#    micro avg       0.77      0.77      0.77        70
#    macro avg       0.74      0.72      0.73        70
# weighted avg       0.76      0.77      0.77        70
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.81      0.81      0.81        16
#          Enc       0.90      0.90      0.90        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.86      0.86      0.86        47
# weighted avg       0.87      0.87      0.87        47
#
# 437101
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.75       1.         0.57142857 0.71428571
#  0.85714286 0.66666667 0.66666667 0.83333333]
# Accuracy: 0.7714285714285715
#               precision    recall  f1-score   support
#
#          CTL       0.71      0.52      0.60        23
#          Enc       0.79      0.89      0.84        47
#
#    micro avg       0.77      0.77      0.77        70
#    macro avg       0.75      0.71      0.72        70
# weighted avg       0.76      0.77      0.76        70
#
# accuracy = 0.8936170212765957
#               precision    recall  f1-score   support
#
#          CTL       0.92      0.75      0.83        16
#          Enc       0.88      0.97      0.92        31
#
#    micro avg       0.89      0.89      0.89        47
#    macro avg       0.90      0.86      0.88        47
# weighted avg       0.90      0.89      0.89        47
#
# 439776
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.875      0.85714286 0.57142857 0.71428571
#  0.57142857 0.83333333 1.         1.        ]
# Accuracy: 0.8
#               precision    recall  f1-score   support
#
#          CTL       0.74      0.61      0.67        23
#          Enc       0.82      0.89      0.86        47
#
#    micro avg       0.80      0.80      0.80        70
#    macro avg       0.78      0.75      0.76        70
# weighted avg       0.80      0.80      0.79        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.77      0.62      0.69        16
#          Enc       0.82      0.90      0.86        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.80      0.76      0.78        47
# weighted avg       0.81      0.81      0.80        47
#
# 441008
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       1.         0.875      1.         0.71428571 0.85714286
#  1.         0.66666667 0.66666667 0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.83      0.65      0.73        23
#          Enc       0.85      0.94      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.84      0.79      0.81        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.6808510638297872
#               precision    recall  f1-score   support
#
#          CTL       0.56      0.31      0.40        16
#          Enc       0.71      0.87      0.78        31
#
#    micro avg       0.68      0.68      0.68        47
#    macro avg       0.63      0.59      0.59        47
# weighted avg       0.66      0.68      0.65        47
#
# 458807
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.625      0.75       0.71428571 0.71428571 0.85714286
#  0.85714286 1.         0.5        0.83333333]
# Accuracy: 0.7714285714285715
#               precision    recall  f1-score   support
#
#          CTL       0.71      0.52      0.60        23
#          Enc       0.79      0.89      0.84        47
#
#    micro avg       0.77      0.77      0.77        70
#    macro avg       0.75      0.71      0.72        70
# weighted avg       0.76      0.77      0.76        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.73      0.69      0.71        16
#          Enc       0.84      0.87      0.86        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.79      0.78      0.78        47
# weighted avg       0.81      0.81      0.81        47
#
# 459801
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.75       0.71428571 0.71428571 0.71428571
#  0.42857143 0.66666667 0.66666667 0.66666667]
# Accuracy: 0.6857142857142857
#               precision    recall  f1-score   support
#
#          CTL       0.53      0.43      0.48        23
#          Enc       0.75      0.81      0.78        47
#
#    micro avg       0.69      0.69      0.69        70
#    macro avg       0.64      0.62      0.63        70
# weighted avg       0.67      0.69      0.68        70
#
# accuracy = 0.6382978723404256
#               precision    recall  f1-score   support
#
#          CTL       0.47      0.50      0.48        16
#          Enc       0.73      0.71      0.72        31
#
#    micro avg       0.64      0.64      0.64        47
#    macro avg       0.60      0.60      0.60        47
# weighted avg       0.64      0.64      0.64        47
#
# 462345
# training: 69 testing: 46
# Enc    46
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.875      0.875      0.85714286 0.71428571 0.85714286
#  0.83333333 0.66666667 1.         0.66666667]
# Accuracy: 0.8115942028985508
#               precision    recall  f1-score   support
#
#          CTL       0.73      0.70      0.71        23
#          Enc       0.85      0.87      0.86        46
#
#    micro avg       0.81      0.81      0.81        69
#    macro avg       0.79      0.78      0.79        69
# weighted avg       0.81      0.81      0.81        69
#
# accuracy = 0.8478260869565217
#               precision    recall  f1-score   support
#
#          CTL       0.91      0.62      0.74        16
#          Enc       0.83      0.97      0.89        30
#
#    micro avg       0.85      0.85      0.85        46
#    macro avg       0.87      0.80      0.82        46
# weighted avg       0.86      0.85      0.84        46
#
# 484204
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       1.         1.         1.         1.
#  0.85714286 1.         0.5        0.83333333]
# Accuracy: 0.8714285714285714
#               precision    recall  f1-score   support
#
#          CTL       0.85      0.74      0.79        23
#          Enc       0.88      0.94      0.91        47
#
#    micro avg       0.87      0.87      0.87        70
#    macro avg       0.86      0.84      0.85        70
# weighted avg       0.87      0.87      0.87        70
#
# accuracy = 0.9361702127659575
#               precision    recall  f1-score   support
#
#          CTL       0.88      0.94      0.91        16
#          Enc       0.97      0.94      0.95        31
#
#    micro avg       0.94      0.94      0.94        47
#    macro avg       0.92      0.94      0.93        47
# weighted avg       0.94      0.94      0.94        47
#
# 490035
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.75       1.         0.57142857 1.
#  1.         0.83333333 0.83333333 1.        ]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.70      0.74        23
#          Enc       0.86      0.91      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.83      0.81      0.82        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.85      0.69      0.76        16
#          Enc       0.85      0.94      0.89        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.85      0.81      0.83        47
# weighted avg       0.85      0.85      0.85        47
#
# 502616
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.875      0.85714286 0.85714286 0.85714286
#  0.85714286 0.66666667 1.         0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.88      0.61      0.72        23
#          Enc       0.83      0.96      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.85      0.78      0.80        70
# weighted avg       0.85      0.84      0.83        70
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.81      0.81      0.81        16
#          Enc       0.90      0.90      0.90        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.86      0.86      0.86        47
# weighted avg       0.87      0.87      0.87        47
#
# 517070
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.75       0.85714286 0.85714286 0.85714286
#  0.57142857 0.83333333 0.66666667 1.        ]
# Accuracy: 0.7857142857142857
#               precision    recall  f1-score   support
#
#          CTL       0.72      0.57      0.63        23
#          Enc       0.81      0.89      0.85        47
#
#    micro avg       0.79      0.79      0.79        70
#    macro avg       0.76      0.73      0.74        70
# weighted avg       0.78      0.79      0.78        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.82      0.56      0.67        16
#          Enc       0.81      0.94      0.87        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.81      0.75      0.77        47
# weighted avg       0.81      0.81      0.80        47
#
# 520377
# training: 69 testing: 46
# Enc    46
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.5        0.5        0.75       0.85714286 0.85714286 0.71428571
#  0.33333333 0.83333333 0.83333333 0.83333333]
# Accuracy: 0.6956521739130435
#               precision    recall  f1-score   support
#
#          CTL       0.55      0.48      0.51        23
#          Enc       0.76      0.80      0.78        46
#
#    micro avg       0.70      0.70      0.70        69
#    macro avg       0.65      0.64      0.65        69
# weighted avg       0.69      0.70      0.69        69
#
# accuracy = 0.7608695652173914
#               precision    recall  f1-score   support
#
#          CTL       0.78      0.44      0.56        16
#          Enc       0.76      0.93      0.84        30
#
#    micro avg       0.76      0.76      0.76        46
#    macro avg       0.77      0.69      0.70        46
# weighted avg       0.76      0.76      0.74        46
#
# 543589
# training: 69 testing: 46
# Enc    46
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.75       0.75       1.         0.85714286 0.85714286
#  0.83333333 0.66666667 1.         1.        ]
# Accuracy: 0.855072463768116
#               precision    recall  f1-score   support
#
#          CTL       0.81      0.74      0.77        23
#          Enc       0.88      0.91      0.89        46
#
#    micro avg       0.86      0.86      0.86        69
#    macro avg       0.84      0.83      0.83        69
# weighted avg       0.85      0.86      0.85        69
#
# accuracy = 0.7608695652173914
#               precision    recall  f1-score   support
#
#          CTL       0.67      0.62      0.65        16
#          Enc       0.81      0.83      0.82        30
#
#    micro avg       0.76      0.76      0.76        46
#    macro avg       0.74      0.73      0.73        46
# weighted avg       0.76      0.76      0.76        46
#
# 549994
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      1.         1.         1.         0.85714286 0.85714286
#  0.85714286 1.         1.         0.66666667]
# Accuracy: 0.9142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.87      0.87      0.87        23
#          Enc       0.94      0.94      0.94        47
#
#    micro avg       0.91      0.91      0.91        70
#    macro avg       0.90      0.90      0.90        70
# weighted avg       0.91      0.91      0.91        70
#
# accuracy = 0.8936170212765957
#               precision    recall  f1-score   support
#
#          CTL       1.00      0.69      0.81        16
#          Enc       0.86      1.00      0.93        31
#
#    micro avg       0.89      0.89      0.89        47
#    macro avg       0.93      0.84      0.87        47
# weighted avg       0.91      0.89      0.89        47
#
# 555537
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       1.         0.875      1.         1.         1.
#  0.85714286 0.66666667 1.         1.        ]
# Accuracy: 0.9142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.90      0.83      0.86        23
#          Enc       0.92      0.96      0.94        47
#
#    micro avg       0.91      0.91      0.91        70
#    macro avg       0.91      0.89      0.90        70
# weighted avg       0.91      0.91      0.91        70
#
# accuracy = 0.9574468085106383
#               precision    recall  f1-score   support
#
#          CTL       0.89      1.00      0.94        16
#          Enc       1.00      0.94      0.97        31
#
#    micro avg       0.96      0.96      0.96        47
#    macro avg       0.94      0.97      0.95        47
# weighted avg       0.96      0.96      0.96        47
#
# 567214
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.625      0.5        1.         0.42857143 0.71428571 0.57142857
# ...
#  1.         0.66666667 0.83333333 0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.75      0.78      0.77        23
#          Enc       0.89      0.87      0.88        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.82      0.83      0.82        70
# weighted avg       0.84      0.84      0.84        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.71      0.75      0.73        16
#          Enc       0.87      0.84      0.85        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.79      0.79      0.79        47
# weighted avg       0.81      0.81      0.81        47
#
# 914042
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.875      0.71428571 1.         0.57142857
#  0.71428571 1.         0.83333333 0.83333333]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.74      0.74      0.74        23
#          Enc       0.87      0.87      0.87        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.81      0.81      0.81        70
# weighted avg       0.83      0.83      0.83        70
#
# accuracy = 0.8936170212765957
#               precision    recall  f1-score   support
#
#          CTL       0.87      0.81      0.84        16
#          Enc       0.91      0.94      0.92        31
#
#    micro avg       0.89      0.89      0.89        47
#    macro avg       0.89      0.87      0.88        47
# weighted avg       0.89      0.89      0.89        47
#
# 915022
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.625      1.         1.         0.71428571 0.85714286
#  1.         0.83333333 0.83333333 0.66666667]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.76      0.70      0.73        23
#          Enc       0.86      0.89      0.88        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.81      0.79      0.80        70
# weighted avg       0.83      0.83      0.83        70
#
# accuracy = 0.7659574468085106
#               precision    recall  f1-score   support
#
#          CTL       0.73      0.50      0.59        16
#          Enc       0.78      0.90      0.84        31
#
#    micro avg       0.77      0.77      0.77        47
#    macro avg       0.75      0.70      0.71        47
# weighted avg       0.76      0.77      0.75        47
#
# 920577
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.75       0.85714286 0.71428571 0.85714286
#  0.85714286 0.66666667 1.         0.83333333]
# Accuracy: 0.8
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.52      0.63        23
#          Enc       0.80      0.94      0.86        47
#
#    micro avg       0.80      0.80      0.80        70
#    macro avg       0.80      0.73      0.75        70
# weighted avg       0.80      0.80      0.79        70
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.86      0.75      0.80        16
#          Enc       0.88      0.94      0.91        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.87      0.84      0.85        47
# weighted avg       0.87      0.87      0.87        47
#
# 932933
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.75       0.875      0.85714286 1.         0.85714286
#  0.71428571 0.5        0.83333333 0.66666667]
# Accuracy: 0.7857142857142857
#               precision    recall  f1-score   support
#
#          CTL       0.70      0.61      0.65        23
#          Enc       0.82      0.87      0.85        47
#
#    micro avg       0.79      0.79      0.79        70
#    macro avg       0.76      0.74      0.75        70
# weighted avg       0.78      0.79      0.78        70
#
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.91      0.62      0.74        16
#          Enc       0.83      0.97      0.90        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.87      0.80      0.82        47
# weighted avg       0.86      0.85      0.84        47
#
# 936730
# training: 69 testing: 46
# Enc    46
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.875      1.         0.625      1.         1.         0.85714286
#  1.         1.         1.         1.        ]
# Accuracy: 0.927536231884058
#               precision    recall  f1-score   support
#
#          CTL       0.91      0.87      0.89        23
#          Enc       0.94      0.96      0.95        46
#
#    micro avg       0.93      0.93      0.93        69
#    macro avg       0.92      0.91      0.92        69
# weighted avg       0.93      0.93      0.93        69
#
# accuracy = 0.9130434782608695
#               precision    recall  f1-score   support
#
#          CTL       0.88      0.88      0.88        16
#          Enc       0.93      0.93      0.93        30
#
#    micro avg       0.91      0.91      0.91        46
#    macro avg       0.90      0.90      0.90        46
# weighted avg       0.91      0.91      0.91        46
#
# 938001
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.5        0.875      0.625      0.57142857 0.57142857 1.
#  0.85714286 1.         0.66666667 0.83333333]
# Accuracy: 0.7428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.62      0.57      0.59        23
#          Enc       0.80      0.83      0.81        47
#
#    micro avg       0.74      0.74      0.74        70
#    macro avg       0.71      0.70      0.70        70
# weighted avg       0.74      0.74      0.74        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.82      0.56      0.67        16
#          Enc       0.81      0.94      0.87        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.81      0.75      0.77        47
# weighted avg       0.81      0.81      0.80        47
#
# 955548
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.875      1.         1.         0.85714286
#  0.71428571 1.         0.66666667 0.66666667]
# Accuracy: 0.8571428571428571
#               precision    recall  f1-score   support
#
#          CTL       0.81      0.74      0.77        23
#          Enc       0.88      0.91      0.90        47
#
#    micro avg       0.86      0.86      0.86        70
#    macro avg       0.84      0.83      0.83        70
# weighted avg       0.86      0.86      0.86        70
#
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.91      0.62      0.74        16
#          Enc       0.83      0.97      0.90        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.87      0.80      0.82        47
# weighted avg       0.86      0.85      0.84        47
#
# 956049
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.75       1.         1.         0.71428571
#  1.         0.83333333 0.83333333 0.66666667]
# Accuracy: 0.8571428571428571
#               precision    recall  f1-score   support
#
#          CTL       0.88      0.65      0.75        23
#          Enc       0.85      0.96      0.90        47
#
#    micro avg       0.86      0.86      0.86        70
#    macro avg       0.87      0.80      0.82        70
# weighted avg       0.86      0.86      0.85        70
#
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.75      0.77        16
#          Enc       0.88      0.90      0.89        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.84      0.83      0.83        47
# weighted avg       0.85      0.85      0.85        47
#
# 956130
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.625      0.75       0.875      0.71428571 0.85714286 0.42857143
#  1.         1.         1.         0.83333333]
# Accuracy: 0.8
#               precision    recall  f1-score   support
#
#          CTL       0.70      0.70      0.70        23
#          Enc       0.85      0.85      0.85        47
#
#    micro avg       0.80      0.80      0.80        70
#    macro avg       0.77      0.77      0.77        70
# weighted avg       0.80      0.80      0.80        70
#
# accuracy = 0.8936170212765957
#               precision    recall  f1-score   support
#
#          CTL       0.92      0.75      0.83        16
#          Enc       0.88      0.97      0.92        31
#
#    micro avg       0.89      0.89      0.89        47
#    macro avg       0.90      0.86      0.88        47
# weighted avg       0.90      0.89      0.89        47
#
# 968913
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       1.         0.875      0.85714286 0.85714286 0.85714286
#  1.         1.         1.         1.        ]
# Accuracy: 0.9142857142857143
#               precision    recall  f1-score   support
#
#          CTL       0.95      0.78      0.86        23
#          Enc       0.90      0.98      0.94        47
#
#    micro avg       0.91      0.91      0.91        70
#    macro avg       0.92      0.88      0.90        70
# weighted avg       0.92      0.91      0.91        70
#
# accuracy = 0.9574468085106383
#               precision    recall  f1-score   support
#
#          CTL       0.94      0.94      0.94        16
#          Enc       0.97      0.97      0.97        31
#
#    micro avg       0.96      0.96      0.96        47
#    macro avg       0.95      0.95      0.95        47
# weighted avg       0.96      0.96      0.96        47
#
# 974246
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         0.875      0.625      0.57142857 0.85714286 0.85714286
#  1.         0.83333333 0.66666667 0.66666667]
# Accuracy: 0.8
#               precision    recall  f1-score   support
#
#          CTL       0.85      0.48      0.61        23
#          Enc       0.79      0.96      0.87        47
#
#    micro avg       0.80      0.80      0.80        70
#    macro avg       0.82      0.72      0.74        70
# weighted avg       0.81      0.80      0.78        70
#
# accuracy = 0.8085106382978723
#               precision    recall  f1-score   support
#
#          CTL       0.73      0.69      0.71        16
#          Enc       0.84      0.87      0.86        31
#
#    micro avg       0.81      0.81      0.81        47
#    macro avg       0.79      0.78      0.78        47
# weighted avg       0.81      0.81      0.81        47
#
# 979001
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.75       0.875      0.5        0.85714286 0.85714286 1.
#  1.         0.83333333 1.         0.83333333]
# Accuracy: 0.8428571428571429
#               precision    recall  f1-score   support
#
#          CTL       0.80      0.70      0.74        23
#          Enc       0.86      0.91      0.89        47
#
#    micro avg       0.84      0.84      0.84        70
#    macro avg       0.83      0.81      0.82        70
# weighted avg       0.84      0.84      0.84        70
# accuracy = 0.851063829787234
#               precision    recall  f1-score   support
#
#          CTL       0.85      0.69      0.76        16
#          Enc       0.85      0.94      0.89        31
#
#    micro avg       0.85      0.85      0.85        47
#    macro avg       0.85      0.81      0.83        47
# weighted avg       0.85      0.85      0.85        47
#
# 983291
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.875      1.         1.         1.
#  0.85714286 0.83333333 0.66666667 1.        ]
# Accuracy: 0.9
#               precision    recall  f1-score   support
#
#          CTL       0.90      0.78      0.84        23
#          Enc       0.90      0.96      0.93        47
#
#    micro avg       0.90      0.90      0.90        70
#    macro avg       0.90      0.87      0.88        70
# weighted avg       0.90      0.90      0.90        70
#
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.78      0.88      0.82        16
#          Enc       0.93      0.87      0.90        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.85      0.87      0.86        47
# weighted avg       0.88      0.87      0.87        47
#
# 988602
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [1.         0.75       0.625      0.85714286 1.         0.71428571
#  0.71428571 1.         0.66666667 1.        ]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.74      0.74      0.74        23
#          Enc       0.87      0.87      0.87        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.81      0.81      0.81        70
# weighted avg       0.83      0.83      0.83        70
#
# accuracy = 0.9148936170212766
#               precision    recall  f1-score   support
#
#          CTL       0.88      0.88      0.88        16
#          Enc       0.94      0.94      0.94        31
#
#    micro avg       0.91      0.91      0.91        47
#    macro avg       0.91      0.91      0.91        47
# weighted avg       0.91      0.91      0.91        47
#
# 996599
# training: 70 testing: 47
# Enc    47
# CTL    23
# Name: condition, dtype: int64 Enc    31
# CTL    16
# Name: condition, dtype: int64
# [0.875      0.875      0.875      0.71428571 1.         0.85714286
#  1.         0.66666667 0.66666667 0.66666667]
# Accuracy: 0.8285714285714286
#               precision    recall  f1-score   support
#
#          CTL       0.82      0.61      0.70        23
#          Enc       0.83      0.94      0.88        47
#
#    micro avg       0.83      0.83      0.83        70
#    macro avg       0.83      0.77      0.79        70
# weighted avg       0.83      0.83      0.82        70
#
# accuracy = 0.8723404255319149
#               precision    recall  f1-score   support
#
#          CTL       0.86      0.75      0.80        16
#          Enc       0.88      0.94      0.91        31
#
#    micro avg       0.87      0.87      0.87        47
#    macro avg       0.87      0.84      0.85        47
# weighted avg       0.87      0.87      0.87        47
#
# 998166
# training: 67 testing: 46
# Enc    44
# CTL    23
# Name: condition, dtype: int64 Enc    30
# CTL    16
# Name: condition, dtype: int64
# [0.875 0.75  0.875 1.    1.    1.    1.    1.    1.    1.   ]
# Accuracy: 0.9402985074626866
#               precision    recall  f1-score   support
#
#          CTL       0.95      0.87      0.91        23
#          Enc       0.93      0.98      0.96        44
#
#    micro avg       0.94      0.94      0.94        67
#    macro avg       0.94      0.92      0.93        67
# weighted avg       0.94      0.94      0.94        67
#
# accuracy = 0.8695652173913043
#               precision    recall  f1-score   support
#
#          CTL       0.86      0.75      0.80        16
#          Enc       0.88      0.93      0.90        30
#
#    micro avg       0.87      0.87      0.87        46
#    macro avg       0.87      0.84      0.85        46
# weighted avg       0.87      0.87      0.87        46

# %%
# HIT VERSUS MISS TRIAL CLASSIFICATION

# build data structure to store accuracy data and coefficients
hit_miss_data = pd.DataFrame()
hit_miss_data.insert(loc = 0, column = 'dccid', value = 'None', allow_duplicates=True)
# hit_miss_data.insert(loc = 1, column = 'diagnosis', value = 'None', allow_duplicates=True)
for i in range(0, 7):
    hit_miss_data.insert(loc = hit_miss_data.shape[1], column = 'CV'+str(i+1)+'_acc', value = NaN, allow_duplicates=True)
hit_miss_data.insert(loc = hit_miss_data.shape[1], column = 'TrainSet_MeanCV_acc', value = 'None', allow_duplicates=True)
hit_miss_data.insert(loc = hit_miss_data.shape[1], column = 'TestSet_acc', value = 'None', allow_duplicates=True)

for sub in hm_subs:
    print(sub)
    sub_data = [sub]
    # load subject's beta maps (one per trial)
    betas = image.load_img(img=os.path.join(beta_dir, str(sub), 'TrialContrasts/betas_sub'+str(sub)+'*.nii'),
                           wildcards=True)
    # initialize NiftiLabelMasker object    
    sub_mask = nb.load(os.path.join(mask_dir, 'func_sub'+str(sub)+'_mask_stereonl.nii'))
    sub_masker = NiftiMasker(mask_img=sub_mask, standardize=True)
    # transform subject's beta maps into vector of network means per trial
    X_hit_miss_ctl = sub_masker.fit_transform(betas)   
    
    # load subject's trial labels
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_ctl_miss_hit.tsv')
    y_hit_miss_ctl = pd.read_csv(labels_file, sep='\t')
    y_hit_miss_ctl_labels = y_hit_miss_ctl['ctl_miss_hit']
    # mask X and y data to exclude trials of no interest
    hit_miss_mask = y_hit_miss_ctl_labels.isin(['hit', 'missed'])
    y_hit_miss = y_hit_miss_ctl_labels[hit_miss_mask]      
    X_hit_miss  = X_hit_miss_ctl[hit_miss_mask]
    
    # Split trials into a training and a test set
    X_train, X_test, y_train, y_test = train_test_split(
        X_hit_miss, # x
        y_hit_miss, # y
        test_size = 0.4, # 60%/40% split
        shuffle = True, # shuffle dataset before splitting
        stratify = y_hit_miss, # keep distribution of conditions consistent betw. train & test sets
        #random_state = 123  # if set number, same shuffle each time, otherwise randomization algo
        ) 
    print('training:', len(X_train), 'testing:', len(X_test))
    print(y_train.value_counts(), y_test.value_counts())
    
    # define the model
    sub_svc = SVC(kernel='linear', class_weight='balanced')
    
    # do cross-validation to evaluate model performance
    # within 10 folds of training set
    # predict
    y_pred = cross_val_predict(sub_svc, X_train, y_train,
                               groups=y_train, cv=7)
    # scores
    cv_acc = cross_val_score(sub_svc, X_train, y_train,
                         groups=y_train, cv=7)
    print(cv_acc)
    
    for i in range(0, len(cv_acc)):
        sub_data.append(cv_acc[i])
        
    # evaluate overall model performance on training data
    overall_acc = accuracy_score(y_pred = y_pred, y_true = y_train)
    overall_cr = classification_report(y_pred = y_pred, y_true = y_train)
    print('Accuracy:',overall_acc)
    print(overall_cr)
    
    sub_data.append(overall_acc)

    # Test model on unseen data from the test set
    sub_svc.fit(X_train, y_train)
    y_pred = sub_svc.predict(X_test) # classify age class using testing data
    acc = sub_svc.score(X_test, y_test) # get accuracy

    cr = classification_report(y_pred=y_pred, y_true=y_test) # get prec., recall & f1
    # print results
    print('accuracy =', acc)
    print(cr)  
    
    sub_data.append(acc)
    
    # get map of coefficients    
    # coef_ = sub_svc.coef_
    # print(coef_.shape)
    #Return voxel weights into a nifti image using the NiftiMasker
    # coef_img = sub_masker.inverse_transform(coef_)
    #Save .nii to file
    # coef_img.to_filename(os.path.join(output_dir, 'Coef_maps', 'SVC_coeff_hit_miss_sub-'+str(sub)+'.nii'))

    hit_miss_data = hit_miss_data.append(pd.Series(sub_data, index=hit_miss_data.columns), ignore_index=True)

hit_miss_data.to_csv(os.path.join(output_dir, 'SVC_withinSub_hit_miss_wholeBrain.tsv'),
    sep='\t', header=True, index=False)
# Out:
# 108391
# training: 46 testing: 32
# hit       37
# missed     9
# Name: ctl_miss_hit, dtype: int64 hit       26
# missed     6
# Name: ctl_miss_hit, dtype: int64
# [0.625      0.75       0.83333333 0.83333333 0.83333333 0.83333333
#  0.66666667]
# Accuracy: 0.7608695652173914
#               precision    recall  f1-score   support
#
#          hit       0.82      0.89      0.86        37
#       missed       0.33      0.22      0.27         9
#
#    micro avg       0.76      0.76      0.76        46
#    macro avg       0.58      0.56      0.56        46
# weighted avg       0.73      0.76      0.74        46
#
# accuracy = 0.6875
#               precision    recall  f1-score   support
#
#          hit       0.81      0.81      0.81        26
#       missed       0.17      0.17      0.17         6
#
#    micro avg       0.69      0.69      0.69        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.69      0.69      0.69        32
#
# 122922
# training: 46 testing: 32
# hit       32
# missed    14
# Name: ctl_miss_hit, dtype: int64 hit       23
# missed     9
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.57142857 0.71428571 0.85714286 0.66666667 0.5
#  0.66666667]
# Accuracy: 0.6521739130434783
#               precision    recall  f1-score   support
#
#          hit       0.71      0.84      0.77        32
#       missed       0.38      0.21      0.27        14
#
#    micro avg       0.65      0.65      0.65        46
#    macro avg       0.54      0.53      0.52        46
# weighted avg       0.61      0.65      0.62        46
#
# accuracy = 0.75
#               precision    recall  f1-score   support
#
#          hit       0.76      0.96      0.85        23
#       missed       0.67      0.22      0.33         9
#
#    micro avg       0.75      0.75      0.75        32
#    macro avg       0.71      0.59      0.59        32
# weighted avg       0.73      0.75      0.70        32
#
# 139593
# training: 46 testing: 32
# missed    24
# hit       22
# Name: ctl_miss_hit, dtype: int64 missed    17
# hit       15
# Name: ctl_miss_hit, dtype: int64
# [0.375      0.57142857 0.71428571 0.5        0.33333333 0.66666667
#  0.83333333]
# Accuracy: 0.5652173913043478
#               precision    recall  f1-score   support
#
#          hit       0.54      0.59      0.57        22
#       missed       0.59      0.54      0.57        24
#
#    micro avg       0.57      0.57      0.57        46
#    macro avg       0.57      0.57      0.57        46
# weighted avg       0.57      0.57      0.57        46
#
# accuracy = 0.4375
#               precision    recall  f1-score   support
#
#          hit       0.44      0.73      0.55        15
#       missed       0.43      0.18      0.25        17
#
#    micro avg       0.44      0.44      0.44        32
#    macro avg       0.43      0.45      0.40        32
# weighted avg       0.43      0.44      0.39        32
#
# 164965
# training: 46 testing: 32
# hit       31
# missed    15
# Name: ctl_miss_hit, dtype: int64 hit       22
# missed    10
# Name: ctl_miss_hit, dtype: int64
# [0.75       0.57142857 0.57142857 0.5        0.5        0.33333333
#  0.5       ]
# Accuracy: 0.5434782608695652
#               precision    recall  f1-score   support
#
#          hit       0.65      0.71      0.68        31
#       missed       0.25      0.20      0.22        15
#
#    micro avg       0.54      0.54      0.54        46
#    macro avg       0.45      0.45      0.45        46
# weighted avg       0.52      0.54      0.53        46
#
# accuracy = 0.625
#               precision    recall  f1-score   support
#
#          hit       0.71      0.77      0.74        22
#       missed       0.38      0.30      0.33        10
#
#    micro avg       0.62      0.62      0.62        32
#    macro avg       0.54      0.54      0.54        32
# weighted avg       0.60      0.62      0.61        32
#
# 199801
# training: 46 testing: 32
# hit       35
# missed    11
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.85714286 0.71428571 0.42857143 0.71428571 0.66666667 0.66666667
#  0.66666667]
# Accuracy: 0.6739130434782609
#               precision    recall  f1-score   support
#
#          hit       0.76      0.83      0.79        35
#       missed       0.25      0.18      0.21        11
#
#    micro avg       0.67      0.67      0.67        46
#    macro avg       0.51      0.51      0.50        46
# weighted avg       0.64      0.67      0.65        46
#
# accuracy = 0.71875
#               precision    recall  f1-score   support
#
#          hit       0.78      0.88      0.82        24
#       missed       0.40      0.25      0.31         8
#
#    micro avg       0.72      0.72      0.72        32
#    macro avg       0.59      0.56      0.57        32
# weighted avg       0.68      0.72      0.69        32
#
# 247659
# training: 42 testing: 29
# missed    25
# hit       17
# Name: ctl_miss_hit, dtype: int64 missed    17
# hit       12
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.28571429 0.42857143 0.33333333 0.6        0.6
#  0.8       ]
# Accuracy: 0.5
#               precision    recall  f1-score   support
#
#          hit       0.36      0.29      0.32        17
#       missed       0.57      0.64      0.60        25
#
#    micro avg       0.50      0.50      0.50        42
#    macro avg       0.46      0.47      0.46        42
# weighted avg       0.48      0.50      0.49        42
#
# accuracy = 0.5862068965517241
#               precision    recall  f1-score   support
#
#          hit       0.50      0.67      0.57        12
#       missed       0.69      0.53      0.60        17
#
#    micro avg       0.59      0.59      0.59        29
#    macro avg       0.60      0.60      0.59        29
# weighted avg       0.61      0.59      0.59        29
#
# 255499
# training: 45 testing: 31
# hit       29
# missed    16
# Name: ctl_miss_hit, dtype: int64 hit       20
# missed    11
# Name: ctl_miss_hit, dtype: int64
# [0.75       0.57142857 1.         0.66666667 0.66666667 0.83333333
#  1.        ]
# Accuracy: 0.7777777777777778
#               precision    recall  f1-score   support
#
#          hit       0.77      0.93      0.84        29
#       missed       0.80      0.50      0.62        16
#
#    micro avg       0.78      0.78      0.78        45
#    macro avg       0.79      0.72      0.73        45
# weighted avg       0.78      0.78      0.76        45
#
# accuracy = 0.45161290322580644
#               precision    recall  f1-score   support
#
#          hit       0.57      0.60      0.59        20
#       missed       0.20      0.18      0.19        11
#
#    micro avg       0.45      0.45      0.45        31
#    macro avg       0.39      0.39      0.39        31
# weighted avg       0.44      0.45      0.45        31
#
# 258618
# training: 46 testing: 32
# hit       30
# missed    16
# Name: ctl_miss_hit, dtype: int64 hit       21
# missed    11
# Name: ctl_miss_hit, dtype: int64
# [0.625      0.625      0.5        1.         0.83333333 0.66666667
#  1.        ]
# Accuracy: 0.7391304347826086
#               precision    recall  f1-score   support
#
#          hit       0.76      0.87      0.81        30
#       missed       0.67      0.50      0.57        16
#
#    micro avg       0.74      0.74      0.74        46
#    macro avg       0.72      0.68      0.69        46
# weighted avg       0.73      0.74      0.73        46
#
# accuracy = 0.40625
#               precision    recall  f1-score   support
#
#          hit       0.57      0.38      0.46        21
#       missed       0.28      0.45      0.34        11
#
#    micro avg       0.41      0.41      0.41        32
#    macro avg       0.42      0.42      0.40        32
# weighted avg       0.47      0.41      0.42        32
#
# 258912
# training: 44 testing: 30
# hit       35
# missed     9
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     6
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.57142857 0.66666667 0.83333333 0.83333333 0.83333333
#  0.83333333]
# Accuracy: 0.7272727272727273
#               precision    recall  f1-score   support
#
#          hit       0.85      0.80      0.82        35
#       missed       0.36      0.44      0.40         9
#
#    micro avg       0.73      0.73      0.73        44
#    macro avg       0.61      0.62      0.61        44
# weighted avg       0.75      0.73      0.74        44
#
# accuracy = 0.6333333333333333
#               precision    recall  f1-score   support
#
#          hit       0.76      0.79      0.78        24
#       missed       0.00      0.00      0.00         6
#
#    micro avg       0.63      0.63      0.63        30
#    macro avg       0.38      0.40      0.39        30
# weighted avg       0.61      0.63      0.62        30
#
# 271596
# training: 44 testing: 30
# hit       30
# missed    14
# Name: ctl_miss_hit, dtype: int64 hit       21
# missed     9
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.28571429 0.5        0.66666667 0.66666667 0.5
#  0.66666667]
# Accuracy: 0.5227272727272727
#               precision    recall  f1-score   support
#
#          hit       0.63      0.73      0.68        30
#       missed       0.11      0.07      0.09        14
#
#    micro avg       0.52      0.52      0.52        44
#    macro avg       0.37      0.40      0.38        44
# weighted avg       0.46      0.52      0.49        44
#
# accuracy = 0.5333333333333333
#               precision    recall  f1-score   support
#
#          hit       0.73      0.52      0.61        21
#       missed       0.33      0.56      0.42         9
#
#    micro avg       0.53      0.53      0.53        30
#    macro avg       0.53      0.54      0.51        30
# weighted avg       0.61      0.53      0.55        30
#
# 314409
# training: 46 testing: 32
# hit       27
# missed    19
# Name: ctl_miss_hit, dtype: int64 hit       18
# missed    14
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.57142857 0.71428571 0.14285714 0.71428571 0.5
#  0.8       ]
# Accuracy: 0.5652173913043478
#               precision    recall  f1-score   support
#
#          hit       0.63      0.63      0.63        27
#       missed       0.47      0.47      0.47        19
#
#    micro avg       0.57      0.57      0.57        46
#    macro avg       0.55      0.55      0.55        46
# weighted avg       0.57      0.57      0.57        46
#
# accuracy = 0.5
#               precision    recall  f1-score   support
#
#          hit       0.56      0.56      0.56        18
#       missed       0.43      0.43      0.43        14
#
#    micro avg       0.50      0.50      0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.50      0.50      0.50        32
#
# 336665
# training: 45 testing: 30
# hit       31
# missed    14
# Name: ctl_miss_hit, dtype: int64 hit       21
# missed     9
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.57142857 0.57142857 0.5        0.83333333 0.33333333
#  0.66666667]
# Accuracy: 0.6
#               precision    recall  f1-score   support
#
#          hit       0.70      0.74      0.72        31
#       missed       0.33      0.29      0.31        14
#
#    micro avg       0.60      0.60      0.60        45
#    macro avg       0.52      0.51      0.51        45
# weighted avg       0.58      0.60      0.59        45
#
# accuracy = 0.6666666666666666
#               precision    recall  f1-score   support
#
#          hit       0.76      0.76      0.76        21
#       missed       0.44      0.44      0.44         9
#
#    micro avg       0.67      0.67      0.67        30
#    macro avg       0.60      0.60      0.60        30
# weighted avg       0.67      0.67      0.67        30
#
# 337021
# training: 46 testing: 32
# hit       36
# missed    10
# Name: ctl_miss_hit, dtype: int64 hit       25
# missed     7
# Name: ctl_miss_hit, dtype: int64
# [0.75       0.28571429 0.71428571 0.83333333 0.83333333 0.83333333
#  0.83333333]
# Accuracy: 0.717391304347826
#               precision    recall  f1-score   support
#
#          hit       0.79      0.86      0.83        36
#       missed       0.29      0.20      0.24        10
#
#    micro avg       0.72      0.72      0.72        46
#    macro avg       0.54      0.53      0.53        46
# weighted avg       0.68      0.72      0.70        46
#
# accuracy = 0.78125
#               precision    recall  f1-score   support
#
#          hit       0.80      0.96      0.87        25
#       missed       0.50      0.14      0.22         7
#
#    micro avg       0.78      0.78      0.78        32
#    macro avg       0.65      0.55      0.55        32
# weighted avg       0.73      0.78      0.73        32
#
# 396250
# training: 46 testing: 32
# hit       25
# missed    21
# Name: ctl_miss_hit, dtype: int64 hit       18
# missed    14
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.42857143 0.42857143 0.42857143 0.5        0.33333333
#  0.66666667]
# Accuracy: 0.45652173913043476
#               precision    recall  f1-score   support
#
#          hit       0.50      0.52      0.51        25
#       missed       0.40      0.38      0.39        21
#
#    micro avg       0.46      0.46      0.46        46
#    macro avg       0.45      0.45      0.45        46
# weighted avg       0.45      0.46      0.46        46
#
# accuracy = 0.4375
#               precision    recall  f1-score   support
#
#          hit       0.50      0.61      0.55        18
#       missed       0.30      0.21      0.25        14
#
#    micro avg       0.44      0.44      0.44        32
#    macro avg       0.40      0.41      0.40        32
# weighted avg       0.41      0.44      0.42        32
#
# 403131
# training: 46 testing: 32
# hit       28
# missed    18
# Name: ctl_miss_hit, dtype: int64 hit       19
# missed    13
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.42857143 0.71428571 0.71428571 0.66666667 0.83333333
#  0.66666667]
# Accuracy: 0.6739130434782609
#               precision    recall  f1-score   support
#
#          hit       0.70      0.82      0.75        28
#       missed       0.62      0.44      0.52        18
#
#    micro avg       0.67      0.67      0.67        46
#    macro avg       0.66      0.63      0.64        46
# weighted avg       0.67      0.67      0.66        46
#
# accuracy = 0.59375
#               precision    recall  f1-score   support
#
#          hit       0.67      0.63      0.65        19
#       missed       0.50      0.54      0.52        13
#
#    micro avg       0.59      0.59      0.59        32
#    macro avg       0.58      0.59      0.58        32
# weighted avg       0.60      0.59      0.60        32
#
# 408506
# training: 46 testing: 32
# hit       30
# missed    16
# Name: ctl_miss_hit, dtype: int64 hit       21
# missed    11
# Name: ctl_miss_hit, dtype: int64
# [0.75       0.625      0.66666667 0.33333333 0.5        0.66666667
#  0.83333333]
# Accuracy: 0.6304347826086957
#               precision    recall  f1-score   support
#
#          hit       0.71      0.73      0.72        30
#       missed       0.47      0.44      0.45        16
#
#    micro avg       0.63      0.63      0.63        46
#    macro avg       0.59      0.59      0.59        46
# weighted avg       0.63      0.63      0.63        46
#
# accuracy = 0.625
#               precision    recall  f1-score   support
#
#          hit       0.68      0.81      0.74        21
#       missed       0.43      0.27      0.33        11
#
#    micro avg       0.62      0.62      0.62        32
#    macro avg       0.55      0.54      0.54        32
# weighted avg       0.59      0.62      0.60        32
#
# 413474
# training: 46 testing: 32
# hit       34
# missed    12
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.71428571 0.42857143 0.71428571 0.57142857 0.5
#  0.8       ]
# Accuracy: 0.5869565217391305
#               precision    recall  f1-score   support
#
#          hit       0.71      0.74      0.72        34
#       missed       0.18      0.17      0.17        12
#
#    micro avg       0.59      0.59      0.59        46
#    macro avg       0.45      0.45      0.45        46
# weighted avg       0.58      0.59      0.58        46
#
# accuracy = 0.625
#               precision    recall  f1-score   support
#
#          hit       0.83      0.62      0.71        24
#       missed       0.36      0.62      0.45         8
#
#    micro avg       0.62      0.62      0.62        32
#    macro avg       0.60      0.62      0.58        32
# weighted avg       0.71      0.62      0.65        32
#
# 437101
# training: 46 testing: 32
# hit       32
# missed    14
# Name: ctl_miss_hit, dtype: int64 hit       23
# missed     9
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.71428571 0.57142857 0.71428571 0.33333333 0.5
#  0.66666667]
# Accuracy: 0.5869565217391305
#               precision    recall  f1-score   support
#
#          hit       0.67      0.81      0.73        32
#       missed       0.14      0.07      0.10        14
#
#    micro avg       0.59      0.59      0.59        46
#    macro avg       0.40      0.44      0.41        46
# weighted avg       0.51      0.59      0.54        46
#
# accuracy = 0.65625
#               precision    recall  f1-score   support
#
#          hit       0.77      0.74      0.76        23
#       missed       0.40      0.44      0.42         9
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.67      0.66      0.66        32
#
# 439776
# training: 46 testing: 32
# hit       35
# missed    11
# Name: ctl_miss_hit, dtype: int64 hit       25
# missed     7
# Name: ctl_miss_hit, dtype: int64
# [0.85714286 0.71428571 0.71428571 0.85714286 0.83333333 0.83333333
#  0.83333333]
# Accuracy: 0.8043478260869565
#               precision    recall  f1-score   support
#
#          hit       0.86      0.89      0.87        35
#       missed       0.60      0.55      0.57        11
#
#    micro avg       0.80      0.80      0.80        46
#    macro avg       0.73      0.72      0.72        46
# weighted avg       0.80      0.80      0.80        46
#
# accuracy = 0.5625
#               precision    recall  f1-score   support
#
#          hit       0.74      0.68      0.71        25
#       missed       0.11      0.14      0.12         7
#
#    micro avg       0.56      0.56      0.56        32
#    macro avg       0.43      0.41      0.42        32
# weighted avg       0.60      0.56      0.58        32
#
# 458807
# training: 46 testing: 32
# hit       31
# missed    15
# Name: ctl_miss_hit, dtype: int64 hit       22
# missed    10
# Name: ctl_miss_hit, dtype: int64
# [0.5        0.42857143 0.42857143 0.33333333 0.83333333 0.66666667
#  0.83333333]
# Accuracy: 0.5652173913043478
#               precision    recall  f1-score   support
#
#          hit       0.66      0.74      0.70        31
#       missed       0.27      0.20      0.23        15
#
#    micro avg       0.57      0.57      0.57        46
#    macro avg       0.46      0.47      0.46        46
# weighted avg       0.53      0.57      0.54        46
#
# accuracy = 0.53125
#               precision    recall  f1-score   support
#
#          hit       0.64      0.73      0.68        22
#       missed       0.14      0.10      0.12        10
#
#    micro avg       0.53      0.53      0.53        32
#    macro avg       0.39      0.41      0.40        32
# weighted avg       0.48      0.53      0.50        32
#
# 459801
# training: 46 testing: 32
# hit       35
# missed    11
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.71428571 0.71428571 0.71428571 0.83333333 0.83333333
#  0.83333333]
# Accuracy: 0.717391304347826
#               precision    recall  f1-score   support
#
#          hit       0.76      0.91      0.83        35
#       missed       0.25      0.09      0.13        11
#
#    micro avg       0.72      0.72      0.72        46
#    macro avg       0.51      0.50      0.48        46
# weighted avg       0.64      0.72      0.66        46
#
# accuracy = 0.71875
#               precision    recall  f1-score   support
#
#          hit       0.80      0.83      0.82        24
#       missed       0.43      0.38      0.40         8
#
#    micro avg       0.72      0.72      0.72        32
#    macro avg       0.61      0.60      0.61        32
# weighted avg       0.71      0.72      0.71        32
#
# 484204
# training: 46 testing: 32
# hit       29
# missed    17
# Name: ctl_miss_hit, dtype: int64 hit       21
# missed    11
# Name: ctl_miss_hit, dtype: int64
# [0.625      0.14285714 0.71428571 0.33333333 0.83333333 0.33333333
#  0.66666667]
# Accuracy: 0.5217391304347826
#               precision    recall  f1-score   support
#
#          hit       0.62      0.62      0.62        29
#       missed       0.35      0.35      0.35        17
#
#    micro avg       0.52      0.52      0.52        46
#    macro avg       0.49      0.49      0.49        46
# weighted avg       0.52      0.52      0.52        46
#
# accuracy = 0.71875
#               precision    recall  f1-score   support
#
#          hit       0.80      0.76      0.78        21
#       missed       0.58      0.64      0.61        11
#
#    micro avg       0.72      0.72      0.72        32
#    macro avg       0.69      0.70      0.69        32
# weighted avg       0.73      0.72      0.72        32
#
# 502616
# training: 46 testing: 32
# hit       37
# missed     9
# Name: ctl_miss_hit, dtype: int64 hit       25
# missed     7
# Name: ctl_miss_hit, dtype: int64
# [0.5        0.75       0.66666667 0.83333333 0.66666667 0.66666667
#  0.83333333]
# Accuracy: 0.6956521739130435
#               precision    recall  f1-score   support
#
#          hit       0.78      0.86      0.82        37
#       missed       0.00      0.00      0.00         9
#
#    micro avg       0.70      0.70      0.70        46
#    macro avg       0.39      0.43      0.41        46
# weighted avg       0.63      0.70      0.66        46
# /anaconda3/envs/may19_py36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# accuracy = 0.78125
#               precision    recall  f1-score   support
#
#          hit       0.78      1.00      0.88        25
#       missed       0.00      0.00      0.00         7
#
#    micro avg       0.78      0.78      0.78        32
#    macro avg       0.39      0.50      0.44        32
# weighted avg       0.61      0.78      0.69        32
#
# 567214
# training: 46 testing: 32
# hit       34
# missed    12
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.85714286 0.71428571 0.57142857 0.57142857 0.71428571 0.5
#  0.8       ]
# Accuracy: 0.6739130434782609
#               precision    recall  f1-score   support
#
#          hit       0.76      0.82      0.79        34
#       missed       0.33      0.25      0.29        12
#
#    micro avg       0.67      0.67      0.67        46
#    macro avg       0.55      0.54      0.54        46
# weighted avg       0.65      0.67      0.66        46
#
# accuracy = 0.65625
#               precision    recall  f1-score   support
#
#          hit       0.72      0.88      0.79        24
#       missed       0.00      0.00      0.00         8
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.36      0.44      0.40        32
# weighted avg       0.54      0.66      0.59        32
#
# 597569
# training: 46 testing: 32
# hit       35
# missed    11
# Name: ctl_miss_hit, dtype: int64 hit       25
# missed     7
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.57142857 0.71428571 0.57142857 0.5        0.66666667
#  0.83333333]
# Accuracy: 0.6521739130434783
#               precision    recall  f1-score   support
#
#          hit       0.77      0.77      0.77        35
#       missed       0.27      0.27      0.27        11
#
#    micro avg       0.65      0.65      0.65        46
#    macro avg       0.52      0.52      0.52        46
# weighted avg       0.65      0.65      0.65        46
#
# accuracy = 0.78125
#               precision    recall  f1-score   support
#
#          hit       0.82      0.92      0.87        25
#       missed       0.50      0.29      0.36         7
#
#    micro avg       0.78      0.78      0.78        32
#    macro avg       0.66      0.60      0.62        32
# weighted avg       0.75      0.78      0.76        32
#
# 652850
# training: 46 testing: 32
# hit       25
# missed    21
# Name: ctl_miss_hit, dtype: int64 hit       17
# missed    15
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.28571429 0.42857143 0.42857143 0.33333333 0.16666667
#  0.16666667]
# Accuracy: 0.32608695652173914
#               precision    recall  f1-score   support
#
#          hit       0.38      0.40      0.39        25
#       missed       0.25      0.24      0.24        21
#
#    micro avg       0.33      0.33      0.33        46
#    macro avg       0.32      0.32      0.32        46
# weighted avg       0.32      0.33      0.32        46
#
# accuracy = 0.4375
#               precision    recall  f1-score   support
#
#          hit       0.47      0.41      0.44        17
#       missed       0.41      0.47      0.44        15
#
#    micro avg       0.44      0.44      0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
# 677561
# training: 46 testing: 32
# hit       34
# missed    12
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.85714286 0.85714286 0.71428571 0.71428571 0.71428571 0.83333333
#  0.6       ]
# Accuracy: 0.7608695652173914
#               precision    recall  f1-score   support
#
#          hit       0.78      0.94      0.85        34
#       missed       0.60      0.25      0.35        12
#
#    micro avg       0.76      0.76      0.76        46
#    macro avg       0.69      0.60      0.60        46
# weighted avg       0.73      0.76      0.72        46
#
# accuracy = 0.625
#               precision    recall  f1-score   support
#
#          hit       0.71      0.83      0.77        24
#       missed       0.00      0.00      0.00         8
#
#    micro avg       0.62      0.62      0.62        32
#    macro avg       0.36      0.42      0.38        32
# weighted avg       0.54      0.62      0.58        32
#
# 711830
# training: 46 testing: 32
# hit       25
# missed    21
# Name: ctl_miss_hit, dtype: int64 hit       18
# missed    14
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.28571429 0.         0.42857143 0.5        0.66666667
#  0.33333333]
# Accuracy: 0.391304347826087
#               precision    recall  f1-score   support
#
#          hit       0.44      0.44      0.44        25
#       missed       0.33      0.33      0.33        21
#
#    micro avg       0.39      0.39      0.39        46
#    macro avg       0.39      0.39      0.39        46
# weighted avg       0.39      0.39      0.39        46
#
# accuracy = 0.5
#               precision    recall  f1-score   support
#
#          hit       0.57      0.44      0.50        18
#       missed       0.44      0.57      0.50        14
#
#    micro avg       0.50      0.50      0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.52      0.50      0.50        32
#
# 729722
# training: 46 testing: 32
# hit       32
# missed    14
# Name: ctl_miss_hit, dtype: int64 hit       22
# missed    10
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.57142857 0.57142857 0.71428571 0.33333333 0.66666667
#  0.5       ]
# Accuracy: 0.5652173913043478
#               precision    recall  f1-score   support
#
#          hit       0.69      0.69      0.69        32
#       missed       0.29      0.29      0.29        14
#
#    micro avg       0.57      0.57      0.57        46
#    macro avg       0.49      0.49      0.49        46
# weighted avg       0.57      0.57      0.57        46
#
# accuracy = 0.5625
#               precision    recall  f1-score   support
#
#          hit       0.65      0.77      0.71        22
#       missed       0.17      0.10      0.12        10
#
#    micro avg       0.56      0.56      0.56        32
#    macro avg       0.41      0.44      0.42        32
# weighted avg       0.50      0.56      0.53        32
#
# 739694
# training: 46 testing: 32
# hit       34
# missed    12
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.28571429 0.57142857 0.71428571 0.71428571 0.66666667
#  0.8       ]
# Accuracy: 0.6086956521739131
#               precision    recall  f1-score   support
#
#          hit       0.71      0.79      0.75        34
#       missed       0.12      0.08      0.10        12
#
#    micro avg       0.61      0.61      0.61        46
#    macro avg       0.42      0.44      0.42        46
# weighted avg       0.56      0.61      0.58        46
#
# accuracy = 0.65625
#               precision    recall  f1-score   support
#
#          hit       0.74      0.83      0.78        24
#       missed       0.20      0.12      0.15         8
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.47      0.48      0.47        32
# weighted avg       0.61      0.66      0.63        32
#
# 748676
# training: 46 testing: 32
# missed    26
# hit       20
# Name: ctl_miss_hit, dtype: int64 missed    18
# hit       14
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.28571429 0.14285714 0.42857143 0.57142857 0.5
#  0.4       ]
# Accuracy: 0.43478260869565216
#               precision    recall  f1-score   support
#
#          hit       0.35      0.35      0.35        20
#       missed       0.50      0.50      0.50        26
#
#    micro avg       0.43      0.43      0.43        46
#    macro avg       0.42      0.42      0.42        46
# weighted avg       0.43      0.43      0.43        46
#
# accuracy = 0.40625
#               precision    recall  f1-score   support
#
#          hit       0.33      0.36      0.34        14
#       missed       0.47      0.44      0.46        18
#
#    micro avg       0.41      0.41      0.41        32
#    macro avg       0.40      0.40      0.40        32
# weighted avg       0.41      0.41      0.41        32
#
# 763590
# training: 45 testing: 30
# missed    28
# hit       17
# Name: ctl_miss_hit, dtype: int64 missed    18
# hit       12
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.71428571 0.42857143 0.33333333 0.33333333 0.33333333
#  0.5       ]
# Accuracy: 0.4666666666666667
#               precision    recall  f1-score   support
#
#          hit       0.23      0.18      0.20        17
#       missed       0.56      0.64      0.60        28
#
#    micro avg       0.47      0.47      0.47        45
#    macro avg       0.40      0.41      0.40        45
# weighted avg       0.44      0.47      0.45        45
# accuracy = 0.6
#               precision    recall  f1-score   support
#
#          hit       0.50      0.50      0.50        12
#       missed       0.67      0.67      0.67        18
#
#    micro avg       0.60      0.60      0.60        30
#    macro avg       0.58      0.58      0.58        30
# weighted avg       0.60      0.60      0.60        30
#
# 778749
# training: 46 testing: 32
# hit       27
# missed    19
# Name: ctl_miss_hit, dtype: int64 hit       19
# missed    13
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.42857143 0.42857143 0.42857143 0.28571429 0.83333333
#  0.6       ]
# Accuracy: 0.5217391304347826
#               precision    recall  f1-score   support
#
#          hit       0.60      0.56      0.58        27
#       missed       0.43      0.47      0.45        19
#
#    micro avg       0.52      0.52      0.52        46
#    macro avg       0.51      0.51      0.51        46
# weighted avg       0.53      0.52      0.52        46
#
# accuracy = 0.59375
#               precision    recall  f1-score   support
#
#          hit       0.62      0.84      0.71        19
#       missed       0.50      0.23      0.32        13
#
#    micro avg       0.59      0.59      0.59        32
#    macro avg       0.56      0.54      0.51        32
# weighted avg       0.57      0.59      0.55        32
#
# 783781
# training: 46 testing: 32
# hit       36
# missed    10
# Name: ctl_miss_hit, dtype: int64 hit       25
# missed     7
# Name: ctl_miss_hit, dtype: int64
# [0.75       0.71428571 0.42857143 0.66666667 0.66666667 0.83333333
#  0.5       ]
# Accuracy: 0.6521739130434783
#               precision    recall  f1-score   support
#
#          hit       0.75      0.83      0.79        36
#       missed       0.00      0.00      0.00        10
#
#    micro avg       0.65      0.65      0.65        46
#    macro avg       0.38      0.42      0.39        46
# weighted avg       0.59      0.65      0.62        46
#
# accuracy = 0.75
#               precision    recall  f1-score   support
#
#          hit       0.81      0.88      0.85        25
#       missed       0.40      0.29      0.33         7
#
#    micro avg       0.75      0.75      0.75        32
#    macro avg       0.61      0.58      0.59        32
# weighted avg       0.72      0.75      0.73        32
#
# 884343
# training: 46 testing: 32
# hit       31
# missed    15
# Name: ctl_miss_hit, dtype: int64 hit       22
# missed    10
# Name: ctl_miss_hit, dtype: int64
# [0.625      0.57142857 0.28571429 0.16666667 0.5        0.5
#  0.66666667]
# Accuracy: 0.4782608695652174
#               precision    recall  f1-score   support
#
#          hit       0.61      0.61      0.61        31
#       missed       0.20      0.20      0.20        15
#
#    micro avg       0.48      0.48      0.48        46
#    macro avg       0.41      0.41      0.41        46
# weighted avg       0.48      0.48      0.48        46
#
# accuracy = 0.5
#               precision    recall  f1-score   support
#
#          hit       0.65      0.59      0.62        22
#       missed       0.25      0.30      0.27        10
#
#    micro avg       0.50      0.50      0.50        32
#    macro avg       0.45      0.45      0.45        32
# weighted avg       0.53      0.50      0.51        32
#
# 886007
# training: 46 testing: 32
# hit       34
# missed    12
# Name: ctl_miss_hit, dtype: int64 hit       24
# missed     8
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.57142857 0.71428571 0.57142857 0.85714286 1.
#  0.8       ]
# Accuracy: 0.7391304347826086
#               precision    recall  f1-score   support
#
#          hit       0.78      0.91      0.84        34
#       missed       0.50      0.25      0.33        12
#
#    micro avg       0.74      0.74      0.74        46
#    macro avg       0.64      0.58      0.59        46
# weighted avg       0.70      0.74      0.71        46
#
# accuracy = 0.65625
#               precision    recall  f1-score   support
#
#          hit       0.76      0.79      0.78        24
#       missed       0.29      0.25      0.27         8
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.64      0.66      0.65        32
#
# 920577
# training: 46 testing: 32
# missed    28
# hit       18
# Name: ctl_miss_hit, dtype: int64 missed    19
# hit       13
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.71428571 0.71428571 0.57142857 0.66666667 0.5
#  0.5       ]
# Accuracy: 0.5869565217391305
#               precision    recall  f1-score   support
#
#          hit       0.47      0.44      0.46        18
#       missed       0.66      0.68      0.67        28
#
#    micro avg       0.59      0.59      0.59        46
#    macro avg       0.56      0.56      0.56        46
# weighted avg       0.58      0.59      0.58        46
#
# accuracy = 0.5
#               precision    recall  f1-score   support
#
#          hit       0.40      0.46      0.43        13
#       missed       0.59      0.53      0.56        19
#
#    micro avg       0.50      0.50      0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.51      0.50      0.50        32
#
# 936730
# training: 45 testing: 31
# hit       27
# missed    18
# Name: ctl_miss_hit, dtype: int64 hit       19
# missed    12
# Name: ctl_miss_hit, dtype: int64
# [0.42857143 0.28571429 0.71428571 0.57142857 0.5        0.5
#  0.6       ]
# Accuracy: 0.5111111111111111
#               precision    recall  f1-score   support
#
#          hit       0.58      0.67      0.62        27
#       missed       0.36      0.28      0.31        18
#
#    micro avg       0.51      0.51      0.51        45
#    macro avg       0.47      0.47      0.47        45
# weighted avg       0.49      0.51      0.50        45
#
# accuracy = 0.5806451612903226
#               precision    recall  f1-score   support
#
#          hit       0.65      0.68      0.67        19
#       missed       0.45      0.42      0.43        12
#
#    micro avg       0.58      0.58      0.58        31
#    macro avg       0.55      0.55      0.55        31
# weighted avg       0.57      0.58      0.58        31
#
# 956130
# training: 46 testing: 32
# hit       27
# missed    19
# Name: ctl_miss_hit, dtype: int64 hit       18
# missed    14
# Name: ctl_miss_hit, dtype: int64
# [0.28571429 0.85714286 0.28571429 0.42857143 0.28571429 0.83333333
#  0.2       ]
# Accuracy: 0.45652173913043476
#               precision    recall  f1-score   support
#
#          hit       0.54      0.48      0.51        27
#       missed       0.36      0.42      0.39        19
#
#    micro avg       0.46      0.46      0.46        46
#    macro avg       0.45      0.45      0.45        46
# weighted avg       0.47      0.46      0.46        46
#
# accuracy = 0.6875
#               precision    recall  f1-score   support
#
#          hit       0.72      0.72      0.72        18
#       missed       0.64      0.64      0.64        14
#
#    micro avg       0.69      0.69      0.69        32
#    macro avg       0.68      0.68      0.68        32
# weighted avg       0.69      0.69      0.69        32
#
# 974246
# training: 46 testing: 32
# missed    27
# hit       19
# Name: ctl_miss_hit, dtype: int64 missed    19
# hit       13
# Name: ctl_miss_hit, dtype: int64
# [0.57142857 0.57142857 0.42857143 0.57142857 0.57142857 0.33333333
#  0.4       ]
# Accuracy: 0.5
#               precision    recall  f1-score   support
#
#          hit       0.40      0.42      0.41        19
#       missed       0.58      0.56      0.57        27
#
#    micro avg       0.50      0.50      0.50        46
#    macro avg       0.49      0.49      0.49        46
# weighted avg       0.50      0.50      0.50        46
#
# accuracy = 0.5
#               precision    recall  f1-score   support
#
#          hit       0.41      0.54      0.47        13
#       missed       0.60      0.47      0.53        19
#
#    micro avg       0.50      0.50      0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.52      0.50      0.50        32
#
# 983291
# training: 46 testing: 32
# hit       35
# missed    11
# Name: ctl_miss_hit, dtype: int64 hit       25
# missed     7
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.71428571 1.         0.71428571 0.5        0.66666667
#  0.83333333]
# Accuracy: 0.7391304347826086
#               precision    recall  f1-score   support
#
#          hit       0.78      0.91      0.84        35
#       missed       0.40      0.18      0.25        11
#
#    micro avg       0.74      0.74      0.74        46
#    macro avg       0.59      0.55      0.55        46
# weighted avg       0.69      0.74      0.70        46
# accuracy = 0.65625
#               precision    recall  f1-score   support
#
#          hit       0.75      0.84      0.79        25
#       missed       0.00      0.00      0.00         7
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.38      0.42      0.40        32
# weighted avg       0.59      0.66      0.62        32
#
# 998166
# training: 44 testing: 30
# hit       27
# missed    17
# Name: ctl_miss_hit, dtype: int64 hit       19
# missed    11
# Name: ctl_miss_hit, dtype: int64
# [0.71428571 0.42857143 0.57142857 0.83333333 0.5        0.33333333
#  0.4       ]
# Accuracy: 0.5454545454545454
#               precision    recall  f1-score   support
#
#          hit       0.61      0.70      0.66        27
#       missed       0.38      0.29      0.33        17
#
#    micro avg       0.55      0.55      0.55        44
#    macro avg       0.50      0.50      0.49        44
# weighted avg       0.52      0.55      0.53        44
#
# accuracy = 0.4666666666666667
#               precision    recall  f1-score   support
#
#          hit       0.58      0.58      0.58        19
#       missed       0.27      0.27      0.27        11
#
#    micro avg       0.47      0.47      0.47        30
#    macro avg       0.43      0.43      0.43        30
# weighted avg       0.47      0.47      0.47        30

# %%
# CORRECT SOURCE VERSUS WRONG SOURCE TRIAL CLASSIFICATION

# build data structure to store accuracy data and coefficients
cs_ws_data = pd.DataFrame()
cs_ws_data.insert(loc = 0, column = 'dccid', value = 'None', allow_duplicates=True)
# cs_ws_data.insert(loc = 1, column = 'diagnosis', value = 'None', allow_duplicates=True)
for i in range(0, 7):
    cs_ws_data.insert(loc = cs_ws_data.shape[1], column = 'CV'+str(i+1)+'_acc', value = NaN, allow_duplicates=True)
cs_ws_data.insert(loc = cs_ws_data.shape[1], column = 'TrainSet_MeanCV_acc', value = 'None', allow_duplicates=True)
cs_ws_data.insert(loc = cs_ws_data.shape[1], column = 'TestSet_acc', value = 'None', allow_duplicates=True)

for sub in cw_subs:
    print(sub)
    sub_data = [sub]
    # load subject's beta maps (one per trial)
    betas = image.load_img(img=os.path.join(beta_dir, str(sub), 'TrialContrasts/betas_sub'+str(sub)+'*.nii'),
                           wildcards=True)
    # initialize NiftiLabelMasker object    
    sub_mask = nb.load(os.path.join(mask_dir, 'func_sub'+str(sub)+'_mask_stereonl.nii'))
    sub_masker = NiftiMasker(mask_img=sub_mask, standardize=True)
                   
    # transform subject's beta maps into vector of network means per trial
    X_cs_ws_miss_ctl = sub_masker.fit_transform(betas)  
    
    # load subject's trial labels
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_ctl_miss_ws_cs.tsv')
    y_cs_ws_miss_ctl = pd.read_csv(labels_file, sep='\t')
    y_cs_ws_miss_ctl_labels = y_cs_ws_miss_ctl['ctl_miss_ws_cs']
    # mask X and y data to exclude trials of no interest
    cs_ws_mask = y_cs_ws_miss_ctl_labels.isin(['correctsource', 'wrongsource'])
    y_cs_ws = y_cs_ws_miss_ctl_labels[cs_ws_mask]      
    X_cs_ws  = X_cs_ws_miss_ctl[cs_ws_mask]
    
    # Split trials into a training and a test set
    X_train, X_test, y_train, y_test = train_test_split(
        X_cs_ws, # x
        y_cs_ws, # y
        test_size = 0.4, # 60%/40% split
        shuffle = True, # shuffle dataset before splitting
        stratify = y_cs_ws, # keep distribution of conditions consistent betw. train & test sets
        #random_state = 123  # if set number, same shuffle each time, otherwise randomization algo
        ) 
    print('training:', len(X_train), 'testing:', len(X_test))
    print(y_train.value_counts(), y_test.value_counts())
    
    # define the model
    sub_svc = SVC(kernel='linear', class_weight='balanced')
    
    # do cross-validation to evaluate model performance
    # within 10 folds of training set
    # predict
    y_pred = cross_val_predict(sub_svc, X_train, y_train,
                               groups=y_train, cv=7)
    # scores
    cv_acc = cross_val_score(sub_svc, X_train, y_train,
                         groups=y_train, cv=7)
    print(cv_acc)
    
    for i in range(0, len(cv_acc)):
        sub_data.append(cv_acc[i])
        
    # evaluate overall model performance on training data
    overall_acc = accuracy_score(y_pred = y_pred, y_true = y_train)
    overall_cr = classification_report(y_pred = y_pred, y_true = y_train)
    print('Accuracy:',overall_acc)
    print(overall_cr)
    
    sub_data.append(overall_acc)

    # Test model on unseen data from the test set
    sub_svc.fit(X_train, y_train)
    y_pred = sub_svc.predict(X_test) # classify age class using testing data
    acc = sub_svc.score(X_test, y_test) # get accuracy

    cr = classification_report(y_pred=y_pred, y_true=y_test) # get prec., recall & f1
    # print results
    print('accuracy =', acc)
    print(cr)  
    
    sub_data.append(acc)
    
    # get map of coefficients    
    # coef_ = sub_svc.coef_
    # print(coef_.shape)
    #Return voxel weights into a nifti image using the NiftiMasker
    # coef_img = sub_masker.inverse_transform(coef_)
    #Save .nii to file
    # coef_img.to_filename(os.path.join(output_dir, 'Coef_maps', 'SVC_coeff_cs_ws_sub-'+str(sub)+'.nii'))
    
    cs_ws_data = cs_ws_data.append(pd.Series(sub_data, index=cs_ws_data.columns), ignore_index=True)
    
cs_ws_data.to_csv(os.path.join(output_dir, 'SVC_withinSub_cs_ws_wholeBrain.tsv'),
    sep='\t', header=True, index=False)
# Out:
# 108391
# training: 37 testing: 26
# correctsource    25
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    18
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.5        0.66666667 0.66666667 0.2        0.5
#  0.5       ]
# Accuracy: 0.5405405405405406
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.80      0.70        25
#   wrongsource       0.00      0.00      0.00        12
#
#     micro avg       0.54      0.54      0.54        37
#     macro avg       0.31      0.40      0.35        37
#  weighted avg       0.42      0.54      0.47        37
#
# accuracy = 0.7692307692307693
#                precision    recall  f1-score   support
#
# correctsource       0.80      0.89      0.84        18
#   wrongsource       0.67      0.50      0.57         8
#
#     micro avg       0.77      0.77      0.77        26
#     macro avg       0.73      0.69      0.71        26
#  weighted avg       0.76      0.77      0.76        26
#
# 122922
# training: 33 testing: 22
# wrongsource      18
# correctsource    15
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      12
# correctsource    10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5  0.4  0.8  0.4  0.   0.5  0.25]
# Accuracy: 0.42424242424242425
#                precision    recall  f1-score   support
#
# correctsource       0.36      0.33      0.34        15
#   wrongsource       0.47      0.50      0.49        18
#
#     micro avg       0.42      0.42      0.42        33
#     macro avg       0.42      0.42      0.42        33
#  weighted avg       0.42      0.42      0.42        33
#
# accuracy = 0.6818181818181818
#                precision    recall  f1-score   support
#
# correctsource       0.71      0.50      0.59        10
#   wrongsource       0.67      0.83      0.74        12
#
#     micro avg       0.68      0.68      0.68        22
#     macro avg       0.69      0.67      0.66        22
#  weighted avg       0.69      0.68      0.67        22
#
# 139593
# training: 22 testing: 15
# wrongsource      13
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      9
# correctsource    6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.25       0.5        0.66666667 0.33333333 0.33333333 1.
#  0.5       ]
# Accuracy: 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.33      0.22      0.27         9
#   wrongsource       0.56      0.69      0.62        13
#
#     micro avg       0.50      0.50      0.50        22
#     macro avg       0.45      0.46      0.44        22
#  weighted avg       0.47      0.50      0.48        22
#
# accuracy = 0.4666666666666667
#                precision    recall  f1-score   support
#
# correctsource       0.25      0.17      0.20         6
#   wrongsource       0.55      0.67      0.60         9
#
#     micro avg       0.47      0.47      0.47        15
#     macro avg       0.40      0.42      0.40        15
#  weighted avg       0.43      0.47      0.44        15
#
# 150649
# training: 38 testing: 26
# wrongsource      26
# correctsource    12
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      17
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.83333333 0.5        0.83333333 0.83333333 0.75
#  1.        ]
# Accuracy: 0.7368421052631579
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.33      0.44        12
#   wrongsource       0.75      0.92      0.83        26
#
#     micro avg       0.74      0.74      0.74        38
#     macro avg       0.71      0.63      0.64        38
#  weighted avg       0.72      0.74      0.71        38
#
# accuracy = 0.6153846153846154
#                precision    recall  f1-score   support
#
# correctsource       0.44      0.44      0.44         9
#   wrongsource       0.71      0.71      0.71        17
#
#     micro avg       0.62      0.62      0.62        26
#     macro avg       0.58      0.58      0.58        26
#  weighted avg       0.62      0.62      0.62        26
#
# 175295
# training: 42 testing: 29
# correctsource    30
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    21
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.85714286 0.42857143 0.66666667 0.66666667 0.66666667 0.8
#  0.2       ]
# Accuracy: 0.6190476190476191
#                precision    recall  f1-score   support
#
# correctsource       0.71      0.80      0.75        30
#   wrongsource       0.25      0.17      0.20        12
#
#     micro avg       0.62      0.62      0.62        42
#     macro avg       0.48      0.48      0.48        42
#  weighted avg       0.58      0.62      0.59        42
#
# accuracy = 0.7586206896551724
#                precision    recall  f1-score   support
#
# correctsource       0.82      0.86      0.84        21
#   wrongsource       0.57      0.50      0.53         8
#
#     micro avg       0.76      0.76      0.76        29
#     macro avg       0.69      0.68      0.69        29
#  weighted avg       0.75      0.76      0.75        29
#
# 178101
# training: 43 testing: 29
# correctsource    23
# wrongsource      20
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# wrongsource      13
# Name: ctl_miss_ws_cs, dtype: int64
# [0.57142857 0.28571429 0.16666667 0.         0.66666667 0.33333333
#  0.6       ]
# Accuracy: 0.37209302325581395
#                precision    recall  f1-score   support
#
# correctsource       0.42      0.43      0.43        23
#   wrongsource       0.32      0.30      0.31        20
#
#     micro avg       0.37      0.37      0.37        43
#     macro avg       0.37      0.37      0.37        43
#  weighted avg       0.37      0.37      0.37        43
#
# accuracy = 0.5172413793103449
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.62      0.59        16
#   wrongsource       0.45      0.38      0.42        13
#
#     micro avg       0.52      0.52      0.52        29
#     macro avg       0.51      0.50      0.50        29
#  weighted avg       0.51      0.52      0.51        29
#
# 197192
# training: 41 testing: 28
# correctsource    29
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    20
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.5        0.5        0.66666667 0.83333333 0.6
#  0.8       ]
# Accuracy: 0.6585365853658537
#                precision    recall  f1-score   support
#
# correctsource       0.73      0.83      0.77        29
#   wrongsource       0.38      0.25      0.30        12
#
#     micro avg       0.66      0.66      0.66        41
#     macro avg       0.55      0.54      0.54        41
#  weighted avg       0.62      0.66      0.64        41
#
# accuracy = 0.6785714285714286
#                precision    recall  f1-score   support
#
# correctsource       0.79      0.75      0.77        20
#   wrongsource       0.44      0.50      0.47         8
#
#     micro avg       0.68      0.68      0.68        28
#     macro avg       0.62      0.62      0.62        28
#  weighted avg       0.69      0.68      0.68        28
#
# 199801
# training: 35 testing: 24
# wrongsource      26
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      18
# correctsource     6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.66666667 0.8        0.8        0.4        1.
#  0.75      ]
# Accuracy: 0.7142857142857143
#                precision    recall  f1-score   support
#
# correctsource       0.33      0.11      0.17         9
#   wrongsource       0.75      0.92      0.83        26
#
#     micro avg       0.71      0.71      0.71        35
#     macro avg       0.54      0.52      0.50        35
#  weighted avg       0.64      0.71      0.66        35
#
# accuracy = 0.7083333333333334
#                precision    recall  f1-score   support
#
# correctsource       0.00      0.00      0.00         6
#   wrongsource       0.74      0.94      0.83        18
#
#     micro avg       0.71      0.71      0.71        24
#     macro avg       0.37      0.47      0.41        24
#  weighted avg       0.55      0.71      0.62        24
#
# 229301
# training: 39 testing: 27
# correctsource    30
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    20
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.42857143 0.71428571 1.         0.8        1.         0.8
#  0.8       ]
# Accuracy: 0.7692307692307693
#                precision    recall  f1-score   support
#
# correctsource       0.80      0.93      0.86        30
#   wrongsource       0.50      0.22      0.31         9
#
#     micro avg       0.77      0.77      0.77        39
#     macro avg       0.65      0.58      0.58        39
#  weighted avg       0.73      0.77      0.73        39
# accuracy = 0.6666666666666666
#                precision    recall  f1-score   support
#
# correctsource       0.72      0.90      0.80        20
#   wrongsource       0.00      0.00      0.00         7
#
#     micro avg       0.67      0.67      0.67        27
#     macro avg       0.36      0.45      0.40        27
#  weighted avg       0.53      0.67      0.59        27
#
# 258618
# training: 30 testing: 21
# correctsource    20
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.2        0.6        0.6        0.25       0.25       0.75
#  0.66666667]
# Accuracy: 0.4666666666666667
#                precision    recall  f1-score   support
#
# correctsource       0.59      0.65      0.62        20
#   wrongsource       0.12      0.10      0.11        10
#
#     micro avg       0.47      0.47      0.47        30
#     macro avg       0.36      0.38      0.37        30
#  weighted avg       0.44      0.47      0.45        30
#
# accuracy = 0.5238095238095238
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.71      0.67        14
#   wrongsource       0.20      0.14      0.17         7
#
#     micro avg       0.52      0.52      0.52        21
#     macro avg       0.41      0.43      0.42        21
#  weighted avg       0.48      0.52      0.50        21
#
# 267168
# training: 40 testing: 27
# wrongsource      20
# correctsource    20
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# wrongsource      13
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.33333333 0.83333333 0.5        0.66666667 0.5
#  0.5       ]
# Accuracy: 0.55
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.55      0.55        20
#   wrongsource       0.55      0.55      0.55        20
#
#     micro avg       0.55      0.55      0.55        40
#     macro avg       0.55      0.55      0.55        40
#  weighted avg       0.55      0.55      0.55        40
#
# accuracy = 0.48148148148148145
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.43      0.46        14
#   wrongsource       0.47      0.54      0.50        13
#
#     micro avg       0.48      0.48      0.48        27
#     macro avg       0.48      0.48      0.48        27
#  weighted avg       0.48      0.48      0.48        27
#
# 326073
# training: 45 testing: 30
# correctsource    32
# wrongsource      13
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    22
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.42857143 0.57142857 0.71428571 0.33333333 0.5
#  0.2       ]
# Accuracy: 0.5111111111111111
#                precision    recall  f1-score   support
#
# correctsource       0.66      0.66      0.66        32
#   wrongsource       0.15      0.15      0.15        13
#
#     micro avg       0.51      0.51      0.51        45
#     macro avg       0.41      0.41      0.41        45
#  weighted avg       0.51      0.51      0.51        45
#
# accuracy = 0.5666666666666667
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.77      0.72        22
#   wrongsource       0.00      0.00      0.00         8
#
#     micro avg       0.57      0.57      0.57        30
#     macro avg       0.34      0.39      0.36        30
#  weighted avg       0.50      0.57      0.53        30
#
# 336665
# training: 31 testing: 21
# correctsource    16
# wrongsource      15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    11
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.33333333 0.6        0.75       0.75       0.25       0.25
#  0.5       ]
# Accuracy: 0.4838709677419355
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.56      0.53        16
#   wrongsource       0.46      0.40      0.43        15
#
#     micro avg       0.48      0.48      0.48        31
#     macro avg       0.48      0.48      0.48        31
#  weighted avg       0.48      0.48      0.48        31
#
# accuracy = 0.47619047619047616
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.64      0.56        11
#   wrongsource       0.43      0.30      0.35        10
#
#     micro avg       0.48      0.48      0.48        21
#     macro avg       0.46      0.47      0.46        21
#  weighted avg       0.47      0.48      0.46        21
#
# 337021
# training: 36 testing: 25
# correctsource    24
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.83333333 0.66666667 0.66666667 0.4        0.4        0.
#  0.75      ]
# Accuracy: 0.5555555555555556
#                precision    recall  f1-score   support
#
# correctsource       0.65      0.71      0.68        24
#   wrongsource       0.30      0.25      0.27        12
#
#     micro avg       0.56      0.56      0.56        36
#     macro avg       0.48      0.48      0.48        36
#  weighted avg       0.54      0.56      0.54        36
#
# accuracy = 0.64
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.81      0.74        16
#   wrongsource       0.50      0.33      0.40         9
#
#     micro avg       0.64      0.64      0.64        25
#     macro avg       0.59      0.57      0.57        25
#  weighted avg       0.62      0.64      0.62        25
#
# 350555
# training: 46 testing: 32
# correctsource    35
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    24
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.71428571 0.85714286 0.71428571 0.66666667 0.66666667
#  0.66666667]
# Accuracy: 0.717391304347826
#                precision    recall  f1-score   support
#
# correctsource       0.78      0.89      0.83        35
#   wrongsource       0.33      0.18      0.24        11
#
#     micro avg       0.72      0.72      0.72        46
#     macro avg       0.55      0.53      0.53        46
#  weighted avg       0.67      0.72      0.69        46
#
# accuracy = 0.65625
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.79      0.78        24
#   wrongsource       0.29      0.25      0.27         8
#
#     micro avg       0.66      0.66      0.66        32
#     macro avg       0.52      0.52      0.52        32
#  weighted avg       0.64      0.66      0.65        32
#
# 385370
# training: 38 testing: 26
# wrongsource      19
# correctsource    19
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      13
# correctsource    13
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.5        0.33333333 0.66666667 0.83333333 0.5
#  0.5       ]
# Accuracy: 0.5789473684210527
#                precision    recall  f1-score   support
#
# correctsource       0.59      0.53      0.56        19
#   wrongsource       0.57      0.63      0.60        19
#
#     micro avg       0.58      0.58      0.58        38
#     macro avg       0.58      0.58      0.58        38
#  weighted avg       0.58      0.58      0.58        38
#
# accuracy = 0.6538461538461539
#                precision    recall  f1-score   support
#
# correctsource       0.64      0.69      0.67        13
#   wrongsource       0.67      0.62      0.64        13
#
#     micro avg       0.65      0.65      0.65        26
#     macro avg       0.65      0.65      0.65        26
#  weighted avg       0.65      0.65      0.65        26
#
# 408506
# training: 30 testing: 21
# wrongsource      16
# correctsource    14
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      11
# correctsource    10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.4  0.4  0.25 0.75 0.5  0.75 0.75]
# Accuracy: 0.5333333333333333
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.43      0.46        14
#   wrongsource       0.56      0.62      0.59        16
#
#     micro avg       0.53      0.53      0.53        30
#     macro avg       0.53      0.53      0.52        30
#  weighted avg       0.53      0.53      0.53        30
#
# accuracy = 0.47619047619047616
#                precision    recall  f1-score   support
#
# correctsource       0.45      0.50      0.48        10
#   wrongsource       0.50      0.45      0.48        11
#
#     micro avg       0.48      0.48      0.48        21
#     macro avg       0.48      0.48      0.48        21
#  weighted avg       0.48      0.48      0.48        21
#
# 413474
# training: 34 testing: 24
# correctsource    25
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    17
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.33333333 0.8        0.8        0.75       0.5
#  1.        ]
# Accuracy: 0.6764705882352942
#                precision    recall  f1-score   support
#
# correctsource       0.75      0.84      0.79        25
#   wrongsource       0.33      0.22      0.27         9
#
#     micro avg       0.68      0.68      0.68        34
#     macro avg       0.54      0.53      0.53        34
#  weighted avg       0.64      0.68      0.65        34
#
# accuracy = 0.6666666666666666
#                precision    recall  f1-score   support
#
# correctsource       0.74      0.82      0.78        17
#   wrongsource       0.40      0.29      0.33         7
#
#     micro avg       0.67      0.67      0.67        24
#     macro avg       0.57      0.55      0.56        24
#  weighted avg       0.64      0.67      0.65        24
#
# 427357
# training: 45 testing: 30
# wrongsource      26
# correctsource    19
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      17
# correctsource    13
# Name: ctl_miss_ws_cs, dtype: int64
# [0.28571429 0.42857143 0.42857143 0.85714286 0.42857143 0.4
#  0.2       ]
# Accuracy: 0.4444444444444444
#                precision    recall  f1-score   support
#
# correctsource       0.33      0.32      0.32        19
#   wrongsource       0.52      0.54      0.53        26
#
#     micro avg       0.44      0.44      0.44        45
#     macro avg       0.43      0.43      0.43        45
#  weighted avg       0.44      0.44      0.44        45
#
# accuracy = 0.6333333333333333
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.77      0.65        13
#   wrongsource       0.75      0.53      0.62        17
#
#     micro avg       0.63      0.63      0.63        30
#     macro avg       0.65      0.65      0.63        30
#  weighted avg       0.67      0.63      0.63        30
#
# 437101
# training: 33 testing: 22
# correctsource    23
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    15
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5  1.   0.8  1.   0.75 0.5  0.75]
# Accuracy: 0.7575757575757576
#                precision    recall  f1-score   support
#
# correctsource       0.83      0.83      0.83        23
#   wrongsource       0.60      0.60      0.60        10
#
#     micro avg       0.76      0.76      0.76        33
#     macro avg       0.71      0.71      0.71        33
#  weighted avg       0.76      0.76      0.76        33
#
# accuracy = 0.5909090909090909
#                precision    recall  f1-score   support
#
# correctsource       0.71      0.67      0.69        15
#   wrongsource       0.38      0.43      0.40         7
#
#     micro avg       0.59      0.59      0.59        22
#     macro avg       0.54      0.55      0.54        22
#  weighted avg       0.61      0.59      0.60        22
#
# 458807
# training: 31 testing: 22
# correctsource    20
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    15
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.4        0.4        0.4        0.8        0.25       0.5
#  0.33333333]
# Accuracy: 0.45161290322580644
#                precision    recall  f1-score   support
#
# correctsource       0.57      0.60      0.59        20
#   wrongsource       0.20      0.18      0.19        11
#
#     micro avg       0.45      0.45      0.45        31
#     macro avg       0.39      0.39      0.39        31
#  weighted avg       0.44      0.45      0.45        31
#
# accuracy = 0.6363636363636364
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.87      0.76        15
#   wrongsource       0.33      0.14      0.20         7
#
#     micro avg       0.64      0.64      0.64        22
#     macro avg       0.51      0.50      0.48        22
#  weighted avg       0.57      0.64      0.59        22
#
# 459801
# training: 35 testing: 24
# correctsource    20
# wrongsource      15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    13
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5  0.6  1.   0.6  0.6  0.8  0.75]
# Accuracy: 0.6857142857142857
#                precision    recall  f1-score   support
#
# correctsource       0.71      0.75      0.73        20
#   wrongsource       0.64      0.60      0.62        15
#
#     micro avg       0.69      0.69      0.69        35
#     macro avg       0.68      0.68      0.68        35
#  weighted avg       0.68      0.69      0.68        35
#
# accuracy = 0.4583333333333333
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.46      0.48        13
#   wrongsource       0.42      0.45      0.43        11
#
#     micro avg       0.46      0.46      0.46        24
#     macro avg       0.46      0.46      0.46        24
#  weighted avg       0.46      0.46      0.46        24
#
# 462345
# training: 40 testing: 28
# correctsource    30
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    21
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.71428571 0.66666667 0.8        0.8        0.8
#  0.8       ]
# Accuracy: 0.75
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.97      0.85        30
#   wrongsource       0.50      0.10      0.17        10
#
#     micro avg       0.75      0.75      0.75        40
#     macro avg       0.63      0.53      0.51        40
#  weighted avg       0.70      0.75      0.68        40
#
# accuracy = 0.7142857142857143
#                precision    recall  f1-score   support
#
# correctsource       0.78      0.86      0.82        21
#   wrongsource       0.40      0.29      0.33         7
#
#     micro avg       0.71      0.71      0.71        28
#     macro avg       0.59      0.57      0.58        28
#  weighted avg       0.69      0.71      0.70        28
#
# 502616
# training: 37 testing: 25
# correctsource    21
# wrongsource      16
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    15
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5 0.5 0.2 0.2 0.6 0.4 0.6]
# Accuracy: 0.43243243243243246
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.57      0.53        21
#   wrongsource       0.31      0.25      0.28        16
#
#     micro avg       0.43      0.43      0.43        37
#     macro avg       0.40      0.41      0.40        37
#  weighted avg       0.42      0.43      0.42        37
#
# accuracy = 0.44
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.40      0.46        15
#   wrongsource       0.36      0.50      0.42        10
#
#     micro avg       0.44      0.44      0.44        25
#     macro avg       0.45      0.45      0.44        25
#  weighted avg       0.47      0.44      0.44        25
#
# 549994
# training: 41 testing: 28
# correctsource    24
# wrongsource      17
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.42857143 0.71428571 0.42857143 0.4        1.         0.2
#  0.4       ]
# Accuracy: 0.5121951219512195
#                precision    recall  f1-score   support
#
# correctsource       0.57      0.71      0.63        24
#   wrongsource       0.36      0.24      0.29        17
#
#     micro avg       0.51      0.51      0.51        41
#     macro avg       0.47      0.47      0.46        41
#  weighted avg       0.48      0.51      0.49        41
#
# accuracy = 0.42857142857142855
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.56      0.53        16
#   wrongsource       0.30      0.25      0.27        12
#
#     micro avg       0.43      0.43      0.43        28
#     macro avg       0.40      0.41      0.40        28
#  weighted avg       0.41      0.43      0.42        28
#
# 555537
# training: 39 testing: 27
# correctsource    23
# wrongsource      16
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.57142857 0.42857143 0.4        0.4        0.6        0.4
#  0.6       ]
# Accuracy: 0.48717948717948717
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.61      0.58        23
#   wrongsource       0.36      0.31      0.33        16
#
#     micro avg       0.49      0.49      0.49        39
#     macro avg       0.46      0.46      0.46        39
#  weighted avg       0.48      0.49      0.48        39
#
# accuracy = 0.48148148148148145
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.56      0.56        16
#   wrongsource       0.36      0.36      0.36        11
#
#     micro avg       0.48      0.48      0.48        27
#     macro avg       0.46      0.46      0.46        27
#  weighted avg       0.48      0.48      0.48        27
#
# 567214
# training: 34 testing: 24
# wrongsource      17
# correctsource    17
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      12
# correctsource    12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.33333333 0.66666667 0.5        0.75       0.75
#  0.5       ]
# Accuracy: 0.5588235294117647
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.65      0.59        17
#   wrongsource       0.57      0.47      0.52        17
#
#     micro avg       0.56      0.56      0.56        34
#     macro avg       0.56      0.56      0.56        34
#  weighted avg       0.56      0.56      0.56        34
#
# accuracy = 0.5416666666666666
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.50      0.52        12
#   wrongsource       0.54      0.58      0.56        12
#
#     micro avg       0.54      0.54      0.54        24
#     macro avg       0.54      0.54      0.54        24
#  weighted avg       0.54      0.54      0.54        24
#
# 619278
# training: 41 testing: 28
# correctsource    28
# wrongsource      13
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    19
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.83333333 0.83333333 0.66666667 0.66666667 0.5        0.66666667
#  0.8       ]
# Accuracy: 0.7073170731707317
#                precision    recall  f1-score   support
#
# correctsource       0.75      0.86      0.80        28
#   wrongsource       0.56      0.38      0.45        13
#
#     micro avg       0.71      0.71      0.71        41
#     macro avg       0.65      0.62      0.63        41
#  weighted avg       0.69      0.71      0.69        41
#
# accuracy = 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.65      0.58      0.61        19
#   wrongsource       0.27      0.33      0.30         9
#
#     micro avg       0.50      0.50      0.50        28
#     macro avg       0.46      0.46      0.46        28
#  weighted avg       0.53      0.50      0.51        28
#
# 652850
# training: 25 testing: 17
# wrongsource      13
# correctsource    12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    9
# wrongsource      8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5  0.5  0.5  0.75 0.75 1.   0.5 ]
# Accuracy: 0.64
#                precision    recall  f1-score   support
#
# correctsource       0.64      0.58      0.61        12
#   wrongsource       0.64      0.69      0.67        13
#
#     micro avg       0.64      0.64      0.64        25
#     macro avg       0.64      0.64      0.64        25
#  weighted avg       0.64      0.64      0.64        25
#
# accuracy = 0.35294117647058826
#                precision    recall  f1-score   support
#
# correctsource       0.38      0.33      0.35         9
#   wrongsource       0.33      0.38      0.35         8
#
#     micro avg       0.35      0.35      0.35        17
#     macro avg       0.35      0.35      0.35        17
#  weighted avg       0.36      0.35      0.35        17
#
# 659068
# training: 42 testing: 28
# correctsource    29
# wrongsource      13
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    20
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.85714286 0.83333333 0.66666667 0.5        1.         0.66666667
#  0.6       ]
# Accuracy: 0.7380952380952381
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.90      0.83        29
#   wrongsource       0.62      0.38      0.48        13
#
#     micro avg       0.74      0.74      0.74        42
#     macro avg       0.69      0.64      0.65        42
#  weighted avg       0.72      0.74      0.72        42
#
# accuracy = 0.6071428571428571
#                precision    recall  f1-score   support
#
# correctsource       0.74      0.70      0.72        20
#   wrongsource       0.33      0.38      0.35         8
#
#     micro avg       0.61      0.61      0.61        28
#     macro avg       0.54      0.54      0.54        28
#  weighted avg       0.62      0.61      0.61        28
#
# 668786
# training: 42 testing: 29
# correctsource    27
# wrongsource      15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    18
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.42857143 0.16666667 0.83333333 0.16666667 0.66666667 0.66666667
#  0.6       ]
# Accuracy: 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.59      0.60        27
#   wrongsource       0.31      0.33      0.32        15
#
#     micro avg       0.50      0.50      0.50        42
#     macro avg       0.46      0.46      0.46        42
#  weighted avg       0.51      0.50      0.50        42
#
# accuracy = 0.6206896551724138
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.78      0.72        18
#   wrongsource       0.50      0.36      0.42        11
#
#     micro avg       0.62      0.62      0.62        29
#     macro avg       0.58      0.57      0.57        29
#  weighted avg       0.60      0.62      0.61        29
#
# 677561
# training: 34 testing: 24
# correctsource    20
# wrongsource      14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6 0.6 0.6 0.8 0.6 0.6 0.5]
# Accuracy: 0.6176470588235294
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.70      0.68        20
#   wrongsource       0.54      0.50      0.52        14
#
#     micro avg       0.62      0.62      0.62        34
#     macro avg       0.60      0.60      0.60        34
#  weighted avg       0.61      0.62      0.62        34
#
# accuracy = 0.5833333333333334
#                precision    recall  f1-score   support
#
# correctsource       0.61      0.79      0.69        14
#   wrongsource       0.50      0.30      0.37        10
#
#     micro avg       0.58      0.58      0.58        24
#     macro avg       0.56      0.54      0.53        24
#  weighted avg       0.56      0.58      0.56        24
#
# 711830
# training: 25 testing: 18
# correctsource    15
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    11
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6        0.5        0.75       1.         0.66666667 0.33333333
#  0.        ]
# Accuracy: 0.56
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.67      0.65        15
#   wrongsource       0.44      0.40      0.42        10
#
#     micro avg       0.56      0.56      0.56        25
#     macro avg       0.53      0.53      0.53        25
#  weighted avg       0.55      0.56      0.56        25
#
# accuracy = 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.57      0.73      0.64        11
#   wrongsource       0.25      0.14      0.18         7
#
#     micro avg       0.50      0.50      0.50        18
#     macro avg       0.41      0.44      0.41        18
#  weighted avg       0.45      0.50      0.46        18
#
# 739694
# training: 34 testing: 24
# correctsource    20
# wrongsource      14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.8 0.6 0.4 0.4 0.6 0.4 0. ]
# Accuracy: 0.47058823529411764
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.55      0.55        20
#   wrongsource       0.36      0.36      0.36        14
#
#     micro avg       0.47      0.47      0.47        34
#     macro avg       0.45      0.45      0.45        34
#  weighted avg       0.47      0.47      0.47        34
#
# accuracy = 0.625
#                precision    recall  f1-score   support
#
# correctsource       0.65      0.79      0.71        14
#   wrongsource       0.57      0.40      0.47        10
#
#     micro avg       0.62      0.62      0.62        24
#     macro avg       0.61      0.59      0.59        24
#  weighted avg       0.62      0.62      0.61        24
#
# 748676
# training: 20 testing: 14
# wrongsource      11
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      7
# correctsource    7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.75       1.         0.33333333 0.66666667 0.         1.
#  1.        ]
# Accuracy: 0.7
#                precision    recall  f1-score   support
#
# correctsource       0.64      0.78      0.70         9
#   wrongsource       0.78      0.64      0.70        11
#
#     micro avg       0.70      0.70      0.70        20
#     macro avg       0.71      0.71      0.70        20
#  weighted avg       0.71      0.70      0.70        20
#
# accuracy = 0.6428571428571429
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.71      0.67         7
#   wrongsource       0.67      0.57      0.62         7
#
#     micro avg       0.64      0.64      0.64        14
#     macro avg       0.65      0.64      0.64        14
#  weighted avg       0.65      0.64      0.64        14
#
# 778749
# training: 27 testing: 19
# wrongsource      14
# correctsource    13
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    10
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.25       0.25       0.5        0.25       0.5        0.
#  0.33333333]
# Accuracy: 0.2962962962962963
#                precision    recall  f1-score   support
#
# correctsource       0.25      0.23      0.24        13
#   wrongsource       0.33      0.36      0.34        14
#
#     micro avg       0.30      0.30      0.30        27
#     macro avg       0.29      0.29      0.29        27
#  weighted avg       0.29      0.30      0.29        27
#
# accuracy = 0.3684210526315789
#                precision    recall  f1-score   support
#
# correctsource       0.38      0.30      0.33        10
#   wrongsource       0.36      0.44      0.40         9
#
#     micro avg       0.37      0.37      0.37        19
#     macro avg       0.37      0.37      0.37        19
#  weighted avg       0.37      0.37      0.36        19
#
# 783781
# training: 36 testing: 25
# correctsource    24
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.66666667 0.66666667 0.4        0.8        0.5
#  0.5       ]
# Accuracy: 0.6111111111111112
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.79      0.73        24
#   wrongsource       0.38      0.25      0.30        12
#
#     micro avg       0.61      0.61      0.61        36
#     macro avg       0.53      0.52      0.52        36
#  weighted avg       0.58      0.61      0.59        36
#
# accuracy = 0.56
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.81      0.70        16
#   wrongsource       0.25      0.11      0.15         9
#
#     micro avg       0.56      0.56      0.56        25
#     macro avg       0.43      0.46      0.43        25
#  weighted avg       0.49      0.56      0.51        25
#
# 878354
# training: 45 testing: 31
# correctsource    33
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    22
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.71428571 0.57142857 0.85714286 0.85714286 0.6
#  0.4       ]
# Accuracy: 0.6888888888888889
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.85      0.80        33
#   wrongsource       0.38      0.25      0.30        12
#
#     micro avg       0.69      0.69      0.69        45
#     macro avg       0.57      0.55      0.55        45
#  weighted avg       0.65      0.69      0.67        45
#
# accuracy = 0.5483870967741935
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.73      0.70        22
#   wrongsource       0.14      0.11      0.12         9
#
#     micro avg       0.55      0.55      0.55        31
#     macro avg       0.40      0.42      0.41        31
#  weighted avg       0.51      0.55      0.53        31
#
# 884343
# training: 31 testing: 22
# correctsource    17
# wrongsource      14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    12
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6  0.8  0.4  0.5  0.5  0.75 0.5 ]
# Accuracy: 0.5806451612903226
#                precision    recall  f1-score   support
#
# correctsource       0.61      0.65      0.63        17
#   wrongsource       0.54      0.50      0.52        14
#
#     micro avg       0.58      0.58      0.58        31
#     macro avg       0.57      0.57      0.57        31
#  weighted avg       0.58      0.58      0.58        31
#
# accuracy = 0.5454545454545454
#                precision    recall  f1-score   support
#
# correctsource       0.57      0.67      0.62        12
#   wrongsource       0.50      0.40      0.44        10
#
#     micro avg       0.55      0.55      0.55        22
#     macro avg       0.54      0.53      0.53        22
#  weighted avg       0.54      0.55      0.54        22
#
# 893978
# training: 38 testing: 26
# wrongsource      20
# correctsource    18
# Name: ctl_miss_ws_cs, dtype: int64 wrongsource      14
# correctsource    12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.16666667 0.66666667 0.66666667 0.6        0.6
#  0.5       ]
# Accuracy: 0.5526315789473685
#                precision    recall  f1-score   support
#
# correctsource       0.53      0.44      0.48        18
#   wrongsource       0.57      0.65      0.60        20
#
#     micro avg       0.55      0.55      0.55        38
#     macro avg       0.55      0.55      0.54        38
#  weighted avg       0.55      0.55      0.55        38
#
# accuracy = 0.5384615384615384
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.67      0.57        12
#   wrongsource       0.60      0.43      0.50        14
#
#     micro avg       0.54      0.54      0.54        26
#     macro avg       0.55      0.55      0.54        26
#  weighted avg       0.55      0.54      0.53        26
#
# 901551
# training: 45 testing: 31
# correctsource    35
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    24
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.71428571 0.71428571 0.66666667 0.83333333 1.
#  0.66666667]
# Accuracy: 0.7555555555555555
#                precision    recall  f1-score   support
#
# correctsource       0.80      0.91      0.85        35
#   wrongsource       0.40      0.20      0.27        10
#
#     micro avg       0.76      0.76      0.76        45
#     macro avg       0.60      0.56      0.56        45
#  weighted avg       0.71      0.76      0.72        45
# /anaconda3/envs/may19_py36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# accuracy = 0.7741935483870968
#                precision    recall  f1-score   support
#
# correctsource       0.77      1.00      0.87        24
#   wrongsource       0.00      0.00      0.00         7
#
#     micro avg       0.77      0.77      0.77        31
#     macro avg       0.39      0.50      0.44        31
#  weighted avg       0.60      0.77      0.68        31
#
# 906145
# training: 40 testing: 27
# correctsource    28
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    19
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.5        0.66666667 0.5        0.66666667 0.8
#  0.6       ]
# Accuracy: 0.6
#                precision    recall  f1-score   support
#
# correctsource       0.70      0.75      0.72        28
#   wrongsource       0.30      0.25      0.27        12
#
#     micro avg       0.60      0.60      0.60        40
#     macro avg       0.50      0.50      0.50        40
#  weighted avg       0.58      0.60      0.59        40
#
# accuracy = 0.5925925925925926
#                precision    recall  f1-score   support
#
# correctsource       0.70      0.74      0.72        19
#   wrongsource       0.29      0.25      0.27         8
#
#     micro avg       0.59      0.59      0.59        27
#     macro avg       0.49      0.49      0.49        27
#  weighted avg       0.58      0.59      0.58        27
#
# 915022
# training: 39 testing: 27
# correctsource    22
# wrongsource      17
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.42857143 0.33333333 0.5        0.6        0.4        0.6
#  0.4       ]
# Accuracy: 0.46153846153846156
#                precision    recall  f1-score   support
#
# correctsource       0.52      0.55      0.53        22
#   wrongsource       0.38      0.35      0.36        17
#
#     micro avg       0.46      0.46      0.46        39
#     macro avg       0.45      0.45      0.45        39
#  weighted avg       0.46      0.46      0.46        39
#
# accuracy = 0.5185185185185185
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.50      0.55        16
#   wrongsource       0.43      0.55      0.48        11
#
#     micro avg       0.52      0.52      0.52        27
#     macro avg       0.52      0.52      0.52        27
#  weighted avg       0.54      0.52      0.52        27
#
# 932933
# training: 40 testing: 27
# correctsource    23
# wrongsource      17
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    15
# wrongsource      12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.57142857 0.42857143 0.66666667 0.4        0.4        0.4
#  0.4       ]
# Accuracy: 0.475
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.52      0.53        23
#   wrongsource       0.39      0.41      0.40        17
#
#     micro avg       0.47      0.47      0.48        40
#     macro avg       0.47      0.47      0.47        40
#  weighted avg       0.48      0.47      0.48        40
#
# accuracy = 0.5185185185185185
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.73      0.63        15
#   wrongsource       0.43      0.25      0.32        12
#
#     micro avg       0.52      0.52      0.52        27
#     macro avg       0.49      0.49      0.47        27
#  weighted avg       0.50      0.52      0.49        27
#
# 936730
# training: 27 testing: 19
# correctsource    18
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    12
# wrongsource       7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.8        0.4        0.75       0.25       0.66666667 0.66666667
#  0.66666667]
# Accuracy: 0.5925925925925926
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.72      0.70        18
#   wrongsource       0.38      0.33      0.35         9
#
#     micro avg       0.59      0.59      0.59        27
#     macro avg       0.53      0.53      0.53        27
#  weighted avg       0.58      0.59      0.59        27
#
# accuracy = 0.6842105263157895
#                precision    recall  f1-score   support
#
# correctsource       0.75      0.75      0.75        12
#   wrongsource       0.57      0.57      0.57         7
#
#     micro avg       0.68      0.68      0.68        19
#     macro avg       0.66      0.66      0.66        19
#  weighted avg       0.68      0.68      0.68        19
#
# 938001
# training: 43 testing: 30
# correctsource    29
# wrongsource      14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    20
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.28571429 0.33333333 0.5        0.5        0.5        0.66666667
#  1.        ]
# Accuracy: 0.5348837209302325
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.62      0.64        29
#   wrongsource       0.31      0.36      0.33        14
#
#     micro avg       0.53      0.53      0.53        43
#     macro avg       0.49      0.49      0.49        43
#  weighted avg       0.55      0.53      0.54        43
#
# accuracy = 0.6333333333333333
#                precision    recall  f1-score   support
#
# correctsource       0.70      0.80      0.74        20
#   wrongsource       0.43      0.30      0.35        10
#
#     micro avg       0.63      0.63      0.63        30
#     macro avg       0.56      0.55      0.55        30
#  weighted avg       0.61      0.63      0.61        30
#
# 955548
# training: 46 testing: 31
# correctsource    35
# wrongsource      11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    23
# wrongsource       8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.57142857 0.57142857 0.57142857 0.71428571 0.83333333 0.5
#  0.83333333]
# Accuracy: 0.6521739130434783
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.80      0.78        35
#   wrongsource       0.22      0.18      0.20        11
#
#     micro avg       0.65      0.65      0.65        46
#     macro avg       0.49      0.49      0.49        46
#  weighted avg       0.63      0.65      0.64        46
#
# accuracy = 0.7741935483870968
#                precision    recall  f1-score   support
#
# correctsource       0.81      0.91      0.86        23
#   wrongsource       0.60      0.38      0.46         8
#
#     micro avg       0.77      0.77      0.77        31
#     macro avg       0.70      0.64      0.66        31
#  weighted avg       0.75      0.77      0.76        31
#
# 968913
# training: 45 testing: 31
# correctsource    36
# wrongsource       9
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    25
# wrongsource       6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.625      0.57142857 0.66666667 0.83333333 0.83333333 0.83333333
#  0.83333333]
# Accuracy: 0.7333333333333333
#                precision    recall  f1-score   support
#
# correctsource       0.79      0.92      0.85        36
#   wrongsource       0.00      0.00      0.00         9
#
#     micro avg       0.73      0.73      0.73        45
#     macro avg       0.39      0.46      0.42        45
#  weighted avg       0.63      0.73      0.68        45
#
# accuracy = 0.7419354838709677
#                precision    recall  f1-score   support
#
# correctsource       0.81      0.88      0.85        25
#   wrongsource       0.25      0.17      0.20         6
#
#     micro avg       0.74      0.74      0.74        31
#     macro avg       0.53      0.52      0.52        31
#  weighted avg       0.71      0.74      0.72        31
#
# 996599
# training: 40 testing: 27
# correctsource    25
# wrongsource      15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    17
# wrongsource      10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.5        0.83333333 0.83333333 0.2        0.6
#  0.6       ]
# Accuracy: 0.625
#                precision    recall  f1-score   support
#
# correctsource       0.69      0.72      0.71        25
#   wrongsource       0.50      0.47      0.48        15
#
#     micro avg       0.62      0.62      0.62        40
#     macro avg       0.60      0.59      0.59        40
#  weighted avg       0.62      0.62      0.62        40
#
# accuracy = 0.5185185185185185
#                precision    recall  f1-score   support
#
# correctsource       0.60      0.71      0.65        17
#   wrongsource       0.29      0.20      0.24        10
#
#     micro avg       0.52      0.52      0.52        27
#     macro avg       0.44      0.45      0.44        27
#  weighted avg       0.48      0.52      0.50        27

# %%
# CORRECT SOURCE VERSUS MISSED TRIAL CLASSIFICATION

# build data structure to store accuracy data and coefficients
cs_miss_data = pd.DataFrame()
cs_miss_data.insert(loc = 0, column = 'dccid', value = 'None', allow_duplicates=True)
# cs_miss_data.insert(loc = 1, column = 'diagnosis', value = 'None', allow_duplicates=True)
for i in range(0, 7):
    cs_miss_data.insert(loc = cs_miss_data.shape[1], column = 'CV'+str(i+1)+'_acc', value = NaN, allow_duplicates=True)
cs_miss_data.insert(loc = cs_miss_data.shape[1], column = 'TrainSet_MeanCV_acc', value = 'None', allow_duplicates=True)
cs_miss_data.insert(loc = cs_miss_data.shape[1], column = 'TestSet_acc', value = 'None', allow_duplicates=True)

for sub in cmiss_subs:
    print(sub)
    sub_data = [sub]
    # load subject's beta maps (one per trial)
    betas = image.load_img(img=os.path.join(beta_dir, str(sub), 'TrialContrasts/betas_sub'+str(sub)+'*.nii'),
                           wildcards=True)
    # initialize NiftiLabelMasker object    
    sub_mask = nb.load(os.path.join(mask_dir, 'func_sub'+str(sub)+'_mask_stereonl.nii'))
    sub_masker = NiftiMasker(mask_img=sub_mask, standardize=True)
                   
    # transform subject's beta maps into vector of network means per trial
    X_cs_ws_miss_ctl = sub_masker.fit_transform(betas) 
    
    # load subject's trial labels
    labels_file = os.path.join(label_dir, 'sub-'+str(sub)+'_ctl_miss_ws_cs.tsv')
    y_cs_ws_miss_ctl = pd.read_csv(labels_file, sep='\t')
    y_cs_ws_miss_ctl_labels = y_cs_ws_miss_ctl['ctl_miss_ws_cs']
    # mask X and y data to exclude trials of no interest
    cs_miss_mask = y_cs_ws_miss_ctl_labels.isin(['correctsource', 'missed'])
    y_cs_miss = y_cs_ws_miss_ctl_labels[cs_miss_mask]      
    X_cs_miss  = X_cs_ws_miss_ctl[cs_miss_mask]
    
    # Split trials into a training and a test set
    X_train, X_test, y_train, y_test = train_test_split(
        X_cs_miss, # x
        y_cs_miss, # y
        test_size = 0.4, # 60%/40% split
        shuffle = True, # shuffle dataset before splitting
        stratify = y_cs_miss, # keep distribution of conditions consistent betw. train & test sets
        #random_state = 123  # if set number, same shuffle each time, otherwise randomization algo
        ) 
    print('training:', len(X_train), 'testing:', len(X_test))
    print(y_train.value_counts(), y_test.value_counts())
    
    # define the model
    sub_svc = SVC(kernel='linear', class_weight='balanced')
    
    # do cross-validation to evaluate model performance
    # within 10 folds of training set
    # predict
    y_pred = cross_val_predict(sub_svc, X_train, y_train,
                               groups=y_train, cv=7)
    # scores
    cv_acc = cross_val_score(sub_svc, X_train, y_train,
                         groups=y_train, cv=7)
    print(cv_acc)
    
    for i in range(0, len(cv_acc)):
        sub_data.append(cv_acc[i])
        
    # evaluate overall model performance on training data
    overall_acc = accuracy_score(y_pred = y_pred, y_true = y_train)
    overall_cr = classification_report(y_pred = y_pred, y_true = y_train)
    print('Accuracy:',overall_acc)
    print(overall_cr)
    
    sub_data.append(overall_acc)

    # Test model on unseen data from the test set
    sub_svc.fit(X_train, y_train)
    y_pred = sub_svc.predict(X_test) # classify age class using testing data
    acc = sub_svc.score(X_test, y_test) # get accuracy

    cr = classification_report(y_pred=y_pred, y_true=y_test) # get prec., recall & f1
    # print results
    print('accuracy =', acc)
    print(cr)  
    
    sub_data.append(acc)
    
    # get map of coefficients    
    # coef_ = sub_svc.coef_
    # print(coef_.shape)
    #Return voxel weights into a nifti image using the NiftiMasker
    # coef_img = sub_masker.inverse_transform(coef_)
    #Save .nii to file
    # coef_img.to_filename(os.path.join(output_dir, 'Coef_maps', 'SVC_coeff_cs_ws_sub-'+str(sub)+'.nii'))
        
    cs_miss_data = cs_miss_data.append(pd.Series(sub_data, index=cs_ws_data.columns), ignore_index=True)
    
cs_miss_data.to_csv(os.path.join(output_dir, 'SVC_withinSub_cs_miss_wholeBrain.tsv'),
    sep='\t', header=True, index=False)
# Out:
# 108391
# training: 34 testing: 24
# correctsource    25
# missed            9
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    18
# missed            6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5  0.5  0.6  0.4  0.75 0.75 0.75]
# Accuracy: 0.5882352941176471
#                precision    recall  f1-score   support
#
# correctsource       0.70      0.76      0.73        25
#        missed       0.14      0.11      0.12         9
#
#     micro avg       0.59      0.59      0.59        34
#     macro avg       0.42      0.44      0.43        34
#  weighted avg       0.56      0.59      0.57        34
#
# accuracy = 0.7083333333333334
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.89      0.82        18
#        missed       0.33      0.17      0.22         6
#
#     micro avg       0.71      0.71      0.71        24
#     macro avg       0.55      0.53      0.52        24
#  weighted avg       0.65      0.71      0.67        24
#
# 122922
# training: 28 testing: 20
# correctsource    15
# missed           13
# Name: ctl_miss_ws_cs, dtype: int64 missed           10
# correctsource    10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.8        0.75       0.75       0.5        0.75       0.75
#  0.33333333]
# Accuracy: 0.6785714285714286
#                precision    recall  f1-score   support
#
# correctsource       0.69      0.73      0.71        15
#        missed       0.67      0.62      0.64        13
#
#     micro avg       0.68      0.68      0.68        28
#     macro avg       0.68      0.67      0.67        28
#  weighted avg       0.68      0.68      0.68        28
#
# accuracy = 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.50      0.50        10
#        missed       0.50      0.50      0.50        10
#
#     micro avg       0.50      0.50      0.50        20
#     macro avg       0.50      0.50      0.50        20
#  weighted avg       0.50      0.50      0.50        20
#
# 139593
# training: 33 testing: 23
# missed           24
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64 missed           17
# correctsource     6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5  0.5  0.8  0.5  0.75 0.75 0.5 ]
# Accuracy: 0.6060606060606061
#                precision    recall  f1-score   support
#
# correctsource       0.00      0.00      0.00         9
#        missed       0.69      0.83      0.75        24
#
#     micro avg       0.61      0.61      0.61        33
#     macro avg       0.34      0.42      0.38        33
#  weighted avg       0.50      0.61      0.55        33
#
# accuracy = 0.6521739130434783
#                precision    recall  f1-score   support
#
# correctsource       0.33      0.33      0.33         6
#        missed       0.76      0.76      0.76        17
#
#     micro avg       0.65      0.65      0.65        23
#     macro avg       0.55      0.55      0.55        23
#  weighted avg       0.65      0.65      0.65        23
#
# 164965
# training: 39 testing: 27
# correctsource    24
# missed           15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    17
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.42857143 0.66666667 0.5        0.6        0.8        0.4
#  0.6       ]
# Accuracy: 0.5641025641025641
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.75      0.68        24
#        missed       0.40      0.27      0.32        15
#
#     micro avg       0.56      0.56      0.56        39
#     macro avg       0.51      0.51      0.50        39
#  weighted avg       0.54      0.56      0.54        39
#
# accuracy = 0.4444444444444444
#                precision    recall  f1-score   support
#
# correctsource       0.55      0.65      0.59        17
#        missed       0.14      0.10      0.12        10
#
#     micro avg       0.44      0.44      0.44        27
#     macro avg       0.35      0.37      0.36        27
#  weighted avg       0.40      0.44      0.42        27
#
# 199801
# training: 20 testing: 14
# missed           11
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64 missed           8
# correctsource    6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.75       0.25       0.66666667 0.33333333 1.         0.5
#  0.        ]
# Accuracy: 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.43      0.33      0.38         9
#        missed       0.54      0.64      0.58        11
#
#     micro avg       0.50      0.50      0.50        20
#     macro avg       0.48      0.48      0.48        20
#  weighted avg       0.49      0.50      0.49        20
#
# accuracy = 0.5714285714285714
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.50      0.50         6
#        missed       0.62      0.62      0.62         8
#
#     micro avg       0.57      0.57      0.57        14
#     macro avg       0.56      0.56      0.56        14
#  weighted avg       0.57      0.57      0.57        14
#
# 247659
# training: 34 testing: 23
# missed           25
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64 missed           17
# correctsource     6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 1.         1.         0.8        1.         0.75
#  0.5       ]
# Accuracy: 0.8235294117647058
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.67      0.67         9
#        missed       0.88      0.88      0.88        25
#
#     micro avg       0.82      0.82      0.82        34
#     macro avg       0.77      0.77      0.77        34
#  weighted avg       0.82      0.82      0.82        34
#
# accuracy = 0.6956521739130435
#                precision    recall  f1-score   support
#
# correctsource       0.40      0.33      0.36         6
#        missed       0.78      0.82      0.80        17
#
#     micro avg       0.70      0.70      0.70        23
#     macro avg       0.59      0.58      0.58        23
#  weighted avg       0.68      0.70      0.69        23
#
# 255499
# training: 39 testing: 27
# correctsource    23
# missed           16
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.42857143 0.71428571 0.8        0.8        0.8        0.8
#  0.6       ]
# Accuracy: 0.6923076923076923
#                precision    recall  f1-score   support
#
# correctsource       0.70      0.83      0.76        23
#        missed       0.67      0.50      0.57        16
#
#     micro avg       0.69      0.69      0.69        39
#     macro avg       0.69      0.66      0.67        39
#  weighted avg       0.69      0.69      0.68        39
#
# accuracy = 0.4444444444444444
#                precision    recall  f1-score   support
#
# correctsource       0.53      0.56      0.55        16
#        missed       0.30      0.27      0.29        11
#
#     micro avg       0.44      0.44      0.44        27
#     macro avg       0.41      0.42      0.42        27
#  weighted avg       0.44      0.44      0.44        27
#
# 258618
# training: 36 testing: 25
# correctsource    20
# missed           16
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.5        0.8        0.6        0.4        0.2
#  0.5       ]
# Accuracy: 0.5277777777777778
#                precision    recall  f1-score   support
#
# correctsource       0.58      0.55      0.56        20
#        missed       0.47      0.50      0.48        16
#
#     micro avg       0.53      0.53      0.53        36
#     macro avg       0.52      0.53      0.52        36
#  weighted avg       0.53      0.53      0.53        36
#
# accuracy = 0.52
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.64      0.60        14
#        missed       0.44      0.36      0.40        11
#
#     micro avg       0.52      0.52      0.52        25
#     macro avg       0.50      0.50      0.50        25
#  weighted avg       0.51      0.52      0.51        25
#
# 271596
# training: 36 testing: 25
# correctsource    22
# missed           14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# missed            9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.83333333 0.8        0.4        0.4        0.6        1.
#  0.2       ]
# Accuracy: 0.6111111111111112
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.73      0.70        22
#        missed       0.50      0.43      0.46        14
#
#     micro avg       0.61      0.61      0.61        36
#     macro avg       0.58      0.58      0.58        36
#  weighted avg       0.60      0.61      0.60        36
# accuracy = 0.56
#                precision    recall  f1-score   support
#
# correctsource       0.63      0.75      0.69        16
#        missed       0.33      0.22      0.27         9
#
#     micro avg       0.56      0.56      0.56        25
#     macro avg       0.48      0.49      0.48        25
#  weighted avg       0.52      0.56      0.53        25
#
# 314409
# training: 40 testing: 28
# correctsource    21
# missed           19
# Name: ctl_miss_ws_cs, dtype: int64 missed           14
# correctsource    14
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.66666667 0.5        0.5        0.83333333 0.4
#  0.6       ]
# Accuracy: 0.575
#                precision    recall  f1-score   support
#
# correctsource       0.60      0.57      0.59        21
#        missed       0.55      0.58      0.56        19
#
#     micro avg       0.57      0.57      0.57        40
#     macro avg       0.57      0.58      0.57        40
#  weighted avg       0.58      0.57      0.58        40
#
# accuracy = 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.57      0.53        14
#        missed       0.50      0.43      0.46        14
#
#     micro avg       0.50      0.50      0.50        28
#     macro avg       0.50      0.50      0.50        28
#  weighted avg       0.50      0.50      0.50        28
#
# 336665
# training: 30 testing: 20
# correctsource    16
# missed           14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    11
# missed            9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.2  0.6  0.75 0.5  1.   0.5  0.5 ]
# Accuracy: 0.5666666666666667
#                precision    recall  f1-score   support
#
# correctsource       0.60      0.56      0.58        16
#        missed       0.53      0.57      0.55        14
#
#     micro avg       0.57      0.57      0.57        30
#     macro avg       0.57      0.57      0.57        30
#  weighted avg       0.57      0.57      0.57        30
#
# accuracy = 0.45
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.36      0.42        11
#        missed       0.42      0.56      0.48         9
#
#     micro avg       0.45      0.45      0.45        20
#     macro avg       0.46      0.46      0.45        20
#  weighted avg       0.46      0.45      0.45        20
#
# 337021
# training: 34 testing: 23
# correctsource    24
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# missed            7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.66666667 0.83333333 0.75       0.75       0.75
#  0.75      ]
# Accuracy: 0.7058823529411765
#                precision    recall  f1-score   support
#
# correctsource       0.75      0.88      0.81        24
#        missed       0.50      0.30      0.37        10
#
#     micro avg       0.71      0.71      0.71        34
#     macro avg       0.62      0.59      0.59        34
#  weighted avg       0.68      0.71      0.68        34
#
# accuracy = 0.6086956521739131
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.88      0.76        16
#        missed       0.00      0.00      0.00         7
#
#     micro avg       0.61      0.61      0.61        23
#     macro avg       0.33      0.44      0.38        23
#  weighted avg       0.46      0.61      0.53        23
#
# 396250
# training: 39 testing: 27
# missed           21
# correctsource    18
# Name: ctl_miss_ws_cs, dtype: int64 missed           14
# correctsource    13
# Name: ctl_miss_ws_cs, dtype: int64
# [0.83333333 0.66666667 0.83333333 0.33333333 0.6        0.6
#  0.4       ]
# Accuracy: 0.6153846153846154
#                precision    recall  f1-score   support
#
# correctsource       0.59      0.56      0.57        18
#        missed       0.64      0.67      0.65        21
#
#     micro avg       0.62      0.62      0.62        39
#     macro avg       0.61      0.61      0.61        39
#  weighted avg       0.61      0.62      0.61        39
#
# accuracy = 0.5185185185185185
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.31      0.38        13
#        missed       0.53      0.71      0.61        14
#
#     micro avg       0.52      0.52      0.52        27
#     macro avg       0.51      0.51      0.49        27
#  weighted avg       0.51      0.52      0.50        27
#
# 403131
# training: 42 testing: 28
# correctsource    23
# missed           19
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.57142857 0.42857143 0.66666667 0.66666667 0.5        0.6
#  0.6       ]
# Accuracy: 0.5714285714285714
#                precision    recall  f1-score   support
#
# correctsource       0.59      0.70      0.64        23
#        missed       0.53      0.42      0.47        19
#
#     micro avg       0.57      0.57      0.57        42
#     macro avg       0.56      0.56      0.56        42
#  weighted avg       0.57      0.57      0.56        42
#
# accuracy = 0.5357142857142857
#                precision    recall  f1-score   support
#
# correctsource       0.58      0.69      0.63        16
#        missed       0.44      0.33      0.38        12
#
#     micro avg       0.54      0.54      0.54        28
#     macro avg       0.51      0.51      0.50        28
#  weighted avg       0.52      0.54      0.52        28
#
# 408506
# training: 30 testing: 21
# missed           16
# correctsource    14
# Name: ctl_miss_ws_cs, dtype: int64 missed           11
# correctsource    10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.4  0.2  0.5  0.75 0.75 0.5  0.5 ]
# Accuracy: 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.45      0.36      0.40        14
#        missed       0.53      0.62      0.57        16
#
#     micro avg       0.50      0.50      0.50        30
#     macro avg       0.49      0.49      0.49        30
#  weighted avg       0.49      0.50      0.49        30
#
# accuracy = 0.6190476190476191
#                precision    recall  f1-score   support
#
# correctsource       0.57      0.80      0.67        10
#        missed       0.71      0.45      0.56        11
#
#     micro avg       0.62      0.62      0.62        21
#     macro avg       0.64      0.63      0.61        21
#  weighted avg       0.65      0.62      0.61        21
#
# 413474
# training: 37 testing: 25
# correctsource    25
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    17
# missed            8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.5        0.66666667 0.66666667 1.         0.5
#  0.75      ]
# Accuracy: 0.6756756756756757
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.76      0.76        25
#        missed       0.50      0.50      0.50        12
#
#     micro avg       0.68      0.68      0.68        37
#     macro avg       0.63      0.63      0.63        37
#  weighted avg       0.68      0.68      0.68        37
#
# accuracy = 0.72
#                precision    recall  f1-score   support
#
# correctsource       0.73      0.94      0.82        17
#        missed       0.67      0.25      0.36         8
#
#     micro avg       0.72      0.72      0.72        25
#     macro avg       0.70      0.60      0.59        25
#  weighted avg       0.71      0.72      0.67        25
#
# 437101
# training: 36 testing: 25
# correctsource    22
# missed           14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# missed            9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.4        0.4        0.4        0.6        0.2
#  0.4       ]
# Accuracy: 0.4444444444444444
#                precision    recall  f1-score   support
#
# correctsource       0.54      0.59      0.57        22
#        missed       0.25      0.21      0.23        14
#
#     micro avg       0.44      0.44      0.44        36
#     macro avg       0.40      0.40      0.40        36
#  weighted avg       0.43      0.44      0.44        36
#
# accuracy = 0.76
#                precision    recall  f1-score   support
#
# correctsource       0.75      0.94      0.83        16
#        missed       0.80      0.44      0.57         9
#
#     micro avg       0.76      0.76      0.76        25
#     macro avg       0.78      0.69      0.70        25
#  weighted avg       0.77      0.76      0.74        25
#
# 439776
# training: 44 testing: 30
# correctsource    33
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    23
# missed            7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.71428571 0.71428571 0.57142857 1.         1.
#  0.6       ]
# Accuracy: 0.75
#                precision    recall  f1-score   support
#
# correctsource       0.79      0.91      0.85        33
#        missed       0.50      0.27      0.35        11
#
#     micro avg       0.75      0.75      0.75        44
#     macro avg       0.64      0.59      0.60        44
#  weighted avg       0.72      0.75      0.72        44
#
# accuracy = 0.6
#                precision    recall  f1-score   support
#
# correctsource       0.74      0.74      0.74        23
#        missed       0.14      0.14      0.14         7
#
#     micro avg       0.60      0.60      0.60        30
#     macro avg       0.44      0.44      0.44        30
#  weighted avg       0.60      0.60      0.60        30
#
# 458807
# training: 36 testing: 24
# correctsource    21
# missed           15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.33333333 0.6        0.6        0.4        1.         0.6
#  0.6       ]
# Accuracy: 0.5833333333333334
#                precision    recall  f1-score   support
#
# correctsource       0.61      0.81      0.69        21
#        missed       0.50      0.27      0.35        15
#
#     micro avg       0.58      0.58      0.58        36
#     macro avg       0.55      0.54      0.52        36
#  weighted avg       0.56      0.58      0.55        36
#
# accuracy = 0.6666666666666666
#                precision    recall  f1-score   support
#
# correctsource       0.69      0.79      0.73        14
#        missed       0.62      0.50      0.56        10
#
#     micro avg       0.67      0.67      0.67        24
#     macro avg       0.66      0.64      0.64        24
#  weighted avg       0.66      0.67      0.66        24
#
# 459801
# training: 31 testing: 21
# correctsource    20
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    13
# missed            8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.2        0.6        0.4        0.2        0.75       1.
#  0.33333333]
# Accuracy: 0.4838709677419355
#                precision    recall  f1-score   support
#
# correctsource       0.60      0.60      0.60        20
#        missed       0.27      0.27      0.27        11
#
#     micro avg       0.48      0.48      0.48        31
#     macro avg       0.44      0.44      0.44        31
#  weighted avg       0.48      0.48      0.48        31
#
# accuracy = 0.7619047619047619
#                precision    recall  f1-score   support
#
# correctsource       0.75      0.92      0.83        13
#        missed       0.80      0.50      0.62         8
#
#     micro avg       0.76      0.76      0.76        21
#     macro avg       0.78      0.71      0.72        21
#  weighted avg       0.77      0.76      0.75        21
#
# 484204
# training: 39 testing: 26
# correctsource    22
# missed           17
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    15
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.33333333 0.5        1.         0.2        0.8
#  0.6       ]
# Accuracy: 0.5897435897435898
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.73      0.67        22
#        missed       0.54      0.41      0.47        17
#
#     micro avg       0.59      0.59      0.59        39
#     macro avg       0.58      0.57      0.57        39
#  weighted avg       0.58      0.59      0.58        39
#
# accuracy = 0.6153846153846154
#                precision    recall  f1-score   support
#
# correctsource       0.65      0.73      0.69        15
#        missed       0.56      0.45      0.50        11
#
#     micro avg       0.62      0.62      0.62        26
#     macro avg       0.60      0.59      0.59        26
#  weighted avg       0.61      0.62      0.61        26
#
# 502616
# training: 31 testing: 21
# correctsource    21
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    15
# missed            6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6  0.8  1.   0.5  0.5  0.75 0.5 ]
# Accuracy: 0.6774193548387096
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.76      0.76        21
#        missed       0.50      0.50      0.50        10
#
#     micro avg       0.68      0.68      0.68        31
#     macro avg       0.63      0.63      0.63        31
#  weighted avg       0.68      0.68      0.68        31
#
# accuracy = 0.3333333333333333
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.33      0.42        15
#        missed       0.17      0.33      0.22         6
#
#     micro avg       0.33      0.33      0.33        21
#     macro avg       0.36      0.33      0.32        21
#  weighted avg       0.44      0.33      0.36        21
#
# 567214
# training: 29 testing: 20
# correctsource    17
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    12
# missed            8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6        0.6        0.2        0.5        0.5        0.66666667
#  0.33333333]
# Accuracy: 0.4827586206896552
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.59      0.57        17
#        missed       0.36      0.33      0.35        12
#
#     micro avg       0.48      0.48      0.48        29
#     macro avg       0.46      0.46      0.46        29
#  weighted avg       0.48      0.48      0.48        29
#
# accuracy = 0.65
#                precision    recall  f1-score   support
#
# correctsource       0.69      0.75      0.72        12
#        missed       0.57      0.50      0.53         8
#
#     micro avg       0.65      0.65      0.65        20
#     macro avg       0.63      0.62      0.63        20
#  weighted avg       0.64      0.65      0.65        20
#
# 597569
# training: 39 testing: 27
# correctsource    28
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    20
# missed            7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.33333333 0.5        0.5        0.8        1.
#  0.6       ]
# Accuracy: 0.5897435897435898
#                precision    recall  f1-score   support
#
# correctsource       0.71      0.71      0.71        28
#        missed       0.27      0.27      0.27        11
#
#     micro avg       0.59      0.59      0.59        39
#     macro avg       0.49      0.49      0.49        39
#  weighted avg       0.59      0.59      0.59        39
#
# accuracy = 0.5555555555555556
#                precision    recall  f1-score   support
#
# correctsource       0.72      0.65      0.68        20
#        missed       0.22      0.29      0.25         7
#
#     micro avg       0.56      0.56      0.56        27
#     macro avg       0.47      0.47      0.47        27
#  weighted avg       0.59      0.56      0.57        27
#
# 652850
# training: 34 testing: 23
# missed           21
# correctsource    13
# Name: ctl_miss_ws_cs, dtype: int64 missed           15
# correctsource     8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6 0.6 0.2 0.2 0.4 0.4 0.5]
# Accuracy: 0.4117647058823529
#                precision    recall  f1-score   support
#
# correctsource       0.23      0.23      0.23        13
#        missed       0.52      0.52      0.52        21
#
#     micro avg       0.41      0.41      0.41        34
#     macro avg       0.38      0.38      0.38        34
#  weighted avg       0.41      0.41      0.41        34
#
# accuracy = 0.4782608695652174
#                precision    recall  f1-score   support
#
# correctsource       0.30      0.38      0.33         8
#        missed       0.62      0.53      0.57        15
#
#     micro avg       0.48      0.48      0.48        23
#     macro avg       0.46      0.45      0.45        23
#  weighted avg       0.51      0.48      0.49        23
#
# 677561
# training: 32 testing: 22
# correctsource    20
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# missed            8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6        0.8        0.8        0.6        0.8        0.25
#  0.66666667]
# Accuracy: 0.65625
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.85      0.76        20
#        missed       0.57      0.33      0.42        12
#
#     micro avg       0.66      0.66      0.66        32
#     macro avg       0.63      0.59      0.59        32
#  weighted avg       0.64      0.66      0.63        32
#
# accuracy = 0.5909090909090909
#                precision    recall  f1-score   support
#
# correctsource       0.67      0.71      0.69        14
#        missed       0.43      0.38      0.40         8
#
#     micro avg       0.59      0.59      0.59        22
#     macro avg       0.55      0.54      0.54        22
#  weighted avg       0.58      0.59      0.58        22
#
# 711830
# training: 36 testing: 25
# missed           21
# correctsource    15
# Name: ctl_miss_ws_cs, dtype: int64 missed           14
# correctsource    11
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5 0.2 0.6 0.6 0.6 0.8 0.6]
# Accuracy: 0.5555555555555556
#                precision    recall  f1-score   support
#
# correctsource       0.47      0.47      0.47        15
#        missed       0.62      0.62      0.62        21
#
#     micro avg       0.56      0.56      0.56        36
#     macro avg       0.54      0.54      0.54        36
#  weighted avg       0.56      0.56      0.56        36
#
# accuracy = 0.52
#                precision    recall  f1-score   support
#
# correctsource       0.44      0.36      0.40        11
#        missed       0.56      0.64      0.60        14
#
#     micro avg       0.52      0.52      0.52        25
#     macro avg       0.50      0.50      0.50        25
#  weighted avg       0.51      0.52      0.51        25
#
# 729722
# training: 40 testing: 28
# correctsource    26
# missed           14
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    18
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.83333333 0.66666667 0.83333333 0.83333333 0.83333333 0.6
#  0.8       ]
# Accuracy: 0.775
#                precision    recall  f1-score   support
#
# correctsource       0.77      0.92      0.84        26
#        missed       0.78      0.50      0.61        14
#
#     micro avg       0.78      0.78      0.78        40
#     macro avg       0.78      0.71      0.73        40
#  weighted avg       0.78      0.78      0.76        40
#
# accuracy = 0.6428571428571429
#                precision    recall  f1-score   support
#
# correctsource       0.72      0.72      0.72        18
#        missed       0.50      0.50      0.50        10
#
#     micro avg       0.64      0.64      0.64        28
#     macro avg       0.61      0.61      0.61        28
#  weighted avg       0.64      0.64      0.64        28
#
# 739694
# training: 32 testing: 22
# correctsource    20
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# missed            8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.4        0.4        0.2        0.8        0.6        0.75
#  0.33333333]
# Accuracy: 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.59      0.65      0.62        20
#        missed       0.30      0.25      0.27        12
#
#     micro avg       0.50      0.50      0.50        32
#     macro avg       0.45      0.45      0.45        32
#  weighted avg       0.48      0.50      0.49        32
#
# accuracy = 0.4090909090909091
#                precision    recall  f1-score   support
#
# correctsource       0.54      0.50      0.52        14
#        missed       0.22      0.25      0.24         8
#
#     micro avg       0.41      0.41      0.41        22
#     macro avg       0.38      0.38      0.38        22
#  weighted avg       0.42      0.41      0.42        22
#
# 748676
# training: 36 testing: 24
# missed           26
# correctsource    10
# Name: ctl_miss_ws_cs, dtype: int64 missed           18
# correctsource     6
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.5        0.5        0.4        0.6        0.75
#  0.5       ]
# Accuracy: 0.5555555555555556
#                precision    recall  f1-score   support
#
# correctsource       0.00      0.00      0.00        10
#        missed       0.67      0.77      0.71        26
#
#     micro avg       0.56      0.56      0.56        36
#     macro avg       0.33      0.38      0.36        36
#  weighted avg       0.48      0.56      0.52        36
#
# accuracy = 0.625
#                precision    recall  f1-score   support
#
# correctsource       0.00      0.00      0.00         6
#        missed       0.71      0.83      0.77        18
#
#     micro avg       0.62      0.62      0.62        24
#     macro avg       0.36      0.42      0.38        24
#  weighted avg       0.54      0.62      0.58        24
#
# 778749
# training: 33 testing: 22
# missed           19
# correctsource    14
# Name: ctl_miss_ws_cs, dtype: int64 missed           13
# correctsource     9
# Name: ctl_miss_ws_cs, dtype: int64
# [0.6 0.6 0.4 0.4 0.4 0.5 1. ]
# Accuracy: 0.5454545454545454
#                precision    recall  f1-score   support
#
# correctsource       0.47      0.57      0.52        14
#        missed       0.62      0.53      0.57        19
#
#     micro avg       0.55      0.55      0.55        33
#     macro avg       0.55      0.55      0.54        33
#  weighted avg       0.56      0.55      0.55        33
#
# accuracy = 0.5454545454545454
#                precision    recall  f1-score   support
#
# correctsource       0.45      0.56      0.50         9
#        missed       0.64      0.54      0.58        13
#
#     micro avg       0.55      0.55      0.55        22
#     macro avg       0.55      0.55      0.54        22
#  weighted avg       0.56      0.55      0.55        22
#
# 783781
# training: 34 testing: 23
# correctsource    24
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    16
# missed            7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.33333333 0.5        0.75       0.5        0.75
#  0.5       ]
# Accuracy: 0.5294117647058824
#                precision    recall  f1-score   support
#
# correctsource       0.65      0.71      0.68        24
#        missed       0.12      0.10      0.11        10
#
#     micro avg       0.53      0.53      0.53        34
#     macro avg       0.39      0.40      0.40        34
#  weighted avg       0.50      0.53      0.51        34
#
# accuracy = 0.6086956521739131
#                precision    recall  f1-score   support
#
# correctsource       0.71      0.75      0.73        16
#        missed       0.33      0.29      0.31         7
#
#     micro avg       0.61      0.61      0.61        23
#     macro avg       0.52      0.52      0.52        23
#  weighted avg       0.59      0.61      0.60        23
#
# 884343
# training: 32 testing: 22
# correctsource    17
# missed           15
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    12
# missed           10
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.4        0.8        0.25       0.75       0.5
#  0.75      ]
# Accuracy: 0.59375
#                precision    recall  f1-score   support
#
# correctsource       0.61      0.65      0.63        17
#        missed       0.57      0.53      0.55        15
#
#     micro avg       0.59      0.59      0.59        32
#     macro avg       0.59      0.59      0.59        32
#  weighted avg       0.59      0.59      0.59        32
#
# accuracy = 0.3181818181818182
#                precision    recall  f1-score   support
#
# correctsource       0.36      0.33      0.35        12
#        missed       0.27      0.30      0.29        10
#
#     micro avg       0.32      0.32      0.32        22
#     macro avg       0.32      0.32      0.32        22
#  weighted avg       0.32      0.32      0.32        22
#
# 886007
# training: 39 testing: 26
# correctsource    27
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    18
# missed            8
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.33333333 0.5        0.66666667 0.5        0.6
#  0.5       ]
# Accuracy: 0.5384615384615384
#                precision    recall  f1-score   support
#
# correctsource       0.65      0.74      0.69        27
#        missed       0.12      0.08      0.10        12
#
#     micro avg       0.54      0.54      0.54        39
#     macro avg       0.39      0.41      0.39        39
#  weighted avg       0.49      0.54      0.51        39
#
# accuracy = 0.6153846153846154
#                precision    recall  f1-score   support
#
# correctsource       0.68      0.83      0.75        18
#        missed       0.25      0.12      0.17         8
#
#     micro avg       0.62      0.62      0.62        26
#     macro avg       0.47      0.48      0.46        26
#  weighted avg       0.55      0.62      0.57        26
#
# 936730
# training: 36 testing: 24
# missed           18
# correctsource    18
# Name: ctl_miss_ws_cs, dtype: int64 missed           12
# correctsource    12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.66666667 0.66666667 0.5        0.33333333 0.75       0.75
#  0.5       ]
# Accuracy: 0.5833333333333334
#                precision    recall  f1-score   support
#
# correctsource       0.59      0.56      0.57        18
#        missed       0.58      0.61      0.59        18
#
#     micro avg       0.58      0.58      0.58        36
#     macro avg       0.58      0.58      0.58        36
#  weighted avg       0.58      0.58      0.58        36
# accuracy = 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.50      0.50      0.50        12
#        missed       0.50      0.50      0.50        12
#
#     micro avg       0.50      0.50      0.50        24
#     macro avg       0.50      0.50      0.50        24
#  weighted avg       0.50      0.50      0.50        24
#
# 956130
# training: 38 testing: 26
# missed           20
# correctsource    18
# Name: ctl_miss_ws_cs, dtype: int64 missed           13
# correctsource    13
# Name: ctl_miss_ws_cs, dtype: int64
# [0.33333333 0.5        0.5        0.16666667 0.4        0.6
#  0.25      ]
# Accuracy: 0.39473684210526316
#                precision    recall  f1-score   support
#
# correctsource       0.33      0.28      0.30        18
#        missed       0.43      0.50      0.47        20
#
#     micro avg       0.39      0.39      0.39        38
#     macro avg       0.38      0.39      0.38        38
#  weighted avg       0.39      0.39      0.39        38
#
# accuracy = 0.5384615384615384
#                precision    recall  f1-score   support
#
# correctsource       0.56      0.38      0.45        13
#        missed       0.53      0.69      0.60        13
#
#     micro avg       0.54      0.54      0.54        26
#     macro avg       0.54      0.54      0.53        26
#  weighted avg       0.54      0.54      0.53        26
#
# 983291
# training: 40 testing: 28
# correctsource    29
# missed           11
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    21
# missed            7
# Name: ctl_miss_ws_cs, dtype: int64
# [0.71428571 0.83333333 0.5        0.5        0.6        0.4
#  0.8       ]
# Accuracy: 0.625
#                precision    recall  f1-score   support
#
# correctsource       0.72      0.79      0.75        29
#        missed       0.25      0.18      0.21        11
#
#     micro avg       0.62      0.62      0.62        40
#     macro avg       0.48      0.49      0.48        40
#  weighted avg       0.59      0.62      0.60        40
#
# accuracy = 0.6428571428571429
#                precision    recall  f1-score   support
#
# correctsource       0.76      0.76      0.76        21
#        missed       0.29      0.29      0.29         7
#
#     micro avg       0.64      0.64      0.64        28
#     macro avg       0.52      0.52      0.52        28
#  weighted avg       0.64      0.64      0.64        28
#
# 998166
# training: 37 testing: 26
# correctsource    21
# missed           16
# Name: ctl_miss_ws_cs, dtype: int64 correctsource    14
# missed           12
# Name: ctl_miss_ws_cs, dtype: int64
# [0.5        0.66666667 0.8        0.4        0.6        0.6
#  0.4       ]
# Accuracy: 0.5675675675675675
#                precision    recall  f1-score   support
#
# correctsource       0.62      0.62      0.62        21
#        missed       0.50      0.50      0.50        16
#
#     micro avg       0.57      0.57      0.57        37
#     macro avg       0.56      0.56      0.56        37
#  weighted avg       0.57      0.57      0.57        37
#
# accuracy = 0.5
#                precision    recall  f1-score   support
#
# correctsource       0.53      0.64      0.58        14
#        missed       0.44      0.33      0.38        12
#
#     micro avg       0.50      0.50      0.50        26
#     macro avg       0.49      0.49      0.48        26
#  weighted avg       0.49      0.50      0.49        26
