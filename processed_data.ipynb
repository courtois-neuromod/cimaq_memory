# %% [markdown]
# # CIMAQ processed data analysis

# %%
import json
import os
from os import listdir as ls
from os.path import basename as bname
from os.path import dirname as dname
from os.path import join
import pandas as pd
from pandas import DataFrame as df
from cimaq_utils import loadimages

# Define main directory
maindir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data"
filelist = dict([(item, (len(ls(join(maindir, item))), ls(join(maindir, item))))
                  for item in ls(maindir)])
display(filelist)

# Participants info sheets
participants_dir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/participants"

# Contents
participants_lists = [(file, pd.read_csv(join(participants_dir, file), sep='\t'))
                     for file in ls(participants_dir)
                     if file.endswith('.tsv')]
participants_jsonfiles = [(file, json.load(open(join(participants_dir, file))))
                         for file in ls(participants_dir)
                         if file.endswith('.json')]

# Tables & tests are already summed up in this file
npsyfile = pd.read_csv(join(participants_dir, "Neuropsych", "ALL_Neuropsych_scores.tsv"), sep='\t')
motionfile =  pd.read_csv(join(participants_dir, "MotionResults", "fMRI_meanMotion.tsv"), sep='\t')

# Niftii images diectrories
masks_dir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/masks"
fmri_resample_dir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/fmri/resample"
features_betamaps_dir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/features/beta_maps"

# Already sorted in https://github.com/FrancoisNadeau/cimaq_memory/blob/master/get_behav.ipynb
taskfiles_dir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed"

anat_dir =  "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/anat"
confouds_dir = "../../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/confounds/resample"
# p1['modalities'] = [ls(join(maindir, row[0], 'ses-4'))
#               for row in p1.iterrows()]
# p1['anat'] = [ls(join(maindir, row[0], 'ses-4', 'anat'))
#               for row in p1.iterrows()]
# p1['n_anat'] = [len(row[1]['anat']) for row in p1.iterrows()]
# p1['dwi'] = [ls(join(maindir, row[0], 'ses-4', 'dwi'))
#               for row in p1.iterrows()]
# p1['func'] = [ls(join(maindir, row[0], 'ses-4', 'func'))
#               for row in p1.iterrows()]
# p1['n_dwi'] = [len(row[1]['dwi']) for row in p1.iterrows()]
# p1['n_func'] = [len(row[1]['func']) for row in p1.iterrows()]
# Out:
# {'templates': (1, ['MIST_parcellation']),
#  'participants': (14,
#   ['sublist_3.tsv',
#    'sublist_4.tsv',
#    'Neuropsych',
#    'sub_list.tsv',
#    'TaskResults',
#    'sublist_2.tsv',
#    'Participants_bids.tsv',
#    'MotionResults',
#    'Participants_bids_headers.json',
#    'Splitting_list.tsv',
#    'MemoTaskParticipantFile_headers.json',
#    'MemoTaskParticipantFile.tsv',
#    'sublist_1.tsv',
#    'sub_list_TaskQC.tsv']),
#  'masks': (101,
#   ['func_sub711830_mask_stereonl.nii',
#    'func_sub437101_mask_stereonl.nii',
#    'func_sub413474_mask_stereonl.nii',
#    'func_sub164965_mask_stereonl.nii',
#    'func_sub785217_mask_stereonl.nii',
#    'func_sub439776_mask_stereonl.nii',
#    'func_sub893978_mask_stereonl.nii',
#    'func_sub630120_mask_stereonl.nii',
#    'func_sub866812_mask_stereonl.nii',
#    'func_sub267168_mask_stereonl.nii',
#    'func_sub804743_mask_stereonl.nii',
#    'func_sub127228_mask_stereonl.nii',
#    'func_sub968913_mask_stereonl.nii',
#    'func_sub108391_mask_stereonl.nii',
#    'func_sub914042_mask_stereonl.nii',
#    'func_sub484204_mask_stereonl.nii',
#    'func_sub886007_mask_stereonl.nii',
#    'func_sub996599_mask_stereonl.nii',
#    'func_sub956049_mask_stereonl.nii',
#    'func_sub906145_mask_stereonl.nii',
#    'func_sub199801_mask_stereonl.nii',
#    'func_sub956130_mask_stereonl.nii',
#    'func_sub739694_mask_stereonl.nii',
#    'func_sub668786_mask_stereonl.nii',
#    'func_sub318809_mask_stereonl.nii',
#    'func_sub763590_mask_stereonl.nii',
#    'func_sub979001_mask_stereonl.nii',
#    'func_sub175295_mask_stereonl.nii',
#    'func_sub983291_mask_stereonl.nii',
#    'func_sub408506_mask_stereonl.nii',
#    'func_sub350555_mask_stereonl.nii',
#    'func_sub122922_mask_stereonl.nii',
#    'func_sub955548_mask_stereonl.nii',
#    'func_sub255499_mask_stereonl.nii',
#    'func_sub258618_mask_stereonl.nii',
#    'func_sub270218_mask_stereonl.nii',
#    'func_sub370092_mask_stereonl.nii',
#    'func_sub901551_mask_stereonl.nii',
#    'func_sub337021_mask_stereonl.nii',
#    'func_sub441008_mask_stereonl.nii',
#    'func_sub197192_mask_stereonl.nii',
#    'func_sub597569_mask_stereonl.nii',
#    'func_sub677561_mask_stereonl.nii',
#    'func_sub974246_mask_stereonl.nii',
#    'func_sub219637_mask_stereonl.nii',
#    'func_sub247659_mask_stereonl.nii',
#    'func_sub517070_mask_stereonl.nii',
#    'func_sub555537_mask_stereonl.nii',
#    'func_sub628299_mask_stereonl.nii',
#    'func_sub658178_mask_stereonl.nii',
#    'func_sub386333_mask_stereonl.nii',
#    'func_sub659068_mask_stereonl.nii',
#    'func_sub271596_mask_stereonl.nii',
#    'func_sub195016_mask_stereonl.nii',
#    'func_sub189005_mask_stereonl.nii',
#    'func_sub254402_mask_stereonl.nii',
#    'func_sub936730_mask_stereonl.nii',
#    'func_sub396250_mask_stereonl.nii',
#    'func_sub458807_mask_stereonl.nii',
#    'func_sub336665_mask_stereonl.nii',
#    'func_sub778749_mask_stereonl.nii',
#    'func_sub120839_mask_stereonl.nii',
#    'func_sub938001_mask_stereonl.nii',
#    'func_sub139593_mask_stereonl.nii',
#    'func_sub502616_mask_stereonl.nii',
#    'func_sub998166_mask_stereonl.nii',
#    'func_sub783781_mask_stereonl.nii',
#    'func_sub388174_mask_stereonl.nii',
#    'func_sub567214_mask_stereonl.nii',
#    'func_sub915022_mask_stereonl.nii',
#    'func_sub326073_mask_stereonl.nii',
#    'func_sub258912_mask_stereonl.nii',
#    'func_sub549994_mask_stereonl.nii',
#    'func_sub652850_mask_stereonl.nii',
#    'func_sub517404_mask_stereonl.nii',
#    'func_sub988602_mask_stereonl.nii',
#    'func_sub403131_mask_stereonl.nii',
#    'func_sub463105_mask_stereonl.nii',
#    'func_sub324734_mask_stereonl.nii',
#    'func_sub543589_mask_stereonl.nii',
#    'func_sub729722_mask_stereonl.nii',
#    'func_sub314409_mask_stereonl.nii',
#    'func_sub490035_mask_stereonl.nii',
#    'func_sub884343_mask_stereonl.nii',
#    'func_sub229301_mask_stereonl.nii',
#    'func_sub147863_mask_stereonl.nii',
#    'func_sub932933_mask_stereonl.nii',
#    'func_sub385370_mask_stereonl.nii',
#    'func_sub878354_mask_stereonl.nii',
#    'func_sub462345_mask_stereonl.nii',
#    'func_sub920577_mask_stereonl.nii',
#    'func_sub845675_mask_stereonl.nii',
#    'func_sub459801_mask_stereonl.nii',
#    'func_sub427357_mask_stereonl.nii',
#    'func_sub254530_mask_stereonl.nii',
#    'func_sub178101_mask_stereonl.nii',
#    'func_sub748676_mask_stereonl.nii',
#    'func_sub150649_mask_stereonl.nii',
#    'func_sub520377_mask_stereonl.nii',
#    'func_sub785245_mask_stereonl.nii',
#    'func_sub619278_mask_stereonl.nii']),
#  'fmri': (1, ['resample']),
#  'features': (1, ['beta_maps']),
#  'task_files': (5,
#   ['TaskFile_headers_CIMAQ_memory.json',
#    'events',
#    'zipped_eprime',
#    'PostScanBehav_CIMAQ_memory.json',
#    'processed']),
#  'anat': (101,
#   ['anat_sub668786_nuc_stereonl.nii',
#    'anat_sub484204_nuc_stereonl.nii',
#    'anat_sub785217_nuc_stereonl.nii',
#    'anat_sub555537_nuc_stereonl.nii',
#    'anat_sub336665_nuc_stereonl.nii',
#    'anat_sub462345_nuc_stereonl.nii',
#    'anat_sub195016_nuc_stereonl.nii',
#    'anat_sub318809_nuc_stereonl.nii',
#    'anat_sub370092_nuc_stereonl.nii',
#    'anat_sub458807_nuc_stereonl.nii',
#    'anat_sub427357_nuc_stereonl.nii',
#    'anat_sub408506_nuc_stereonl.nii',
#    'anat_sub677561_nuc_stereonl.nii',
#    'anat_sub413474_nuc_stereonl.nii',
#    'anat_sub543589_nuc_stereonl.nii',
#    'anat_sub920577_nuc_stereonl.nii',
#    'anat_sub441008_nuc_stereonl.nii',
#    'anat_sub783781_nuc_stereonl.nii',
#    'anat_sub120839_nuc_stereonl.nii',
#    'anat_sub164965_nuc_stereonl.nii',
#    'anat_sub845675_nuc_stereonl.nii',
#    'anat_sub884343_nuc_stereonl.nii',
#    'anat_sub385370_nuc_stereonl.nii',
#    'anat_sub255499_nuc_stereonl.nii',
#    'anat_sub628299_nuc_stereonl.nii',
#    'anat_sub270218_nuc_stereonl.nii',
#    'anat_sub878354_nuc_stereonl.nii',
#    'anat_sub729722_nuc_stereonl.nii',
#    'anat_sub517404_nuc_stereonl.nii',
#    'anat_sub988602_nuc_stereonl.nii',
#    'anat_sub463105_nuc_stereonl.nii',
#    'anat_sub914042_nuc_stereonl.nii',
#    'anat_sub175295_nuc_stereonl.nii',
#    'anat_sub139593_nuc_stereonl.nii',
#    'anat_sub396250_nuc_stereonl.nii',
#    'anat_sub998166_nuc_stereonl.nii',
#    'anat_sub199801_nuc_stereonl.nii',
#    'anat_sub968913_nuc_stereonl.nii',
#    'anat_sub936730_nuc_stereonl.nii',
#    'anat_sub804743_nuc_stereonl.nii',
#    'anat_sub388174_nuc_stereonl.nii',
#    'anat_sub932933_nuc_stereonl.nii',
#    'anat_sub652850_nuc_stereonl.nii',
#    'anat_sub147863_nuc_stereonl.nii',
#    'anat_sub658178_nuc_stereonl.nii',
#    'anat_sub150649_nuc_stereonl.nii',
#    'anat_sub659068_nuc_stereonl.nii',
#    'anat_sub178101_nuc_stereonl.nii',
#    'anat_sub439776_nuc_stereonl.nii',
#    'anat_sub974246_nuc_stereonl.nii',
#    'anat_sub906145_nuc_stereonl.nii',
#    'anat_sub254402_nuc_stereonl.nii',
#    'anat_sub956049_nuc_stereonl.nii',
#    'anat_sub337021_nuc_stereonl.nii',
#    'anat_sub886007_nuc_stereonl.nii',
#    'anat_sub983291_nuc_stereonl.nii',
#    'anat_sub197192_nuc_stereonl.nii',
#    'anat_sub254530_nuc_stereonl.nii',
#    'anat_sub748676_nuc_stereonl.nii',
#    'anat_sub739694_nuc_stereonl.nii',
#    'anat_sub490035_nuc_stereonl.nii',
#    'anat_sub996599_nuc_stereonl.nii',
#    'anat_sub938001_nuc_stereonl.nii',
#    'anat_sub956130_nuc_stereonl.nii',
#    'anat_sub955548_nuc_stereonl.nii',
#    'anat_sub229301_nuc_stereonl.nii',
#    'anat_sub247659_nuc_stereonl.nii',
#    'anat_sub597569_nuc_stereonl.nii',
#    'anat_sub326073_nuc_stereonl.nii',
#    'anat_sub630120_nuc_stereonl.nii',
#    'anat_sub324734_nuc_stereonl.nii',
#    'anat_sub778749_nuc_stereonl.nii',
#    'anat_sub567214_nuc_stereonl.nii',
#    'anat_sub127228_nuc_stereonl.nii',
#    'anat_sub979001_nuc_stereonl.nii',
#    'anat_sub219637_nuc_stereonl.nii',
#    'anat_sub437101_nuc_stereonl.nii',
#    'anat_sub785245_nuc_stereonl.nii',
#    'anat_sub763590_nuc_stereonl.nii',
#    'anat_sub258912_nuc_stereonl.nii',
#    'anat_sub502616_nuc_stereonl.nii',
#    'anat_sub549994_nuc_stereonl.nii',
#    'anat_sub108391_nuc_stereonl.nii',
#    'anat_sub915022_nuc_stereonl.nii',
#    'anat_sub189005_nuc_stereonl.nii',
#    'anat_sub619278_nuc_stereonl.nii',
#    'anat_sub271596_nuc_stereonl.nii',
#    'anat_sub267168_nuc_stereonl.nii',
#    'anat_sub893978_nuc_stereonl.nii',
#    'anat_sub459801_nuc_stereonl.nii',
#    'anat_sub122922_nuc_stereonl.nii',
#    'anat_sub901551_nuc_stereonl.nii',
#    'anat_sub517070_nuc_stereonl.nii',
#    'anat_sub403131_nuc_stereonl.nii',
#    'anat_sub711830_nuc_stereonl.nii',
#    'anat_sub866812_nuc_stereonl.nii',
#    'anat_sub520377_nuc_stereonl.nii',
#    'anat_sub314409_nuc_stereonl.nii',
#    'anat_sub350555_nuc_stereonl.nii',
#    'anat_sub258618_nuc_stereonl.nii',
#    'anat_sub386333_nuc_stereonl.nii']),
#  'confounds': (1, ['resample'])}
