# %% [markdown]
# # CIMA-Q 2019-09-01 Release patch 0.1
#
# #### Visualize and append missing data from previous cmiaq_03-19 release to cimaq_20190901 (current release)
#
# ### Missing data in question includes both:
# #### - In-scan behavioral data 'events.tsv' files
# #### - Offline delayed retrieval data 'behavioral.tsv' files

# %%
import json
import os
from os import listdir as ls
from os.path import basename as bname
from os.path import dirname as dname
from os.path import join
import pandas as pd
from pandas import DataFrame as df
from cimaq_utils import loadimages

# %% [markdown]
# ## Get CIMQA-Q 'events.tsv' files
# #### Name each file according to BIDS specification
# #### - In conformity with CIMA-Q release found in /data/simexp/DATA/cimaq_20190901
#         - The files are present, but in a distant subdirectory in the previous release
#         - path: '/data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed'
# #### Files correspond to regular BIDS 'events.tsv' files describing trial-based information
# ##### - trial type, stimuli onset & offset, participants' response times, etc.

# %%
# List of data tuples (filename, filepath, DataFrame)
# Note: filenames contain both 7-digits & 6-digits participant identifiers.
#       Datas in cimaq_20190901 use the 7-digits ID to reference participants
maindir = "../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed"
allevents = sorted([(os.path.splitext(bname(file))[0],
                     pd.read_csv(file, sep='\t').set_index("onset"), file)
                        for file in loadimages(maindir) if 'events' in file
                        and file.endswith('.tsv')])
# display(allevents[77][0], allevents[77][1], allevents[77][2])
display(allevents[0][0], allevents[0][1], allevents[0][2])
# Out:
# 'sub-108391_ses-4_task-memory_events'
#          trial_number  duration   offset trial_type  response  response_time  \
# onset
# 11.537              4     3.009   14.546        CTL       1.0          0.615
# 20.046              5     3.009   23.055        Enc       1.0          0.666
# 23.556              6     3.009   26.565        Enc       1.0          0.708
# 27.552              7     3.009   30.561        Enc       1.0          0.600
# 31.564              8     3.009   34.573        Enc       1.0          0.747
# ...               ...       ...      ...        ...       ...            ...
# 694.428           116     3.009  697.437        Enc       1.0          0.811
# 703.438           117     3.009  706.447        CTL       1.0          0.705
# 716.945           118     3.009  719.954        Enc       1.0          0.813
# 724.952           119     3.009  727.961        Enc       1.0          0.814
# 728.948           120     3.009  731.957        Enc       1.0          0.578
#
#         stim_id stim_file stim_category          stim_name  \
# onset
# 11.537      NaN      None          None               None
# 20.046    Old65      None      sporting    soccer ball_new
# 23.556    Old07      None        animal           lion_new
# 27.552    Old15      None          food  bottleofredwine01
# 31.564    Old69      None         fruit          lemon_new
# ...         ...       ...           ...                ...
# 694.428   Old52      None       musical      xylophone_old
# 703.438     NaN      None          None               None
# 716.945   Old18      None          food          cracker02
# 724.952   Old35      None       kitchen              plate
# 728.948   Old20      None          food        frenchfries
#
#          recognition_accuracy  recognition_responsetime  position_correct  \
# onset
# 11.537                     -1                       NaN                 8
# 20.046                      0                     1.915                 6
# 23.556                      0                     1.450                 5
# 27.552                      1                     3.335                 6
# 31.564                      0                     0.775                 9
# ...                       ...                       ...               ...
# 694.428                     1                     1.210                 6
# 703.438                    -1                       NaN                 9
# 716.945                     1                     0.836                 5
# 724.952                     1                     1.332                 5
# 728.948                     1                     0.800                 8
#
#          position_response  position_accuracy  position_responsetime
# onset
# 11.537                -1.0                 -1                    NaN
# 20.046                -1.0                  0                    NaN
# 23.556                -1.0                  0                    NaN
# 27.552                 9.0                  1                  3.786
# 31.564                -1.0                  0                    NaN
# ...                    ...                ...                    ...
# 694.428                6.0                  2                  0.977
# 703.438               -1.0                 -1                    NaN
# 716.945                5.0                  2                  1.298
# 724.952                5.0                  2                  2.982
# 728.948                8.0                  2                  0.559
#
# [117 rows x 16 columns]
# '../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed/sub-108391_ses-4_task-memory_events.tsv'

# %% [markdown]
# ## Get CIMA-Q 'behavioral.tsv' files
# #### Name each file according to BIDS specification
# #### - In conformity with CIMA-Q release found in /data/simexp/DATA/cimaq_20190901

# %%
# List of data tuples (filename, filepath, DataFrame)
# Note: filenames contain both 7-digits & 6-digits participant identifiers.
#       Datas in cimaq_20190901 use the 7-digits ID to reference participants
allbehavs = sorted([(os.path.splitext(bname(file))[0],
                     pd.read_csv(file, sep='\t').set_index("trial_number"), file)
                    for file in loadimages(maindir)
                    if 'PostScan' in file and file.endswith('.tsv')])
display(allbehavs[77][0], allbehavs[77][1], allbehavs[77][2])
# Out:
# 'PostScanBehav_pscid7674650_dccid729722'
#              old_new                    stim_file stim_id stim_category  \
# trial_number
# 1                OLD          food_shellpasta.bmp   Old25          food
# 2                New         kitchen_fork_old.bmp   New18       kitchen
# 3                OLD     fruit_blackberry_new.bmp   Old66         fruit
# 4                New  sporting_basketball_new.bmp   New14      sporting
# 5                New       animal_dolphin_old.bmp   New09        animal
# ...              ...                          ...     ...           ...
# 113              OLD  kitchen_scrubbing brush.bmp   Old36       kitchen
# 114              New           animal_ostrich.bmp   New26        animal
# 115              OLD     vegie_green capsicum.bmp   Old75         vegie
# 116              OLD           animal_cheetah.bmp   Old02        animal
# 117              New        sporting_windsurf.bmp   New31      sporting
#
#                     stim_name  recognition_response  recognition_accuracy  \
# trial_number
# 1                  shellpasta                     1                     1
# 2                    fork_old                     2                     1
# 3              blackberry_new                     1                     1
# 4              basketball_new                     2                     1
# 5                 dolphin_old                     2                     1
# ...                       ...                   ...                   ...
# 113           scrubbing brush                     2                     0
# 114                   ostrich                     2                     1
# 115            green capsicum                     1                     1
# 116                   cheetah                     2                     0
# 117                  windsurf                     2                     1
#
#               recognition_responsetime recognition_performance  \
# trial_number
# 1                                2.142                     Hit
# 2                                3.233                      CR
# 3                                3.675                     Hit
# 4                                2.303                      CR
# 5                                1.904                      CR
# ...                                ...                     ...
# 113                              3.895                    Miss
# 114                              0.923                      CR
# 115                              1.211                     Hit
# 116                              2.130                    Miss
# 117                              1.185                      CR
#
#               position_correct  position_response  position_accuracy  \
# trial_number
# 1                            6                  6                2.0
# 2                           -1                 -1                NaN
# 3                            9                  9                2.0
# 4                           -1                 -1                NaN
# 5                           -1                 -1                NaN
# ...                        ...                ...                ...
# 113                          8                 -1                0.0
# 114                         -1                 -1                NaN
# 115                          6                  5                1.0
# 116                          5                 -1                0.0
# 117                         -1                 -1                NaN
#
#               position_responsetime
# trial_number
# 1                             1.695
# 2                               NaN
# 3                             0.552
# 4                               NaN
# 5                               NaN
# ...                             ...
# 113                             NaN
# 114                             NaN
# 115                           0.314
# 116                             NaN
# 117                             NaN
#
# [117 rows x 13 columns]
# '../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed/PostScanBehav_pscid7674650_dccid729722.tsv'

# %% [markdown]
# ## Create BIDS compliant 'participants.tsv' file
#
# ### Althought present in current release, it is safer to generate one here to properly index participants
# #### - In previous release cimaq_03-19, participants are labeled according to their 6-digit ID
# #### - Creating this sheet allows proper follow-ip between releases

# %%
# Strip prefixes and extract pscid & dccid
participants = df((((item[0], item[0].split('_', 1)[1][5:12],
                     item[0].rsplit('_', 1)[1][5:], item[2]) for item in allbehavs)),
                 columns=["_c_behavfilenames", "pscid", "dccid", "c_behavpaths"])

# Add 'newname' columns containing BIDS comliant participant IDs with their 7-digits ID
participants["sub-IDs"] = ["sub-"+row[1]["pscid"] for row in participants.iterrows()]
participants["n_behavfilenames"] = ["sub-"+row[1]["pscid"]+"_ses-4_task-memory_behavioral" for row in participants.iterrows()]
participants = participants.set_index("dccid").sort_index()

# Add current 'events.tsv' files path in a new column 'c_evpaths'
# N.B.: These files use the 6-digits participant IDs
p_events = df((((item[0], item[0].split('sub-', 1)[1][:6], item[2])
                for item in allevents)),
              columns=["c_evfilenames", "dccid", "c_evpaths"]).set_index("dccid").sort_index()
participants = pd.concat([participants, p_events], axis=1)
participants["n_evfilenames"] = [row[1]["c_evfilenames"].replace("sub-"+row[0], "sub-"+row[1]["pscid"])
                                 for row in participants.iterrows()]
display(participants)
# Out:
#                              _c_behavfilenames    pscid  \
# dccid
# 108391  PostScanBehav_pscid4509950_dccid108391  4509950
# 120839  PostScanBehav_pscid7424803_dccid120839  7424803
# 122922  PostScanBehav_pscid7874568_dccid122922  7874568
# 127228  PostScanBehav_pscid3865361_dccid127228  3865361
# 139593  PostScanBehav_pscid5760364_dccid139593  5760364
# ...                                        ...      ...
# 979001  PostScanBehav_pscid7516889_dccid979001  7516889
# 983291  PostScanBehav_pscid3874544_dccid983291  3874544
# 988602  PostScanBehav_pscid6633412_dccid988602  6633412
# 996599  PostScanBehav_pscid4576408_dccid996599  4576408
# 998166  PostScanBehav_pscid7543023_dccid998166  7543023
#
#                                              c_behavpaths      sub-IDs  \
# dccid
# 108391  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-4509950
# 120839  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-7424803
# 122922  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-7874568
# 127228  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-3865361
# 139593  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-5760364
# ...                                                   ...          ...
# 979001  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-7516889
# 983291  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-3874544
# 988602  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-6633412
# 996599  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-4576408
# 998166  ../../../data/simexp/DATA/cimaq_03-19/derivati...  sub-7543023
#
#                                 n_behavfilenames  \
# dccid
# 108391  sub-4509950_ses-4_task-memory_behavioral
# 120839  sub-7424803_ses-4_task-memory_behavioral
# 122922  sub-7874568_ses-4_task-memory_behavioral
# 127228  sub-3865361_ses-4_task-memory_behavioral
# 139593  sub-5760364_ses-4_task-memory_behavioral
# ...                                          ...
# 979001  sub-7516889_ses-4_task-memory_behavioral
# 983291  sub-3874544_ses-4_task-memory_behavioral
# 988602  sub-6633412_ses-4_task-memory_behavioral
# 996599  sub-4576408_ses-4_task-memory_behavioral
# 998166  sub-7543023_ses-4_task-memory_behavioral
#
#                               c_evfilenames  \
# dccid
# 108391  sub-108391_ses-4_task-memory_events
# 120839  sub-120839_ses-4_task-memory_events
# 122922  sub-122922_ses-4_task-memory_events
# 127228  sub-127228_ses-4_task-memory_events
# 139593  sub-139593_ses-4_task-memory_events
# ...                                     ...
# 979001  sub-979001_ses-4_task-memory_events
# 983291  sub-983291_ses-4_task-memory_events
# 988602  sub-988602_ses-4_task-memory_events
# 996599  sub-996599_ses-4_task-memory_events
# 998166  sub-998166_ses-4_task-memory_events
#
#                                                 c_evpaths  \
# dccid
# 108391  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 120839  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 122922  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 127228  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 139593  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# ...                                                   ...
# 979001  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 983291  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 988602  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 996599  ../../../data/simexp/DATA/cimaq_03-19/derivati...
# 998166  ../../../data/simexp/DATA/cimaq_03-19/derivati...
#
#                                n_evfilenames
# dccid
# 108391  sub-4509950_ses-4_task-memory_events
# 120839  sub-7424803_ses-4_task-memory_events
# 122922  sub-7874568_ses-4_task-memory_events
# 127228  sub-3865361_ses-4_task-memory_events
# 139593  sub-5760364_ses-4_task-memory_events
# ...                                      ...
# 979001  sub-7516889_ses-4_task-memory_events
# 983291  sub-3874544_ses-4_task-memory_events
# 988602  sub-6633412_ses-4_task-memory_events
# 996599  sub-4576408_ses-4_task-memory_events
# 998166  sub-7543023_ses-4_task-memory_events
#
# [103 rows x 8 columns]

# %% [markdown]
# ### Create (oldpath, newpath) tuples to rename all files according to BIDS

# %%
behav_renamer = tuple(zip(participants["c_behavpaths"],
                          [join(dname(row[1]["c_behavpaths"]), row[1]["n_behavfilenames"]+".tsv")
                           for row in participants.iterrows()]))
ev_renamer = tuple(zip(participants["c_evpaths"],
                       [join(dname(row[1]["c_evpaths"]), row[1]["n_evfilenames"]+".tsv")
                        for row in participants.iterrows()]))
# Showing examples
display(behav_renamer[0], ev_renamer[0])
# Out:
# ('../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed/PostScanBehav_pscid4509950_dccid108391.tsv',
#  '../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed/sub-4509950_ses-4_task-memory_behavioral.tsv')
# ('../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed/sub-108391_ses-4_task-memory_events.tsv',
#  '../../../data/simexp/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed/sub-4509950_ses-4_task-memory_events.tsv')

# %% [markdown]
# #### Perform renaming operation using "os.rename"

# %%
# [os.rename(item[0], item[1]) for item in behav_renamer]
# [os.rename(item[0], item[1]) for item in ev_renamer]
